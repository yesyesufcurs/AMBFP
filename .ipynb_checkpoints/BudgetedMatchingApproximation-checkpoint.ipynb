# %%
# import libraries needed
import time
import networkx as nx
from sortedcontainers import SortedList, SortedSet, SortedDict
import random
import numpy as np
import math
from itertools import chain, combinations
from networkx.generators.random_graphs import erdos_renyi_graph, fast_gnp_random_graph
from networkx.algorithms.matching import max_weight_matching
from networkx.algorithms.bipartite import random_graph
from subprocess import check_output
from gurobipy.gurobipy import Model, quicksum, GRB

# %%
# Create new edge and set edge weight and cost
def setEdgeData(G, edge, weight, cost):
    G.add_edge(edge[0], edge[1])
    G[edge[0]][edge[1]]['weight'] = weight
    G[edge[0]][edge[1]]['cost'] = cost

def getEdgeCost(G, edge):
    return G[edge[0]][edge[1]]['cost']

def getEdgeWeight(G, edge):
    return G[edge[0]][edge[1]]['weight']

def zerotruncatedPoisson(p):
    #source: https://web.archive.org/web/20180826164029/http://giocc.com/zero_truncated_poisson_sampling_algorithm.html
    k = 1
    t = math.e**(-p) / (1 - math.e**(-p)) * p
    s = t
    u = random.random()
    while s < u:
        k += 1
        t *= p / k
        s += t
    return k

def isMatching(edges):
    # Check if set of edges is matching
    seen = []
    for e in edges:
        if e[0] in seen:
            return False
        seen.append(e[0])
        if e[1] in seen:
            return False
        seen.append(e[1])
    return True

def powerset(iterable, maxSize):
    "Source: https://docs.python.org/3/library/itertools.html#itertools-recipes"
    "powerset([1,2,3]) --> () (1,) (2,) (3,) (1,2) (1,3) (2,3) (1,2,3)"
    s = list(iterable)
    return chain.from_iterable(combinations(s, r) for r in range(maxSize+1))
def powersetAll(iterable):
    "Source: https://docs.python.org/3/library/itertools.html#itertools-recipes"
    "powerset([1,2,3]) --> () (1,) (2,) (3,) (1,2) (1,3) (2,3) (1,2,3)"
    s = list(iterable)
    return chain.from_iterable(combinations(s, r) for r in range(len(s)+1))

def generateRandomGraph(n, p, Ew, Ec):
    """
    Generates random graph using the Erdös-Rényi model.
    params
    n: number of vertices
    p: probability parameter Erdös-Rényi
    Ew: poisson weight parameter
    Ec: poisson cost parameter
    """
    graph = erdos_renyi_graph(n,p)
    for edge in graph.edges:
        weight = 0
        cost = 0
        weight = zerotruncatedPoisson(Ew)
        cost = np.random.poisson(Ec)
        setEdgeData(graph, edge, weight, cost)
    return graph

def computeCost(g, matching):
    return sum(getEdgeCost(g, e) for e in matching)
def computeWeight(g, matching):
    return sum(getEdgeWeight(g, e) for e in matching)
def budgetedMatchingProblemBruteforce(g, B):
    maximum = 0
    cost = 0
    matching = None
    for e in powerset(g.edges):
        if len(e) <= len(g.nodes) and isMatching(e):
            c = computeCost(g, e)
            m = computeWeight(g, e)
            if c <= B and m > maximum:
                maximum = m
                matching = e
                cost = c
    return cost, maximum, matching

def generateRandomUnrestricted(n, p, Ec, Ew):
    """
    Generates random graph using the Erdös-Rényi model.
    This version puts costs on "weight" label
    and weights on "realWeight" label. This is for simpler code later on
    params
    n: number of vertices
    p: probability parameter Erdös-Rényi
    Ew: poisson weight parameter
    Ec: poisson cost parameter
    """
    graph = fast_gnp_random_graph(n,p) # does same as erdos_renyi_graph
    for edge in graph.edges:
        graph[edge[0]][edge[1]]['weight'] = np.random.poisson(Ec) # These are the costs!
        graph[edge[0]][edge[1]]['realWeight'] = zerotruncatedPoisson(Ew) # These are the weights!
    return graph

def generateRandomUnrestrictedBipartite(n, p, Ec, Ew):
    """
    Generates random bipartite graph using the Erdös-Rényi model.
    params
    n: number of vertices
    p: probability parameter Erdös-Rényi
    Ew: poisson weight parameter
    Ec: poisson cost parameter
    """
    graph = random_graph(math.floor(n/2), math.ceil(n/2), p)
    for edge in graph.edges:
        graph[edge[0]][edge[1]]['weight'] = np.random.poisson(Ec)
        graph[edge[0]][edge[1]]['realWeight'] = zerotruncatedPoisson(Ew)
    return graph

def restrictedToGeneral(G):
    """
    Transforms restricted version that has weight = 1 everywhere to
    generic instance of graph
    """
    graph = nx.Graph()
    for e in G.edges():
        setEdgeData(graph, e, 1, G[e[0]][e[1]]['weight'])
    return graph

def transform_graph(G, weight="weight"):
    """
    Transforms min weight to max weight problem
    """
    if len(G.edges) == 0:
        return max_weight_matching(G, maxcardinality, weight)
    G_edges = G.edges(data=weight, default=1)
    min_weight = min([w for _, _, w in G_edges])
    InvG = nx.Graph()
    edges = ((u, v, 1 / (1 + w - min_weight)) for u, v, w in G_edges)
    InvG.add_weighted_edges_from(edges, weight=weight)
    return InvG
    

def transform_graph_max_size_k(G, k, weight="weight"):
    """
    Transforms max weight matching to max weight matching on k vertices
    """
    sumOfWeights = sum(G[e[0]][e[1]][weight] for e in G.edges)
    transG = nx.Graph()
    G_edges = G.edges(data=weight, default=1)
    edges = ((u, v, w + sumOfWeights) for u, v, w in G_edges)
    transG.add_weighted_edges_from(edges, weight=weight)
    old_nodes = list(transG.nodes).copy()
    for i in range(len(transG.nodes), 2*len(transG.nodes)-2*k):
        for j in old_nodes:
            transG.add_edge(j, i, weight=2*sumOfWeights)
    return transG


def transform_graph_min_size_k(G, k, weight="weight"):
    """
    Transforms min weight perfect matching to min weight matching on k vertices
    """
    transG = nx.Graph()
    G_edges = G.edges(data=weight, default=1)
    edges = ((u, v, w) for u, v, w in G_edges)
    transG.add_weighted_edges_from(edges, weight=weight)
    old_nodes = list(G.nodes).copy()
    for i in range(len(G.nodes), 2*len(G.nodes)-2*k):
        for j in old_nodes:
            transG.add_edge(j, i, weight=0)
    return transG

def graphToAdjacency(G):
    """
    Transform graph to adjacency list
    """
    lines = []
    lines.append(str(len(G.nodes)))
    lines.append(str(len(G.edges)))
    for e in G.edges:
        e0 = e[0]
        e1 = e[1]
        lines.append(f"{e0} {e1} {G[e0][e1]['weight']}")
    return lines

def min_cost_matching(G):
    """
    Returns minimum cost perfect matching, if exists else false
    this uses the C# implementation
    source: https://github.com/dilsonpereira/Minimum-Cost-Perfect-Matching
    """
    adjacency = graphToAdjacency(G)
    f = open("input.txt", "w")
    for line in adjacency:
        f.write(line)
        f.write("\n")
    f.close()
    try:
        raw_data = check_output('MinimumCostMatching\example -f input.txt --minweight', shell=True).decode('utf-8').split(":")[-1].split("\r\n")
    except:
        return False
    return set(tuple(int(e) for e in x.split(" ")) for x in raw_data if x!="")

def min_cost_matching_size_k(G, k):
    """
    Compute minimum cost matching of size k
    """
    graph = transform_graph_min_size_k(G, k)
    matching = min_cost_matching(graph)
    if matching == False: return False
    nodesG = len(G.nodes)
    return set(x for x in matching if (x[0] < nodesG and x[1] < nodesG))
    
def budgetedMatchingPolynomial(G, B):
    """
    BudgetedMatching on graph G with weights restricted to 1
    and buget B
    """
    matching = min_cost_matching(G)
    maximumWeight = len(G.nodes)//2
    cost = sum(G[e[0]][e[1]]["weight"] for e in matching) if matching != False else B
    
    while (cost > B or not(matching)) and maximumWeight > 0:
        maximumWeight -= 1
        matching = min_cost_matching_size_k(G, maximumWeight)
        if (matching != False): cost = sum(G[e[0]][e[1]]["weight"] for e in matching)
    return (cost, maximumWeight, matching)

def penalizedGraph(G, lamb):
    """
    Tranform graph weights to weights in Lagrangian relaxation
    """
    graph = nx.Graph()
    for e in G.edges:
        graph.add_edge(*e)
        graph[e[0]][e[1]]["weight"] = G[e[0]][e[1]]["realWeight"] - G[e[0]][e[1]]["weight"] * lamb
    return graph

def budgetedMatchingPenalized(G, B, lamb = 1):
    """
    Compute the Lagrangian relaxation of the budgeted matching problem on graph G with budget B and Lambda value lamb
    """
    graph = penalizedGraph(G, lamb)
    matching = nx.max_weight_matching(graph)
    cost = sum(G[e[0]][e[1]]["weight"] for e in matching) if matching != False else False
    weight = lamb * B + sum(graph[e[0]][e[1]]["weight"] for e in matching) if matching != False else False
    return (cost, weight, matching)
        

def graph_to_gurobi(graph, budget):
    """
    Transform instance of BMP graph to ILP in Gurobi
    """
    model = Model("Budgeted Matching Constaint")
    x = {}
    edges = list(graph.edges)
    nodes = list(graph.nodes)
    for e in edges:
        x[e] = model.addVar(vtype=GRB.INTEGER, name=f'edge[{e}]', lb = 0, ub=1)
    model.addConstrs(
        (quicksum(x[e] for e in edges if v in e) <= 1 for v in nodes),
        name='Satisfy Matching'
    )
    model.addConstr(
        quicksum(x[e] * graph[e[0]][e[1]]['weight'] for e in edges) <= budget,
        name='Satisfy Budget'
    )
    model.setObjective(
        quicksum(x[e] * graph[e[0]][e[1]]['realWeight'] for e in edges),
        sense=GRB.MAXIMIZE
    )
    return model

def linear_relaxation(G, B):
    """
    Compute linear relaxation of BMP instance
    """
    model = Model("Linear relaxation")
    x = {}
    edges = list(G.edges)
    nodes = list(G.nodes)
    for e in edges:
        x[e] = model.addVar(vtype=GRB.CONTINUOUS, name=f'edge[{e}]', lb = 0, ub=1)
    model.addConstrs(
        (quicksum(x[e] for e in edges if v in e) <= 1 for v in nodes),
        name='Satisfy Matching'
    )
    model.addConstr(
        quicksum(x[e] * G[e[0]][e[1]]['weight'] for e in edges) <= B,
        name='Satisfy Budget'
    )
    model.setObjective(
        quicksum(x[e] * G[e[0]][e[1]]['realWeight'] for e in edges),
        sense=GRB.MAXIMIZE
    )
    return model

# %%
def ternary_search(G, B, f, a, b, eps):
    """
    Approximate lambda that minimses Langrangian relaxation using ternary search
    """
    LB = False
    while (b - a) > eps:
        c = a + (b-a)/3
        d = a + 2/3*(b-a)
        fc, fd = f(c), f(d)
        sol_fc, sol_fd = sum(G[e[0]][e[1]]['realWeight'] for e in fc[2]), sum(G[e[0]][e[1]]['realWeight'] for e in fd[2])
        if (not(LB) or sol_fc > LB) and fc[0] <= B:
            LB = sol_fc
        if (not(LB) or sol_fd > LB) and fd[0] <= B:
            LB = sol_fd
        if fc[1] < fd[1]:
            b = d
        else:
            a = c
    return (a if f(a)[1] < f(b)[1] else b, LB)

def binary_search(G, B, f, a, b, eps):
    """
    Approximate lambda that minimses Langrangian relaxation using binary search
    """
    LB = False
    while (b - a) > eps:
        c = (a + b)/2
        fc = f(c)
        sol_fc = sum(G[e[0]][e[1]]['realWeight'] for e in fc[2])
        if (not(LB) or sol_fc > LB) and fc[0] <= B:
            LB = sol_fc
        if fc[0] > B:
            a = c
        else:
            b = c
    return (a if f(a)[1] < f(b)[1] else b, LB)

def minimize_LD(G, B):
    """
    Approximate Lagrangian dual using ternary search
    """
    maxWeight = max(G[e[0]][e[1]]["realWeight"] for e in G.edges)
    minCost = min(G[e[0]][e[1]]["weight"] for e in G.edges)
    maxLam = maxWeight/max(1, minCost)
    def f(x):
        return budgetedMatchingPenalized(G, B, x)
    x = ternary_search(G, B, f, 0, maxLam, 0.01)
    return (x[0], f(x[0]), x[1])

def minimize_LD_bin(G, B):
    """
    Approximate Lagrangian dual using binary search
    """
    maxWeight = max(G[e[0]][e[1]]["realWeight"] for e in G.edges)
    minCost = min(G[e[0]][e[1]]["weight"] for e in G.edges)
    maxLam = maxWeight/max(1, minCost)
    def f(x):
        return budgetedMatchingPenalized(G, B, x)
    x = binary_search(G, B, f, 0, maxLam, 0.0001)
    return (x[0], f(x[0]), x[1])

def bounds_LD(G, B):
    """
    Approximate lower and upper bound using Lagrangian relaxation using ternary search
    """
    ans = minimize_LD(G,B)
    return (math.ceil(ans[-1]), math.floor(ans[1][1]))

def bounds_LD_bin(G, B):
    """
    Approximate lower and upper bound using Lagrangian relaxation using binary search
    """
    ans = minimize_LD_bin(G,B)
    return (math.ceil(ans[-1]), math.floor(ans[1][1]))

def bounds_LR(G, B):
    """
    Approximate lower and upper bound using linear relaxation and rounding down method
    """
    model = linear_relaxation(G, B)
    model.optimize()
    e = list(G.edges)
    x = model.x
    LB = sum(G[e[i][0]][e[i][1]]['realWeight'] * math.floor(x[i]) for i in range(len(x)))
    UB = model.objval
    return(LB, math.floor(UB))

# %%
'''
Test of budgeted matching approximation on sparse graphs
LRs = Linear Relaxation bounds
LDs_bin = Lagrangian relaxation bounds
sols = Exact solutions
'''
import time
# Sparse Graphs
LRs = {}
LDs_bin = {}
sols = {}
for n in range(100, 1001, 50):
    print("iterationnumber", n)
    running_time_bruteforce = 0
    running_time_gurobi = 0
    LRs[n] = []
    LDs_bin[n] = []
    sols[n] = []
    for i in range(5):
        g = generateRandomUnrestricted(n, 2/n, 10, 10)
        LR = bounds_LR(g, 3*n)
        LRs[n].append(LR)
        model = graph_to_gurobi(g, 3*n)
        model.optimize()
        sols[n].append(model.objval)
        LDbin = bounds_LD_bin(g, 3*n)
        LDs_bin[n].append(LDbin)
# Out:
# iterationnumber 100
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 101 rows, 96 columns and 288 nonzeros
# Model fingerprint: 0xd82e2c1c
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+02]
# Presolve removed 43 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 58 rows, 96 columns, 259 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.6900000e+02   2.512500e+01   0.000000e+00      0s
#       18    3.7500000e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 18 iterations and 0.01 seconds
# Optimal objective  3.750000000e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 101 rows, 96 columns and 288 nonzeros
# Model fingerprint: 0xa0247950
# Variable types: 0 continuous, 96 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+02]
# Found heuristic solution: objective 285.0000000
# Presolve removed 48 rows and 13 columns
# Presolve time: 0.00s
# Presolved: 53 rows, 83 columns, 220 nonzeros
# Found heuristic solution: objective 326.0000000
# Variable types: 0 continuous, 83 integer (83 binary)
#
# Root relaxation: objective 3.750000e+02, 19 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     375.0000000  375.00000  0.00%     -    0s
#
# Explored 0 nodes (19 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 375 326 285
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.750000000000e+02, best bound 3.750000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 101 rows, 98 columns and 294 nonzeros
# Model fingerprint: 0x38b14d48
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+02]
# Presolve removed 39 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 62 rows, 98 columns, 267 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.3700000e+02   5.100000e+01   0.000000e+00      0s
#       31    3.7333333e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 31 iterations and 0.00 seconds
# Optimal objective  3.733333333e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 101 rows, 98 columns and 294 nonzeros
# Model fingerprint: 0x0eaf2bbc
# Variable types: 0 continuous, 98 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+02]
# Found heuristic solution: objective 279.0000000
# Presolve removed 47 rows and 14 columns
# Presolve time: 0.00s
# Presolved: 54 rows, 84 columns, 218 nonzeros
# Found heuristic solution: objective 346.0000000
# Variable types: 0 continuous, 84 integer (84 binary)
#
# Root relaxation: objective 3.733333e+02, 29 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  373.33333    0    1  346.00000  373.33333  7.90%     -    0s
# H    0     0                     369.0000000  373.33333  1.17%     -    0s
# H    0     0                     372.0000000  373.33333  0.36%     -    0s
#
# Cutting planes:
#   GUB cover: 1
#
# Explored 1 nodes (29 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 372 369 346 279
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.720000000000e+02, best bound 3.720000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 101 rows, 91 columns and 273 nonzeros
# Model fingerprint: 0x1c159af1
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+02]
# Presolve removed 45 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 56 rows, 91 columns, 240 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.6100000e+02   5.075000e+01   0.000000e+00      0s
#       26    3.8933333e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 26 iterations and 0.00 seconds
# Optimal objective  3.893333333e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 101 rows, 91 columns and 273 nonzeros
# Model fingerprint: 0xc335f995
# Variable types: 0 continuous, 91 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+02]
# Found heuristic solution: objective 309.0000000
# Presolve removed 54 rows and 12 columns
# Presolve time: 0.00s
# Presolved: 47 rows, 79 columns, 195 nonzeros
# Found heuristic solution: objective 363.0000000
# Variable types: 0 continuous, 79 integer (79 binary)
#
# Root relaxation: objective 3.893333e+02, 16 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  389.33333    0    1  363.00000  389.33333  7.25%     -    0s
# H    0     0                     388.0000000  389.33333  0.34%     -    0s
#      0     0  389.33333    0    1  388.00000  389.33333  0.34%     -    0s
#
# Cutting planes:
#   Cover: 1
#   RLT: 1
#
# Explored 1 nodes (17 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 388 363 309
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.880000000000e+02, best bound 3.880000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 101 rows, 109 columns and 327 nonzeros
# Model fingerprint: 0x210ab5f1
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [4e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+02]
# Presolve removed 34 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 67 rows, 109 columns, 298 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.4700000e+02   6.350000e+01   0.000000e+00      0s
#       29    4.5040000e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 29 iterations and 0.00 seconds
# Optimal objective  4.504000000e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 101 rows, 109 columns and 327 nonzeros
# Model fingerprint: 0x3f271b3a
# Variable types: 0 continuous, 109 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [4e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+02]
# Found heuristic solution: objective 315.0000000
# Presolve removed 40 rows and 12 columns
# Presolve time: 0.00s
# Presolved: 61 rows, 97 columns, 257 nonzeros
# Found heuristic solution: objective 411.0000000
# Variable types: 0 continuous, 97 integer (97 binary)
#
# Root relaxation: objective 4.504000e+02, 22 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  450.40000    0    1  411.00000  450.40000  9.59%     -    0s
# H    0     0                     450.0000000  450.40000  0.09%     -    0s
#      0     0  450.40000    0    1  450.00000  450.40000  0.09%     -    0s
#
# Explored 1 nodes (22 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 450 411 315
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.500000000000e+02, best bound 4.500000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 101 rows, 118 columns and 354 nonzeros
# Model fingerprint: 0xf1c01944
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [4e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+02]
# Presolve removed 29 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 72 rows, 117 columns, 333 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    7.0000000e+02   9.212500e+01   0.000000e+00      0s
#       39    4.2900000e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 39 iterations and 0.00 seconds
# Optimal objective  4.290000000e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 101 rows, 118 columns and 354 nonzeros
# Model fingerprint: 0xe6baa7a4
# Variable types: 0 continuous, 118 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [4e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+02]
# Found heuristic solution: objective 276.0000000
# Presolve removed 38 rows and 19 columns
# Presolve time: 0.00s
# Presolved: 63 rows, 99 columns, 270 nonzeros
# Found heuristic solution: objective 383.0000000
# Variable types: 0 continuous, 99 integer (99 binary)
#
# Root relaxation: objective 4.290000e+02, 29 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     429.0000000  429.00000  0.00%     -    0s
#
# Explored 0 nodes (29 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 429 383 276
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.290000000000e+02, best bound 4.290000000000e+02, gap 0.0000%
# iterationnumber 150
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 151 rows, 164 columns and 492 nonzeros
# Model fingerprint: 0xf7b4a927
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Presolve removed 49 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 102 rows, 164 columns, 459 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.2800000e+02   1.065000e+02   0.000000e+00      0s
#       42    6.2784615e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 42 iterations and 0.01 seconds
# Optimal objective  6.278461538e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 151 rows, 164 columns and 492 nonzeros
# Model fingerprint: 0x6ffea3c7
# Variable types: 0 continuous, 164 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 476.0000000
# Presolve removed 60 rows and 20 columns
# Presolve time: 0.00s
# Presolved: 91 rows, 144 columns, 393 nonzeros
# Found heuristic solution: objective 586.0000000
# Variable types: 0 continuous, 144 integer (144 binary)
#
# Root relaxation: objective 6.278462e+02, 51 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  627.84615    0    9  586.00000  627.84615  7.14%     -    0s
# H    0     0                     624.0000000  627.84615  0.62%     -    0s
# H    0     0                     625.0000000  627.84615  0.46%     -    0s
# H    0     0                     627.0000000  627.84615  0.13%     -    0s
#
# Cutting planes:
#   Gomory: 1
#
# Explored 1 nodes (51 simplex iterations) in 0.02 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 627 625 624 ... 476
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.270000000000e+02, best bound 6.270000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 151 rows, 149 columns and 447 nonzeros
# Model fingerprint: 0x57c4de1b
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Presolve removed 64 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 87 rows, 148 columns, 403 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    8.7100000e+02   7.962500e+01   0.000000e+00      0s
#       37    6.1821429e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 37 iterations and 0.00 seconds
# Optimal objective  6.182142857e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 151 rows, 149 columns and 447 nonzeros
# Model fingerprint: 0x23ce393e
# Variable types: 0 continuous, 149 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 498.0000000
# Presolve removed 81 rows and 32 columns
# Presolve time: 0.00s
# Presolved: 70 rows, 117 columns, 297 nonzeros
# Found heuristic solution: objective 585.0000000
# Variable types: 0 continuous, 117 integer (117 binary)
#
# Root relaxation: objective 6.182143e+02, 33 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  618.21429    0    1  585.00000  618.21429  5.68%     -    0s
# H    0     0                     618.0000000  618.21429  0.03%     -    0s
#      0     0  618.21429    0    1  618.00000  618.21429  0.03%     -    0s
#
# Explored 1 nodes (33 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 618 585 498
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.180000000000e+02, best bound 6.180000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 151 rows, 159 columns and 477 nonzeros
# Model fingerprint: 0xb2814adf
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [2e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Presolve removed 51 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 100 rows, 159 columns, 444 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    8.7500000e+02   9.150000e+01   0.000000e+00      0s
#       31    6.0714286e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 31 iterations and 0.00 seconds
# Optimal objective  6.071428571e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 151 rows, 159 columns and 477 nonzeros
# Model fingerprint: 0xc77f7b52
# Variable types: 0 continuous, 159 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [2e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 425.0000000
# Presolve removed 61 rows and 19 columns
# Presolve time: 0.00s
# Presolved: 90 rows, 140 columns, 381 nonzeros
# Found heuristic solution: objective 547.0000000
# Variable types: 0 continuous, 140 integer (140 binary)
#
# Root relaxation: objective 6.071429e+02, 31 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  607.14286    0    1  547.00000  607.14286  11.0%     -    0s
# H    0     0                     606.0000000  607.14286  0.19%     -    0s
#      0     0  607.14286    0    1  606.00000  607.14286  0.19%     -    0s
#
# Explored 1 nodes (31 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 606 547 425
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.060000000000e+02, best bound 6.060000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 151 rows, 146 columns and 438 nonzeros
# Model fingerprint: 0x0694f694
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Presolve removed 72 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 79 rows, 145 columns, 388 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    8.3800000e+02   8.050000e+01   0.000000e+00      0s
# Extra simplex iterations after uncrush: 1
#       35    5.7992308e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 35 iterations and 0.01 seconds
# Optimal objective  5.799230769e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 151 rows, 146 columns and 438 nonzeros
# Model fingerprint: 0xae7c6d6f
# Variable types: 0 continuous, 146 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 455.0000000
# Presolve removed 78 rows and 22 columns
# Presolve time: 0.00s
# Presolved: 73 rows, 124 columns, 323 nonzeros
# Found heuristic solution: objective 528.0000000
# Variable types: 0 continuous, 124 integer (123 binary)
#
# Root relaxation: objective 5.799231e+02, 28 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  579.92308    0    1  528.00000  579.92308  9.83%     -    0s
# H    0     0                     578.0000000  579.92308  0.33%     -    0s
# H    0     0                     579.0000000  579.92308  0.16%     -    0s
#      0     0  579.92308    0    1  579.00000  579.92308  0.16%     -    0s
#
# Explored 1 nodes (28 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 579 578 528 455
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.790000000000e+02, best bound 5.790000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 151 rows, 149 columns and 447 nonzeros
# Model fingerprint: 0xadd3b33c
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [2e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Presolve removed 68 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 83 rows, 149 columns, 399 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    8.6900000e+02   9.862500e+01   0.000000e+00      0s
#       29    5.7328571e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 29 iterations and 0.00 seconds
# Optimal objective  5.732857143e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 151 rows, 149 columns and 447 nonzeros
# Model fingerprint: 0xef703ec4
# Variable types: 0 continuous, 149 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [2e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 441.0000000
# Presolve removed 85 rows and 28 columns
# Presolve time: 0.00s
# Presolved: 66 rows, 121 columns, 306 nonzeros
# Found heuristic solution: objective 539.0000000
# Variable types: 0 continuous, 121 integer (119 binary)
#
# Root relaxation: objective 5.732857e+02, 29 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  573.28571    0    3  539.00000  573.28571  6.36%     -    0s
# H    0     0                     561.0000000  573.28571  2.19%     -    0s
# H    0     0                     572.0000000  573.28571  0.22%     -    0s
# H    0     0                     573.0000000  573.28571  0.05%     -    0s
#      0     0  573.28571    0    3  573.00000  573.28571  0.05%     -    0s
#
# Explored 1 nodes (29 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 573 572 561 ... 441
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.730000000000e+02, best bound 5.730000000000e+02, gap 0.0000%
# iterationnumber 200
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 201 rows, 191 columns and 573 nonzeros
# Model fingerprint: 0xdf6b9ef9
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [2e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+02]
# Presolve removed 77 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 124 rows, 191 columns, 520 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.1040000e+03   8.887500e+01   0.000000e+00      0s
#       37    8.1282353e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 37 iterations and 0.01 seconds
# Optimal objective  8.128235294e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 201 rows, 191 columns and 573 nonzeros
# Model fingerprint: 0xdf8a6111
# Variable types: 0 continuous, 191 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [2e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+02]
# Found heuristic solution: objective 622.0000000
# Presolve removed 92 rows and 26 columns
# Presolve time: 0.00s
# Presolved: 109 rows, 165 columns, 432 nonzeros
# Found heuristic solution: objective 747.0000000
# Variable types: 0 continuous, 165 integer (165 binary)
#
# Root relaxation: objective 8.128235e+02, 39 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  812.82353    0    3  747.00000  812.82353  8.81%     -    0s
# H    0     0                     809.0000000  812.82353  0.47%     -    0s
# H    0     0                     812.0000000  812.82353  0.10%     -    0s
#      0     0  812.82353    0    3  812.00000  812.82353  0.10%     -    0s
#
# Explored 1 nodes (39 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 812 809 747 622
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.120000000000e+02, best bound 8.120000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 201 rows, 189 columns and 567 nonzeros
# Model fingerprint: 0x314c0dd9
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+02]
# Presolve removed 87 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 114 rows, 189 columns, 518 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.1400000e+03   1.238750e+02   0.000000e+00      0s
#       47    7.5192308e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 47 iterations and 0.01 seconds
# Optimal objective  7.519230769e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 201 rows, 189 columns and 567 nonzeros
# Model fingerprint: 0x2bc9be9c
# Variable types: 0 continuous, 189 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+02]
# Found heuristic solution: objective 570.0000000
# Presolve removed 101 rows and 26 columns
# Presolve time: 0.00s
# Presolved: 100 rows, 163 columns, 429 nonzeros
# Found heuristic solution: objective 711.0000000
# Variable types: 0 continuous, 163 integer (163 binary)
#
# Root relaxation: objective 7.519231e+02, 36 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  751.92308    0    1  711.00000  751.92308  5.76%     -    0s
# H    0     0                     749.0000000  751.92308  0.39%     -    0s
# H    0     0                     750.0000000  751.92308  0.26%     -    0s
# H    0     0                     751.0000000  751.92308  0.12%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   RLT: 1
#
# Explored 1 nodes (36 simplex iterations) in 0.02 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 751 750 749 ... 570
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.510000000000e+02, best bound 7.510000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 201 rows, 215 columns and 645 nonzeros
# Model fingerprint: 0x004e2257
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+02]
# Presolve removed 72 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 129 rows, 214 columns, 597 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.1810000e+03   1.091250e+02   0.000000e+00      0s
#       52    8.3180000e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 52 iterations and 0.01 seconds
# Optimal objective  8.318000000e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 201 rows, 215 columns and 645 nonzeros
# Model fingerprint: 0x83fcef4a
# Variable types: 0 continuous, 215 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+02]
# Found heuristic solution: objective 661.0000000
# Presolve removed 85 rows and 27 columns
# Presolve time: 0.00s
# Presolved: 116 rows, 188 columns, 511 nonzeros
# Found heuristic solution: objective 785.0000000
# Variable types: 0 continuous, 188 integer (188 binary)
#
# Root relaxation: objective 8.318000e+02, 52 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  831.80000    0    2  785.00000  831.80000  5.96%     -    0s
# H    0     0                     830.0000000  831.80000  0.22%     -    0s
# H    0     0                     831.0000000  831.80000  0.10%     -    0s
#      0     0  831.80000    0    2  831.00000  831.80000  0.10%     -    0s
#
# Explored 1 nodes (52 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 831 830 785 661
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.310000000000e+02, best bound 8.310000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 201 rows, 184 columns and 552 nonzeros
# Model fingerprint: 0x2e303499
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+02]
# Presolve removed 88 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 113 rows, 184 columns, 495 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.6800000e+02   9.387500e+01   0.000000e+00      0s
#       39    7.4000000e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 39 iterations and 0.00 seconds
# Optimal objective  7.400000000e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 201 rows, 184 columns and 552 nonzeros
# Model fingerprint: 0x5dcb022e
# Variable types: 0 continuous, 184 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+02]
# Found heuristic solution: objective 548.0000000
# Presolve removed 109 rows and 31 columns
# Presolve time: 0.00s
# Presolved: 92 rows, 153 columns, 388 nonzeros
# Found heuristic solution: objective 687.0000000
# Variable types: 0 continuous, 153 integer (151 binary)
#
# Root relaxation: objective 7.400000e+02, 35 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     740.0000000  740.00000  0.00%     -    0s
#
# Explored 0 nodes (35 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 740 687 548
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.400000000000e+02, best bound 7.400000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 201 rows, 199 columns and 597 nonzeros
# Model fingerprint: 0x49756aa9
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+02]
# Presolve removed 84 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 117 rows, 196 columns, 542 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0100000e+03   8.512500e+01   0.000000e+00      0s
#       57    7.7056522e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 57 iterations and 0.00 seconds
# Optimal objective  7.705652174e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 201 rows, 199 columns and 597 nonzeros
# Model fingerprint: 0x896c81ab
# Variable types: 0 continuous, 199 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+02]
# Found heuristic solution: objective 590.0000000
# Presolve removed 94 rows and 27 columns
# Presolve time: 0.00s
# Presolved: 107 rows, 172 columns, 465 nonzeros
# Found heuristic solution: objective 712.0000000
# Variable types: 0 continuous, 172 integer (172 binary)
#
# Root relaxation: objective 7.705000e+02, 52 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  770.50000    0    1  712.00000  770.50000  8.22%     -    0s
# H    0     0                     767.0000000  770.50000  0.46%     -    0s
# H    0     0                     769.0000000  770.50000  0.20%     -    0s
# H    0     0                     770.0000000  770.50000  0.06%     -    0s
#
# Cutting planes:
#   Cover: 1
#   RLT: 1
#
# Explored 1 nodes (52 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 770 769 767 ... 590
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.700000000000e+02, best bound 7.700000000000e+02, gap 0.0000%
# iterationnumber 250
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 251 rows, 272 columns and 816 nonzeros
# Model fingerprint: 0xf0ddf037
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [2e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+02]
# Presolve removed 86 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 165 rows, 272 columns, 753 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.5380000e+03   1.808750e+02   0.000000e+00      0s
#       58    1.0053077e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 58 iterations and 0.01 seconds
# Optimal objective  1.005307692e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 251 rows, 272 columns and 816 nonzeros
# Model fingerprint: 0x90f8933f
# Variable types: 0 continuous, 272 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [2e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+02]
# Found heuristic solution: objective 731.0000000
# Presolve removed 108 rows and 42 columns
# Presolve time: 0.00s
# Presolved: 143 rows, 230 columns, 615 nonzeros
# Found heuristic solution: objective 888.0000000
# Variable types: 0 continuous, 230 integer (229 binary)
#
# Root relaxation: objective 1.005308e+03, 52 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1005.30769    0    5  888.00000 1005.30769  13.2%     -    0s
# H    0     0                     990.0000000 1005.30769  1.55%     -    0s
# H    0     0                    1002.0000000 1005.30769  0.33%     -    0s
# H    0     0                    1003.0000000 1005.30769  0.23%     -    0s
# H    0     0                    1004.0000000 1005.30769  0.13%     -    0s
# H    0     0                    1005.0000000 1005.30769  0.03%     -    0s
#      0     0 1005.30769    0    5 1005.00000 1005.30769  0.03%     -    0s
#
# Explored 1 nodes (52 simplex iterations) in 0.02 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 7: 1005 1004 1003 ... 731
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.005000000000e+03, best bound 1.005000000000e+03, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 251 rows, 259 columns and 777 nonzeros
# Model fingerprint: 0x968cc22f
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+02]
# Presolve removed 97 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 154 rows, 259 columns, 713 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.3860000e+03   1.140000e+02   0.000000e+00      0s
#       59    1.0192000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 59 iterations and 0.01 seconds
# Optimal objective  1.019200000e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 251 rows, 259 columns and 777 nonzeros
# Model fingerprint: 0x2011cccb
# Variable types: 0 continuous, 259 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+02]
# Found heuristic solution: objective 781.0000000
# Presolve removed 126 rows and 45 columns
# Presolve time: 0.00s
# Presolved: 125 rows, 214 columns, 555 nonzeros
# Found heuristic solution: objective 951.0000000
# Variable types: 0 continuous, 214 integer (213 binary)
#
# Root relaxation: objective 1.019200e+03, 53 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1019.20000    0    3  951.00000 1019.20000  7.17%     -    0s
# H    0     0                    1014.0000000 1019.20000  0.51%     -    0s
# H    0     0                    1018.0000000 1019.20000  0.12%     -    0s
# H    0     0                    1019.0000000 1019.20000  0.02%     -    0s
#      0     0 1019.20000    0    3 1019.00000 1019.20000  0.02%     -    0s
#
# Explored 1 nodes (53 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 1019 1018 1014 ... 781
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.019000000000e+03, best bound 1.019000000000e+03, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 251 rows, 247 columns and 741 nonzeros
# Model fingerprint: 0x1f22031c
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [4e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+02]
# Presolve removed 105 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 146 rows, 246 columns, 667 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.4720000e+03   1.417500e+02   0.000000e+00      0s
#       63    1.0268000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 63 iterations and 0.00 seconds
# Optimal objective  1.026800000e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 251 rows, 247 columns and 741 nonzeros
# Model fingerprint: 0xc0ac5ad5
# Variable types: 0 continuous, 247 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [4e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+02]
# Found heuristic solution: objective 844.0000000
# Presolve removed 142 rows and 62 columns
# Presolve time: 0.00s
# Presolved: 109 rows, 185 columns, 463 nonzeros
# Found heuristic solution: objective 973.0000000
# Variable types: 0 continuous, 185 integer (182 binary)
#
# Root relaxation: objective 1.026800e+03, 48 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1026.80000    0    3  973.00000 1026.80000  5.53%     -    0s
# H    0     0                    1025.0000000 1026.80000  0.18%     -    0s
# H    0     0                    1026.0000000 1026.80000  0.08%     -    0s
#      0     0 1026.80000    0    3 1026.00000 1026.80000  0.08%     -    0s
#
# Explored 1 nodes (48 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 1026 1025 973 844
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.026000000000e+03, best bound 1.026000000000e+03, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 251 rows, 256 columns and 768 nonzeros
# Model fingerprint: 0xff2ee6e4
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [2e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+02]
# Presolve removed 99 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 152 rows, 253 columns, 689 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.4400000e+03   1.093125e+02   0.000000e+00      0s
#       64    1.0093333e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 64 iterations and 0.01 seconds
# Optimal objective  1.009333333e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 251 rows, 256 columns and 768 nonzeros
# Model fingerprint: 0x5ac95606
# Variable types: 0 continuous, 256 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [2e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+02]
# Found heuristic solution: objective 684.0000000
# Presolve removed 120 rows and 41 columns
# Presolve time: 0.00s
# Presolved: 131 rows, 215 columns, 559 nonzeros
# Found heuristic solution: objective 922.0000000
# Variable types: 0 continuous, 215 integer (213 binary)
#
# Root relaxation: objective 1.009333e+03, 61 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1009.33333    0    1  922.00000 1009.33333  9.47%     -    0s
# H    0     0                    1007.0000000 1009.33333  0.23%     -    0s
# H    0     0                    1009.0000000 1009.33333  0.03%     -    0s
#      0     0 1009.33333    0    1 1009.00000 1009.33333  0.03%     -    0s
#
# Explored 1 nodes (61 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 1009 1007 922 684
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.009000000000e+03, best bound 1.009000000000e+03, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 251 rows, 232 columns and 696 nonzeros
# Model fingerprint: 0xe33994bf
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+02]
# Presolve removed 114 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 137 rows, 231 columns, 622 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.2710000e+03   1.072500e+02   0.000000e+00      0s
#       51    9.4000000e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 51 iterations and 0.01 seconds
# Optimal objective  9.400000000e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 251 rows, 232 columns and 696 nonzeros
# Model fingerprint: 0x1eda0f23
# Variable types: 0 continuous, 232 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+02]
# Found heuristic solution: objective 786.0000000
# Presolve removed 148 rows and 59 columns
# Presolve time: 0.00s
# Presolved: 103 rows, 173 columns, 430 nonzeros
# Found heuristic solution: objective 891.0000000
# Variable types: 0 continuous, 173 integer (171 binary)
#
# Root relaxation: objective 9.400000e+02, 49 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  940.00000    0    3  891.00000  940.00000  5.50%     -    0s
# H    0     0                     932.0000000  940.00000  0.86%     -    0s
# H    0     0                     939.0000000  940.00000  0.11%     -    0s
#
# Cutting planes:
#   Cover: 1
#
# Explored 1 nodes (49 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 939 932 891 786
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.390000000000e+02, best bound 9.390000000000e+02, gap 0.0000%
# iterationnumber 300
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 301 rows, 328 columns and 984 nonzeros
# Model fingerprint: 0x8f4caf60
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+02]
# Presolve removed 113 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 188 rows, 327 columns, 902 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.8220000e+03   1.968750e+02   0.000000e+00      0s
#       70    1.2509565e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 70 iterations and 0.01 seconds
# Optimal objective  1.250956522e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 301 rows, 328 columns and 984 nonzeros
# Model fingerprint: 0xc1673326
# Variable types: 0 continuous, 328 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+02]
# Found heuristic solution: objective 924.0000000
# Presolve removed 147 rows and 62 columns
# Presolve time: 0.00s
# Presolved: 154 rows, 266 columns, 697 nonzeros
# Found heuristic solution: objective 1155.0000000
# Variable types: 0 continuous, 266 integer (264 binary)
#
# Root relaxation: objective 1.250957e+03, 66 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1250.95652    0    3 1155.00000 1250.95652  8.31%     -    0s
# H    0     0                    1249.0000000 1250.95652  0.16%     -    0s
# H    0     0                    1250.0000000 1250.95652  0.08%     -    0s
#
# Cutting planes:
#   GUB cover: 1
#   RLT: 1
#
# Explored 1 nodes (66 simplex iterations) in 0.02 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 1250 1249 1155 924
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.250000000000e+03, best bound 1.250000000000e+03, gap 0.0000%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-e5f993d54000> in <module>
#      23         model.optimize()
#      24         sols[n].append(model.objval)
# ---> 25         LDbin = bounds_LD_bin(g, 3*n)
#      26         LDs_bin[n].append(LDbin)
#
# <ipython-input-14-a34df4e3a32c> in bounds_LD_bin(G, B)
#      90
#      91 def bounds_LD_bin(G, B):
# ---> 92     ans = minimize_LD_bin(G,B)
#      93     return (math.ceil(ans[-1]), math.floor(ans[1][1]))
#      94
#
# <ipython-input-14-a34df4e3a32c> in minimize_LD_bin(G, B)
#      82     def f(x):
#      83         return budgetedMatchingPenalized(G, B, x)
# ---> 84     x = binary_search(G, B, f, 0, maxLam, 0.0001)
#      85     return (x[0], f(x[0]), x[1])
#      86
#
# <ipython-input-14-a34df4e3a32c> in binary_search(G, B, f, a, b, eps)
#      57     while (b - a) > eps:
#      58         c = (a + b)/2
# ---> 59         fc = f(c)
#      60         sol_fc = sum(G[e[0]][e[1]]['realWeight'] for e in fc[2])
#      61         if (not(LB) or sol_fc > LB) and fc[0] <= B:
#
# <ipython-input-14-a34df4e3a32c> in f(x)
#      81     maxLam = maxWeight/max(1, minCost)
#      82     def f(x):
# ---> 83         return budgetedMatchingPenalized(G, B, x)
#      84     x = binary_search(G, B, f, 0, maxLam, 0.0001)
#      85     return (x[0], f(x[0]), x[1])
#
# <ipython-input-2-aa95e185ce6d> in budgetedMatchingPenalized(G, B, lamb)
#     287 def budgetedMatchingPenalized(G, B, lamb = 1):
#     288     graph = penalizedGraph(G, lamb)
# --> 289     matching = nx.max_weight_matching(graph)
#     290     cost = sum(G[e[0]][e[1]]["weight"] for e in matching) if matching != False else False
#     291     weight = lamb * B + sum(graph[e[0]][e[1]]["weight"] for e in matching) if matching != False else False
#
# ~\Anaconda3\lib\site-packages\networkx\algorithms\matching.py in max_weight_matching(G, maxcardinality, weight)
#     794                         continue
#     795                     if (v, w) not in allowedge:
# --> 796                         kslack = slack(v, w)
#     797                         if kslack <= 0:
#     798                             # edge k has zero slack => it is allowable
#
# ~\Anaconda3\lib\site-packages\networkx\algorithms\matching.py in slack(v, w)
#     357     # Return 2 * slack of edge (v, w) (does not work inside blossoms).
#     358     def slack(v, w):
# --> 359         return dualvar[v] + dualvar[w] - 2 * G[v][w].get(weight, 1)
#     360
#     361     # Assign label t to the top-level blossom containing vertex w,
#
# ~\Anaconda3\lib\site-packages\networkx\classes\graph.py in __getitem__(self, n)
#     463         AtlasView({1: {}})
#     464         """
# --> 465         return self.adj[n]
#     466
#     467     def add_node(self, node_for_adding, **attr):
#
# KeyboardInterrupt:

# %%
LDs
# Out:
# {100: [(410, 410)],
#  150: [(550, 554)],
#  200: [(801, 804)],
#  250: [(930, 945)],
#  300: [(1236, 1240)],
#  350: [(1375, 1385)],
#  400: [(1550, 1551)],
#  450: [(1845, 1848)],
#  500: [(2003, 2005)],
#  550: [(2276, 2286)],
#  600: [(2389, 2392)],
#  650: [(2503, 2509)],
#  700: [(2874, 2882)],
#  750: [(2988, 2993)],
#  800: [(3253, 3277)],
#  850: [(3446, 3452)],
#  900: [(3534, 3546)],
#  950: [(3709, 3723)],
#  1000: [(4224, 4229)]}

# %%
LRs
# Out:
# {100: [(410, 410)],
#  150: [(550, 554)],
#  200: [(758, 804)],
#  250: [(938, 945)],
#  300: [(1236, 1240)],
#  350: [(1358, 1385)],
#  400: [(1550, 1551)],
#  450: [(1845, 1848)],
#  500: [(2003, 2005)],
#  550: [(2270, 2286)],
#  600: [(2389, 2392)],
#  650: [(2503, 2509)],
#  700: [(2854, 2882)],
#  750: [(2976, 2993)],
#  800: [(3267, 3277)],
#  850: [(3414, 3452)],
#  900: [(3541, 3546)],
#  950: [(3673, 3723)],
#  1000: [(4224, 4229)]}

# %%
sols
# Out:
# {100: [410.0],
#  150: [553.0],
#  200: [804.0],
#  250: [945.0],
#  300: [1240.0],
#  350: [1385.0],
#  400: [1551.0],
#  450: [1848.0],
#  500: [2005.0],
#  550: [2286.0],
#  600: [2392.0],
#  650: [2508.0],
#  700: [2882.0],
#  750: [2993.0],
#  800: [3277.0],
#  850: [3452.0],
#  900: [3546.0],
#  950: [3723.0],
#  1000: [4229.0]}

# %%
LDs_bin
# Out:
# {100: [(410, 410)],
#  150: [(550, 554)],
#  200: [(801, 804)],
#  250: [(930, 945)],
#  300: [(1236, 1240)],
#  350: [(1375, 1385)],
#  400: [(1550, 1551)],
#  450: [(1845, 1848)],
#  500: [(2003, 2005)],
#  550: [(2276, 2286)],
#  600: [(2389, 2392)],
#  650: [(2503, 2509)],
#  700: [(2874, 2882)],
#  750: [(2988, 2993)],
#  800: [(3253, 3277)],
#  850: [(3446, 3452)],
#  900: [(3534, 3546)],
#  950: [(3709, 3723)],
#  1000: [(4224, 4229)]}

# %%
'''
Test of budgeted matching approximation on dense graphs
LRs_dense = Linear Relaxation bounds
LDs_bin_dense = Lagrangian relaxation bounds
sols_dense = Exact solutions
'''
import time
# dense Graphs
LRs_dense = {}
LDs_bin_dense = {}
sols_dense = {}
for n in range(100, 1001, 50):
    print("iterationnumber", n)
    running_time_bruteforce = 0
    running_time_gurobi = 0
    LRs_dense[n] = []
    LDs_bin_dense[n] = []
    sols_dense[n] = []
    for i in range(5):
        g = generateRandomUnrestricted(n, 0.8, 10, 10)
        LR = bounds_LR(g, 3*n)
        LRs_dense[n].append(LR)
        model = graph_to_gurobi(g, 3*n)
        model.optimize()
        sols_dense[n].append(model.objval)
        LDbin = bounds_LD_bin(g, 3*n)
        LDs_bin_dense[n].append(LDbin)
# Out:
# iterationnumber 100
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 101 rows, 3914 columns and 11742 nonzeros
# Model fingerprint: 0xab65890b
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+02]
# Presolve time: 0.00s
# Presolved: 101 rows, 3914 columns, 11742 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.2050000e+03   1.368875e+03   0.000000e+00      0s
#      208    8.0983333e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 208 iterations and 0.01 seconds
# Optimal objective  8.098333333e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 101 rows, 3914 columns and 11742 nonzeros
# Model fingerprint: 0x08189a47
# Variable types: 0 continuous, 3914 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+02]
# Found heuristic solution: objective 300.0000000
# Presolve time: 0.01s
# Presolved: 101 rows, 3914 columns, 11742 nonzeros
# Variable types: 0 continuous, 3914 integer (3914 binary)
#
# Root relaxation: objective 8.098333e+02, 281 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  809.83333    0   20  300.00000  809.83333   170%     -    0s
# H    0     0                     789.0000000  809.83333  2.64%     -    0s
# H    0     0                     808.0000000  809.83333  0.23%     -    0s
# H    0     0                     809.0000000  809.83333  0.10%     -    0s
#      0     0  809.83333    0   20  809.00000  809.83333  0.10%     -    0s
#
# Explored 1 nodes (282 simplex iterations) in 0.06 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 809 808 789 300
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.090000000000e+02, best bound 8.090000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 101 rows, 3969 columns and 11907 nonzeros
# Model fingerprint: 0xd84d1e97
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+02]
# Presolve time: 0.00s
# Presolved: 101 rows, 3969 columns, 11907 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.2260000e+03   1.709500e+03   0.000000e+00      0s
#      242    8.3700000e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 242 iterations and 0.01 seconds
# Optimal objective  8.370000000e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 101 rows, 3969 columns and 11907 nonzeros
# Model fingerprint: 0x2a3b757b
# Variable types: 0 continuous, 3969 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+02]
# Found heuristic solution: objective 297.0000000
# Presolve time: 0.01s
# Presolved: 101 rows, 3969 columns, 11907 nonzeros
# Variable types: 0 continuous, 3969 integer (3969 binary)
#
# Root relaxation: objective 8.370000e+02, 249 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     837.0000000  837.00000  0.00%     -    0s
#
# Explored 0 nodes (249 simplex iterations) in 0.03 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 837 297
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.370000000000e+02, best bound 8.370000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 101 rows, 3920 columns and 11760 nonzeros
# Model fingerprint: 0xc9458a8f
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+02]
# Presolve time: 0.00s
# Presolved: 101 rows, 3920 columns, 11760 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.6310000e+03   1.864875e+03   0.000000e+00      0s
#      222    8.1190909e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 222 iterations and 0.01 seconds
# Optimal objective  8.119090909e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 101 rows, 3920 columns and 11760 nonzeros
# Model fingerprint: 0x99a37d7d
# Variable types: 0 continuous, 3920 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+02]
# Found heuristic solution: objective 337.0000000
# Presolve time: 0.01s
# Presolved: 101 rows, 3920 columns, 11760 nonzeros
# Variable types: 0 continuous, 3920 integer (3920 binary)
#
# Root relaxation: objective 8.119091e+02, 203 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  811.90909    0   16  337.00000  811.90909   141%     -    0s
# H    0     0                     770.0000000  811.90909  5.44%     -    0s
# H    0     0                     802.0000000  811.90909  1.24%     -    0s
# H    0     0                     809.0000000  811.90909  0.36%     -    0s
#      0     0  811.00000    0   26  809.00000  811.00000  0.25%     -    0s
#      0     0  811.00000    0    8  809.00000  811.00000  0.25%     -    0s
# H    0     0                     810.0000000  811.00000  0.12%     -    0s
#
# Cutting planes:
#   GUB cover: 1
#
# Explored 1 nodes (264 simplex iterations) in 0.10 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 810 809 802 ... 337
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.100000000000e+02, best bound 8.100000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 101 rows, 4046 columns and 12138 nonzeros
# Model fingerprint: 0x805e2f41
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+02]
# Presolve time: 0.00s
# Presolved: 101 rows, 4046 columns, 12138 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.6170000e+03   1.830125e+03   0.000000e+00      0s
#      212    7.8086364e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 212 iterations and 0.01 seconds
# Optimal objective  7.808636364e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 101 rows, 4046 columns and 12138 nonzeros
# Model fingerprint: 0x23cf70cb
# Variable types: 0 continuous, 4046 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+02]
# Found heuristic solution: objective 308.0000000
# Presolve time: 0.01s
# Presolved: 101 rows, 4046 columns, 12138 nonzeros
# Variable types: 0 continuous, 4046 integer (4046 binary)
#
# Root relaxation: objective 7.808636e+02, 234 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  780.86364    0    8  308.00000  780.86364   154%     -    0s
# H    0     0                     764.0000000  780.86364  2.21%     -    0s
# H    0     0                     778.0000000  780.86364  0.37%     -    0s
# H    0     0                     779.0000000  780.86364  0.24%     -    0s
#
# Cutting planes:
#   Clique: 1
#   GUB cover: 1
#
# Explored 1 nodes (234 simplex iterations) in 0.08 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 779 778 764 308
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.790000000000e+02, best bound 7.790000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 101 rows, 3968 columns and 11903 nonzeros
# Model fingerprint: 0x619b52be
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+02]
# Presolve time: 0.00s
# Presolved: 101 rows, 3968 columns, 11903 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.4110000e+03   1.777875e+03   0.000000e+00      0s
#      184    7.9588889e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 184 iterations and 0.01 seconds
# Optimal objective  7.958888889e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 101 rows, 3968 columns and 11903 nonzeros
# Model fingerprint: 0xe00d5be0
# Variable types: 0 continuous, 3968 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+02]
# Found heuristic solution: objective 266.0000000
# Presolve time: 0.01s
# Presolved: 101 rows, 3968 columns, 11903 nonzeros
# Variable types: 0 continuous, 3968 integer (3968 binary)
#
# Root relaxation: objective 7.958889e+02, 224 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  795.88889    0   22  266.00000  795.88889   199%     -    0s
# H    0     0                     770.0000000  795.88889  3.36%     -    0s
# H    0     0                     787.0000000  795.88889  1.13%     -    0s
# H    0     0                     790.0000000  795.88889  0.75%     -    0s
# H    0     0                     793.0000000  795.88889  0.36%     -    0s
#      0     0  795.88889    0   36  793.00000  795.88889  0.36%     -    0s
#      0     0  795.88889    0   16  793.00000  795.88889  0.36%     -    0s
#      0     0  795.83721    0   29  793.00000  795.83721  0.36%     -    0s
# H    0     0                     794.0000000  795.50000  0.19%     -    0s
#      0     0  795.33333    0   13  794.00000  795.33333  0.17%     -    0s
#
# Cutting planes:
#   Cover: 2
#   Clique: 2
#   MIR: 1
#   GUB cover: 1
#   Mod-K: 4
#
# Explored 1 nodes (316 simplex iterations) in 0.10 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 6: 794 793 790 ... 266
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.940000000000e+02, best bound 7.940000000000e+02, gap 0.0000%
# iterationnumber 150
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 151 rows, 8880 columns and 26640 nonzeros
# Model fingerprint: 0x3502385d
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Presolve time: 0.01s
# Presolved: 151 rows, 8880 columns, 26640 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.2775000e+04   3.678250e+03   0.000000e+00      0s
#      374    1.2561190e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 374 iterations and 0.03 seconds
# Optimal objective  1.256119048e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 151 rows, 8880 columns and 26640 nonzeros
# Model fingerprint: 0xfa3cfd68
# Variable types: 0 continuous, 8880 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 480.0000000
# Presolve time: 0.02s
# Presolved: 151 rows, 8880 columns, 26640 nonzeros
# Variable types: 0 continuous, 8880 integer (8880 binary)
#
# Root relaxation: objective 1.256119e+03, 451 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1256.11905    0   37  480.00000 1256.11905   162%     -    0s
# H    0     0                    1188.0000000 1256.11905  5.73%     -    0s
# H    0     0                    1250.0000000 1256.11905  0.49%     -    0s
# H    0     0                    1252.0000000 1256.11905  0.33%     -    0s
# H    0     0                    1254.0000000 1256.11905  0.17%     -    0s
# H    0     0                    1255.0000000 1255.76923  0.06%     -    0s
#
# Cutting planes:
#   Mod-K: 3
#
# Explored 1 nodes (451 simplex iterations) in 0.15 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 6: 1255 1254 1252 ... 480
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.255000000000e+03, best bound 1.255000000000e+03, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 151 rows, 8952 columns and 26855 nonzeros
# Model fingerprint: 0xf9e55a02
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Presolve time: 0.01s
# Presolved: 151 rows, 8952 columns, 26855 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.2158000e+04   3.436000e+03   0.000000e+00      0s
#      379    1.2572222e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 379 iterations and 0.03 seconds
# Optimal objective  1.257222222e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 151 rows, 8952 columns and 26855 nonzeros
# Model fingerprint: 0x8515d533
# Variable types: 0 continuous, 8952 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 464.0000000
# Presolve time: 0.02s
# Presolved: 151 rows, 8952 columns, 26855 nonzeros
# Variable types: 0 continuous, 8952 integer (8952 binary)
#
# Root relaxation: objective 1.257222e+03, 433 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1257.22222    0    8  464.00000 1257.22222   171%     -    0s
# H    0     0                    1245.0000000 1257.22222  0.98%     -    0s
# H    0     0                    1251.0000000 1257.22222  0.50%     -    0s
# H    0     0                    1255.0000000 1257.22222  0.18%     -    0s
# H    0     0                    1256.0000000 1256.57143  0.05%     -    0s
#
# Cutting planes:
#   MIR: 1
#   GUB cover: 1
#
# Explored 1 nodes (433 simplex iterations) in 0.14 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 1256 1255 1251 ... 464
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.256000000000e+03, best bound 1.256000000000e+03, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 151 rows, 8987 columns and 26961 nonzeros
# Model fingerprint: 0x60266b8b
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Presolve time: 0.01s
# Presolved: 151 rows, 8987 columns, 26961 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.3863000e+04   4.056625e+03   0.000000e+00      0s
#      375    1.2682414e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 375 iterations and 0.03 seconds
# Optimal objective  1.268241379e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 151 rows, 8987 columns and 26961 nonzeros
# Model fingerprint: 0x288bff66
# Variable types: 0 continuous, 8987 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 481.0000000
# Presolve time: 0.02s
# Presolved: 151 rows, 8987 columns, 26961 nonzeros
# Variable types: 0 continuous, 8987 integer (8987 binary)
#
# Root relaxation: objective 1.268241e+03, 454 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1268.24138    0   29  481.00000 1268.24138   164%     -    0s
# H    0     0                    1215.0000000 1268.24138  4.38%     -    0s
# H    0     0                    1260.0000000 1268.24138  0.65%     -    0s
# H    0     0                    1266.0000000 1268.24138  0.18%     -    0s
# H    0     0                    1267.0000000 1268.24138  0.10%     -    0s
#
# Cutting planes:
#   Mod-K: 1
#
# Explored 1 nodes (457 simplex iterations) in 0.14 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 1267 1266 1260 ... 481
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.267000000000e+03, best bound 1.267000000000e+03, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 151 rows, 8890 columns and 26669 nonzeros
# Model fingerprint: 0xa2d4741a
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Presolve time: 0.01s
# Presolved: 151 rows, 8890 columns, 26669 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.2286000e+04   3.525375e+03   0.000000e+00      0s
#      371    1.2485000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 371 iterations and 0.03 seconds
# Optimal objective  1.248500000e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 151 rows, 8890 columns and 26669 nonzeros
# Model fingerprint: 0xe57f2d9a
# Variable types: 0 continuous, 8890 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 453.0000000
# Presolve time: 0.02s
# Presolved: 151 rows, 8890 columns, 26669 nonzeros
# Variable types: 0 continuous, 8890 integer (8890 binary)
#
# Root relaxation: objective 1.248500e+03, 455 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1248.50000    0   24  453.00000 1248.50000   176%     -    0s
# H    0     0                    1212.0000000 1248.50000  3.01%     -    0s
# H    0     0                    1238.0000000 1248.50000  0.85%     -    0s
# H    0     0                    1244.0000000 1248.50000  0.36%     -    0s
# H    0     0                    1246.0000000 1248.50000  0.20%     -    0s
# H    0     0                    1248.0000000 1248.50000  0.04%     -    0s
#
# Cutting planes:
#   Clique: 1
#   Mod-K: 1
#
# Explored 1 nodes (455 simplex iterations) in 0.14 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 6: 1248 1246 1244 ... 453
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.248000000000e+03, best bound 1.248000000000e+03, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 151 rows, 8941 columns and 26822 nonzeros
# Model fingerprint: 0x33127bf9
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Presolve time: 0.01s
# Presolved: 151 rows, 8941 columns, 26822 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.1139000e+04   3.141875e+03   0.000000e+00      0s
#      318    1.2810000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 318 iterations and 0.02 seconds
# Optimal objective  1.281000000e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 151 rows, 8941 columns and 26822 nonzeros
# Model fingerprint: 0xc8635806
# Variable types: 0 continuous, 8941 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 481.0000000
# Presolve time: 0.02s
# Presolved: 151 rows, 8941 columns, 26822 nonzeros
# Variable types: 0 continuous, 8941 integer (8941 binary)
#
# Root relaxation: objective 1.281000e+03, 381 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1281.00000    0   15  481.00000 1281.00000   166%     -    0s
# H    0     0                    1225.0000000 1281.00000  4.57%     -    0s
# H    0     0                    1272.0000000 1281.00000  0.71%     -    0s
# H    0     0                    1277.0000000 1281.00000  0.31%     -    0s
# H    0     0                    1278.0000000 1281.00000  0.23%     -    0s
# H    0     0                    1279.0000000 1281.00000  0.16%     -    0s
#
# Cutting planes:
#   Clique: 2
#   Mod-K: 1
#
# Explored 1 nodes (415 simplex iterations) in 0.15 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 6: 1279 1278 1277 ... 481
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.279000000000e+03, best bound 1.279000000000e+03, gap 0.0000%
# iterationnumber 200
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 201 rows, 15982 columns and 47946 nonzeros
# Model fingerprint: 0xc672116d
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+02]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve time: 0.02s
# Presolved: 201 rows, 15982 columns, 47946 nonzeros
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.618e+04
#  Factor NZ  : 2.030e+04 (roughly 7 MBytes of memory)
#  Factor Ops : 2.727e+06 (less than 1 second per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   3.17083759e+05  9.80147125e+02  3.87e+04 1.54e+01  1.80e+01     0s
#
# Barrier performed 0 iterations in 0.05 seconds
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 481 iterations and 0.05 seconds
# Optimal objective  1.730933333e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 201 rows, 15982 columns and 47946 nonzeros
# Model fingerprint: 0xa10030a9
# Variable types: 0 continuous, 15982 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+02]
# Found heuristic solution: objective 575.0000000
# Presolve time: 0.04s
# Presolved: 201 rows, 15982 columns, 47946 nonzeros
# Variable types: 0 continuous, 15982 integer (15982 binary)
# Root relaxation: objective 1.730933e+03, 548 iterations, 0.04 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1730.93333    0   16  575.00000 1730.93333   201%     -    0s
# H    0     0                    1695.0000000 1730.93333  2.12%     -    0s
# H    0     0                    1724.0000000 1730.93333  0.40%     -    0s
# H    0     0                    1727.0000000 1730.93333  0.23%     -    0s
# H    0     0                    1730.0000000 1730.93333  0.05%     -    0s
#
# Cutting planes:
#   Mod-K: 1
#
# Explored 1 nodes (555 simplex iterations) in 0.20 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 1730 1727 1724 ... 575
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.730000000000e+03, best bound 1.730000000000e+03, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 201 rows, 15943 columns and 47827 nonzeros
# Model fingerprint: 0x61fcf789
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+02]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve time: 0.02s
# Presolved: 201 rows, 15943 columns, 47827 nonzeros
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.614e+04
#  Factor NZ  : 2.030e+04 (roughly 7 MBytes of memory)
#  Factor Ops : 2.727e+06 (less than 1 second per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   3.15533028e+05  9.82553564e+02  3.84e+04 1.53e+01  1.79e+01     0s
#    1   2.76674912e+04  2.71991941e+03  2.85e+03 1.42e-14  1.30e+00     0s
#    2   2.50281595e+03  2.46875937e+03  1.43e+02 1.07e-14  9.93e-02     0s
#    3   1.42524776e+03  1.91989174e+03  8.24e+00 1.07e-14  2.06e-02     0s
#    4   1.57563364e+03  1.81410137e+03  7.66e-01 7.11e-15  7.89e-03     0s
#    5   1.64514785e+03  1.77779989e+03  3.28e-01 8.88e-15  4.33e-03     0s
#    6   1.71080020e+03  1.76027585e+03  1.08e-01 7.11e-15  1.61e-03     0s
#    7   1.73627789e+03  1.75193651e+03  3.12e-02 8.88e-15  5.07e-04     0s
#    8   1.74431774e+03  1.74985881e+03  1.04e-02 7.11e-15  1.79e-04     0s
#    9   1.74846543e+03  1.74904266e+03  6.52e-04 1.07e-14  1.84e-05     0s
#   10   1.74881627e+03  1.74881958e+03  9.61e-07 1.07e-14  1.04e-07     0s
#   11   1.74881818e+03  1.74881818e+03  9.07e-12 1.07e-14  3.39e-11     0s
#
# Barrier solved model in 11 iterations and 0.06 seconds
# Optimal objective 1.74881818e+03
#
#
# Solved with dual simplex
# Solved in 537 iterations and 0.06 seconds
# Optimal objective  1.748818182e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 201 rows, 15943 columns and 47827 nonzeros
# Model fingerprint: 0x68d012ef
# Variable types: 0 continuous, 15943 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+02]
# Found heuristic solution: objective 662.0000000
# Presolve time: 0.04s
# Presolved: 201 rows, 15943 columns, 47827 nonzeros
# Variable types: 0 continuous, 15943 integer (15943 binary)
#
# Root relaxation: objective 1.748818e+03, 618 iterations, 0.05 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1748.81818    0   22  662.00000 1748.81818   164%     -    0s
# H    0     0                    1686.0000000 1748.81818  3.73%     -    0s
# H    0     0                    1740.0000000 1748.81818  0.51%     -    0s
# H    0     0                    1746.0000000 1748.81818  0.16%     -    0s
# H    0     0                    1748.0000000 1748.81818  0.05%     -    0s
#
# Cutting planes:
#   Mod-K: 1
#
# Explored 1 nodes (620 simplex iterations) in 0.21 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 1748 1746 1740 ... 662
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.748000000000e+03, best bound 1.748000000000e+03, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 201 rows, 15928 columns and 47784 nonzeros
# Model fingerprint: 0x6bb54270
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+02]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve time: 0.02s
# Presolved: 201 rows, 15928 columns, 47784 nonzeros
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.613e+04
#  Factor NZ  : 2.030e+04 (roughly 7 MBytes of memory)
#  Factor Ops : 2.727e+06 (less than 1 second per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   3.16215108e+05  9.82269149e+02  3.85e+04 1.78e+01  2.08e+01     0s
#    1   2.48324054e+04  2.97316283e+03  2.59e+03 1.07e-14  1.39e+00     0s
#    2   2.14383198e+03  2.65655547e+03  1.10e+02 1.42e-14  1.01e-01     0s
#    3   1.30396697e+03  1.90510815e+03  0.00e+00 1.07e-14  1.88e-02     0s
#    4   1.55200635e+03  1.83856113e+03  0.00e+00 1.07e-14  8.94e-03     0s
#    5   1.64971888e+03  1.80635370e+03  0.00e+00 7.11e-15  4.89e-03     0s
#    6   1.72800937e+03  1.78493570e+03  0.00e+00 7.11e-15  1.78e-03     0s
#    7   1.75295579e+03  1.77228412e+03  0.00e+00 7.11e-15  6.03e-04     0s
#    8   1.76088997e+03  1.76742786e+03  0.00e+00 8.88e-15  2.04e-04     0s
#    9   1.76445356e+03  1.76579433e+03  0.00e+00 7.11e-15  4.18e-05     0s
#   10   1.76491700e+03  1.76502124e+03  0.00e+00 8.88e-15  3.25e-06     0s
#   11   1.76499827e+03  1.76500058e+03  0.00e+00 8.88e-15  7.21e-08     0s
#   12   1.76500000e+03  1.76500000e+03  0.00e+00 1.07e-14  7.21e-11     0s
#
# Barrier solved model in 12 iterations and 0.05 seconds
# Optimal objective 1.76500000e+03
#
#
# Solved with primal simplex
# Solved in 5637 iterations and 0.06 seconds
# Optimal objective  1.765000000e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 201 rows, 15928 columns and 47784 nonzeros
# Model fingerprint: 0x99801a55
# Variable types: 0 continuous, 15928 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+02]
# Found heuristic solution: objective 624.0000000
# Presolve time: 0.04s
# Presolved: 201 rows, 15928 columns, 47784 nonzeros
# Variable types: 0 continuous, 15928 integer (15928 binary)
#
# Root relaxation: objective 1.765000e+03, 687 iterations, 0.05 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1765.00000    0   24  624.00000 1765.00000   183%     -    0s
# H    0     0                    1714.0000000 1765.00000  2.98%     -    0s
# H    0     0                    1755.0000000 1765.00000  0.57%     -    0s
# H    0     0                    1762.0000000 1765.00000  0.17%     -    0s
# H    0     0                    1764.0000000 1765.00000  0.06%     -    0s
#
# Cutting planes:
#   Mod-K: 1
#
# Explored 1 nodes (714 simplex iterations) in 0.31 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 1764 1762 1755 ... 624
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.764000000000e+03, best bound 1.764000000000e+03, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 201 rows, 16004 columns and 48010 nonzeros
# Model fingerprint: 0xde980e3e
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+02]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve time: 0.02s
# Presolved: 201 rows, 16004 columns, 48010 nonzeros
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.620e+04
#  Factor NZ  : 2.030e+04 (roughly 7 MBytes of memory)
#  Factor Ops : 2.727e+06 (less than 1 second per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   3.18473773e+05  9.82187001e+02  3.87e+04 1.32e+01  1.55e+01     0s
#    1   3.20587453e+04  2.49532776e+03  3.67e+03 1.07e-14  1.52e+00     0s
#    2   2.95290983e+03  2.30835967e+03  2.16e+02 1.42e-14  1.20e-01     0s
#    3   1.44010445e+03  1.86476780e+03  1.46e+01 1.42e-14  2.21e-02     0s
#    4   1.54419908e+03  1.75636768e+03  1.18e+00 1.07e-14  7.28e-03     0s
#    5   1.64290186e+03  1.73337285e+03  2.37e-01 7.11e-15  2.95e-03     0s
#    6   1.67892589e+03  1.71530739e+03  7.20e-02 7.11e-15  1.17e-03     0s
#    7   1.69888924e+03  1.70903117e+03  1.49e-02 7.11e-15  3.24e-04     0s
#    8   1.70535708e+03  1.70659003e+03  8.91e-04 1.07e-14  3.88e-05     0s
#    9   1.70594997e+03  1.70603512e+03  1.07e-04 1.07e-14  2.71e-06     0s
#   10   1.70602096e+03  1.70602401e+03  1.07e-06 1.07e-14  9.54e-08     0s
#   11   1.70602381e+03  1.70602381e+03  4.21e-10 1.07e-14  1.94e-11     0s
#
# Barrier solved model in 11 iterations and 0.06 seconds
# Optimal objective 1.70602381e+03
#
# Crossover log...
#
#      179 DPushes remaining with DInf 0.0000000e+00                 0s
#
# Solved with dual simplex
# Solved in 503 iterations and 0.06 seconds
# Optimal objective  1.706023810e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 201 rows, 16004 columns and 48010 nonzeros
# Model fingerprint: 0x095dba46
# Variable types: 0 continuous, 16004 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+02]
# Found heuristic solution: objective 618.0000000
# Presolve time: 0.04s
# Presolved: 201 rows, 16004 columns, 48010 nonzeros
# Variable types: 0 continuous, 16004 integer (16004 binary)
#
# Root relaxation: objective 1.706024e+03, 580 iterations, 0.04 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1706.02381    0   25  618.00000 1706.02381   176%     -    0s
# H    0     0                    1654.0000000 1706.02381  3.15%     -    0s
# H    0     0                    1698.0000000 1706.02381  0.47%     -    0s
# H    0     0                    1705.0000000 1706.02381  0.06%     -    0s
#      0     0 1706.02381    0   25 1705.00000 1706.02381  0.06%     -    0s
#
# Explored 1 nodes (580 simplex iterations) in 0.17 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 1705 1698 1654 618
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.705000000000e+03, best bound 1.705000000000e+03, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 201 rows, 15940 columns and 47819 nonzeros
# Model fingerprint: 0x73101f91
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+02]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve time: 0.02s
# Presolved: 201 rows, 15940 columns, 47819 nonzeros
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.614e+04
#  Factor NZ  : 2.030e+04 (roughly 7 MBytes of memory)
#  Factor Ops : 2.727e+06 (less than 1 second per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   3.18373670e+05  9.84831623e+02  3.87e+04 1.33e+01  1.56e+01     0s
#    1   3.36267880e+04  2.50211823e+03  3.48e+03 1.07e-14  1.36e+00     0s
#    2   2.68645875e+03  2.31317627e+03  1.60e+02 1.07e-14  9.27e-02     0s
#    3   1.43714064e+03  1.84020863e+03  7.39e+00 1.07e-14  1.70e-02     0s
#    4   1.56875541e+03  1.77577962e+03  1.23e+00 1.07e-14  7.17e-03     0s
#    5   1.63461703e+03  1.74464352e+03  5.52e-01 7.11e-15  3.74e-03     0s
#    6   1.68819488e+03  1.72814425e+03  1.29e-01 7.11e-15  1.32e-03     0s
#    7   1.70626769e+03  1.71720504e+03  2.15e-02 7.11e-15  3.53e-04     0s
#    8   1.71120735e+03  1.71377557e+03  3.99e-03 7.11e-15  8.24e-05     0s
#    9   1.71249294e+03  1.71290848e+03  3.12e-04 8.88e-15  1.31e-05     0s
#   10   1.71264253e+03  1.71265647e+03  9.34e-06 1.07e-14  4.40e-07     0s
#   11   1.71265382e+03  1.71265385e+03  2.87e-08 1.07e-14  1.11e-09     0s
#   12   1.71265385e+03  1.71265385e+03  8.07e-11 1.07e-14  1.11e-12     0s
#
# Barrier solved model in 12 iterations and 0.06 seconds
# Optimal objective 1.71265385e+03
#
# Crossover log...
#
#      172 DPushes remaining with DInf 0.0000000e+00                 0s
#        0 DPushes remaining with DInf 0.0000000e+00                 0s
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.3622437e-13      0s
#
#
# Solved with primal simplex
# Solved in 6346 iterations and 0.06 seconds
# Optimal objective  1.712653846e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 201 rows, 15940 columns and 47819 nonzeros
# Model fingerprint: 0x96d0ce4e
# Variable types: 0 continuous, 15940 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+02]
# Found heuristic solution: objective 607.0000000
# Presolve time: 0.04s
# Presolved: 201 rows, 15940 columns, 47819 nonzeros
# Variable types: 0 continuous, 15940 integer (15940 binary)
#
# Root relaxation: objective 1.712654e+03, 652 iterations, 0.05 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1712.65385    0   29  607.00000 1712.65385   182%     -    0s
# H    0     0                    1631.0000000 1712.65385  5.01%     -    0s
# H    0     0                    1704.0000000 1712.65385  0.51%     -    0s
# H    0     0                    1707.0000000 1712.65385  0.33%     -    0s
# H    0     0                    1710.0000000 1712.65385  0.16%     -    0s
# H    0     0                    1711.0000000 1712.65385  0.10%     -    0s
#
# Cutting planes:
#   Mod-K: 2
#
# Explored 1 nodes (652 simplex iterations) in 0.28 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 6: 1711 1710 1707 ... 607
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.711000000000e+03, best bound 1.711000000000e+03, gap 0.0000%
# iterationnumber 250
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 251 rows, 24916 columns and 74745 nonzeros
# Model fingerprint: 0xfcd43699
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+02]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve time: 0.02s
# Presolved: 251 rows, 24916 columns, 74745 nonzeros
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 2.517e+04
#  Factor NZ  : 3.163e+04 (roughly 10 MBytes of memory)
#  Factor Ops : 5.303e+06 (less than 1 second per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   4.96029316e+05  1.23158779e+03  6.04e+04 1.39e+01  1.62e+01     0s
#    1   4.81379223e+04  3.20216678e+03  4.93e+03 1.07e-14  1.26e+00     0s
#    2   3.20459014e+03  2.98759772e+03  1.78e+02 1.07e-14  7.18e-02     0s
#    3   1.86630185e+03  2.36148785e+03  1.49e+01 1.07e-14  1.57e-02     0s
#    4   2.02237006e+03  2.29585660e+03  1.54e+00 1.07e-14  6.03e-03     0s
#    5   2.10980848e+03  2.24161840e+03  6.19e-01 1.07e-14  2.85e-03     0s
#    6   2.17320837e+03  2.21728993e+03  1.57e-01 1.07e-14  9.36e-04     0s
#    7   2.19382975e+03  2.20893329e+03  3.61e-02 1.07e-14  3.14e-04     0s
#    8   2.20072440e+03  2.20393351e+03  6.01e-03 7.11e-15  6.62e-05     0s
#    9   2.20184015e+03  2.20260889e+03  1.96e-03 1.07e-14  1.60e-05     0s
#   10   2.20241511e+03  2.20243123e+03  2.78e-05 8.88e-15  3.32e-07     0s
#   11   2.20242857e+03  2.20242857e+03  2.91e-09 1.07e-14  5.58e-11     0s
#
# Barrier solved model in 11 iterations and 0.08 seconds
# Optimal objective 2.20242857e+03
#
# Crossover log...
#
#      215 DPushes remaining with DInf 0.0000000e+00                 0s
#        0 DPushes remaining with DInf 0.0000000e+00                 0s
#
#        1 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.1901591e-13      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      219    2.2024286e+03   0.000000e+00   0.000000e+00      0s
#
# Solved with barrier
# Solved in 219 iterations and 0.10 seconds
# Optimal objective  2.202428571e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 251 rows, 24916 columns and 74745 nonzeros
# Model fingerprint: 0x78ad750e
# Variable types: 0 continuous, 24916 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+02]
# Found heuristic solution: objective 807.0000000
# Presolve time: 0.07s
# Presolved: 251 rows, 24916 columns, 74745 nonzeros
# Variable types: 0 continuous, 24916 integer (24916 binary)
#
# Starting sifting (using dual simplex for sub-problems)...
#
#     Iter     Pivots    Primal Obj      Dual Obj        Time
#        0          0     infinity     -3.4635000e+04      0s
#        1        251   9.5609695e+09  -2.4252352e+04      0s
#        2        732   6.3214774e+09  -1.5783634e+04      0s
#        3       1117   4.7242322e+09  -1.3109153e+04      0s
#        4       1491   3.8087349e+09  -1.1644688e+04      0s
#        5       1861   3.0169876e+09  -1.0084658e+04      0s
#        6       2232   2.2617400e+09  -8.7013547e+03      0s
#        7       2601   1.3062436e+09  -7.7311571e+03      0s
#        8       2971   6.0837152e+08  -7.0528536e+03      0s
#        9       3369   1.4699852e+08  -6.4082605e+03      0s
#       10       3912  -1.4667500e+03  -4.3973664e+03      0s
#       11       4376  -1.4895333e+03  -3.9510747e+03      0s
#       12       4891  -1.6980000e+03  -3.1214407e+03      0s
#       13       5387  -1.9461538e+03  -2.6860633e+03      0s
#       14       5878  -2.1298000e+03  -2.4075582e+03      0s
#       15       6206  -2.1962727e+03  -2.2501404e+03      0s
#
# Sifting complete
#
#
# Root relaxation: objective 2.202429e+03, 6497 iterations, 0.09 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2202.42857    0   36  807.00000 2202.42857   173%     -    0s
# H    0     0                    2146.0000000 2202.42857  2.63%     -    0s
# H    0     0                    2199.0000000 2202.42857  0.16%     -    0s
# H    0     0                    2202.0000000 2202.42857  0.02%     -    0s
#      0     0 2202.42857    0   36 2202.00000 2202.42857  0.02%     -    0s
#
# Explored 1 nodes (6504 simplex iterations) in 0.30 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 2202 2199 2146 807
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.202000000000e+03, best bound 2.202000000000e+03, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 251 rows, 24907 columns and 74720 nonzeros
# Model fingerprint: 0xec5b8b86
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+02]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve time: 0.03s
# Presolved: 251 rows, 24907 columns, 74720 nonzeros
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 2.516e+04
#  Factor NZ  : 3.163e+04 (roughly 10 MBytes of memory)
#  Factor Ops : 5.303e+06 (less than 1 second per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   4.94239534e+05  1.22994628e+03  6.04e+04 1.36e+01  1.58e+01     0s
#    1   4.99939794e+04  3.15983007e+03  5.16e+03 1.07e-14  1.30e+00     0s
#    2   3.76825533e+03  2.96047337e+03  2.38e+02 1.07e-14  8.45e-02     0s
#    3   1.91502529e+03  2.36921020e+03  1.90e+01 1.07e-14  1.64e-02     0s
#    4   2.01120080e+03  2.26360987e+03  2.53e+00 1.07e-14  5.94e-03     0s
#    5   2.09521028e+03  2.24537420e+03  1.33e+00 1.07e-14  3.47e-03     0s
#    6   2.16521960e+03  2.21789919e+03  3.56e-01 8.88e-15  1.17e-03     0s
#    7   2.19610491e+03  2.21094367e+03  7.69e-02 1.07e-14  3.23e-04     0s
#    8   2.20357514e+03  2.20741185e+03  1.64e-02 1.07e-14  8.22e-05     0s
#    9   2.20546999e+03  2.20632455e+03  3.00e-03 1.07e-14  1.81e-05     0s
#   10   2.20599822e+03  2.20600100e+03  0.00e+00 1.07e-14  5.56e-08     0s
#   11   2.20600000e+03  2.20600000e+03  5.54e-11 1.07e-14  2.38e-13     0s
#
# Barrier solved model in 11 iterations and 0.08 seconds
# Optimal objective 2.20600000e+03
#
# Crossover log...
#
#      241 DPushes remaining with DInf 0.0000000e+00                 0s
#        0 DPushes remaining with DInf 0.0000000e+00                 0s
#
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.2634338e-13      0s
#
#
# Solved with primal simplex
# Solved in 7680 iterations and 0.09 seconds
# Optimal objective  2.206000000e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 251 rows, 24907 columns and 74720 nonzeros
# Model fingerprint: 0x046e0f7f
# Variable types: 0 continuous, 24907 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+02]
# Found heuristic solution: objective 705.0000000
# Presolve time: 0.07s
# Presolved: 251 rows, 24907 columns, 74720 nonzeros
# ...
# H    0     0                    6189.0000000 6192.71429  0.06%     -    4s
# H    0     0                    6190.0000000 6192.71429  0.04%     -    4s
# H    0     0                    6191.0000000 6192.71429  0.03%     -    4s
#
# Cutting planes:
#   Clique: 1
#   Mod-K: 1
#
# Explored 1 nodes (24601 simplex iterations) in 4.26 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 7: 6191 6190 6189 ... 1993
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.191000000000e+03, best bound 6.191000000000e+03, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 651 rows, 168868 columns and 506597 nonzeros
# Model fingerprint: 0x4c9251f7
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve time: 0.19s
# Presolved: 651 rows, 168868 columns, 506597 nonzeros
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.695e+05
#  Factor NZ  : 2.122e+05 (roughly 70 MBytes of memory)
#  Factor Ops : 9.218e+07 (less than 1 second per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   3.38033091e+06  3.23746489e+03  4.11e+05 1.68e+01  1.95e+01     0s
#    1   2.61627069e+05  9.33267165e+03  2.74e+04 1.42e-14  1.24e+00     0s
#    2   1.21093551e+04  8.99197886e+03  8.71e+02 1.07e-14  5.31e-02     0s
#    3   5.04799790e+03  7.20470338e+03  8.47e+01 1.42e-14  1.20e-02     0s
#    4   5.05765580e+03  6.60344598e+03  8.99e+00 1.07e-14  5.10e-03     0s
#    5   5.41163194e+03  6.38890078e+03  5.05e+00 1.07e-14  3.17e-03     0s
#    6   5.70076192e+03  6.28491739e+03  2.46e+00 1.07e-14  1.86e-03     0s
#    7   5.90361813e+03  6.27178953e+03  1.24e+00 8.88e-15  1.15e-03     0s
#    8   6.06002535e+03  6.23584247e+03  4.81e-01 1.07e-14  5.45e-04     0s
#    9   6.12549882e+03  6.20353266e+03  1.97e-01 1.07e-14  2.41e-04     1s
#   10   6.17260518e+03  6.18659583e+03  2.45e-02 1.07e-14  4.26e-05     1s
#   11   6.17873070e+03  6.18281446e+03  7.01e-03 1.07e-14  1.24e-05     1s
#   12   6.18142795e+03  6.18184949e+03  1.84e-04 1.07e-14  1.26e-06     1s
#   13   6.18156519e+03  6.18159624e+03  9.26e-06 1.07e-14  9.22e-08     1s
#   14   6.18157892e+03  6.18157897e+03  1.49e-10 1.07e-14  1.27e-10     1s
#
# Barrier solved model in 14 iterations and 0.62 seconds
# Optimal objective 6.18157892e+03
# Crossover log...
#
#      560 DPushes remaining with DInf 0.0000000e+00                 1s
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#        9 PPushes remaining with PInf 1.0397376e-06                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 4.9027449e-13      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      572    6.1815789e+03   0.000000e+00   0.000000e+00      1s
#
# Solved with barrier
# Solved in 572 iterations and 0.72 seconds
# Optimal objective  6.181578947e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 651 rows, 168868 columns and 506597 nonzeros
# Model fingerprint: 0x7c49a388
# Variable types: 0 continuous, 168868 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 1998.0000000
# Presolve time: 0.46s
# Presolved: 651 rows, 168868 columns, 506597 nonzeros
# Variable types: 0 continuous, 168868 integer (168868 binary)
#
# Starting sifting (using dual simplex for sub-problems)...
#
#     Iter     Pivots    Primal Obj      Dual Obj        Time
#        0          0     infinity     -2.2189400e+05      1s
#        1        651   6.5785291e+10  -1.6320881e+05      1s
#        2       1945   5.4362692e+10  -1.0627749e+05      1s
#        3       2950   4.7977709e+10  -9.3638224e+04      1s
#        4       3953   4.4477717e+10  -8.4625056e+04      1s
#        5       4998   4.1294852e+10  -8.0135982e+04      1s
#        6       6020   3.9128733e+10  -7.5443421e+04      1s
#        7       7004   3.7386987e+10  -7.0546605e+04      1s
#        8       8032   3.5661617e+10  -6.7170980e+04      1s
#        9       9012   3.3824247e+10  -6.4141441e+04      1s
#       10       9997   3.2346251e+10  -6.2309916e+04      1s
#       11      11014   3.1080756e+10  -6.0177206e+04      1s
#       12      12038   2.8670264e+10  -5.4753311e+04      1s
#       13      13029   2.5191274e+10  -4.9277176e+04      1s
#       14      14006   2.0802789e+10  -4.6191855e+04      1s
#       15      15008   1.7373302e+10  -4.1886474e+04      1s
#       16      16051   1.3383941e+10  -3.7649886e+04      1s
#       17      17047   9.4777059e+09  -3.3537790e+04      1s
#       18      17995   4.9415996e+09  -2.7998033e+04      1s
#       19      19308   1.0999745e+08  -2.6808427e+04      1s
#       20      20953  -5.3912059e+03  -2.0135377e+04      1s
#       21      22504  -5.4043824e+03  -1.4528661e+04      1s
#       22      24009  -5.5397143e+03  -1.0429864e+04      1s
#       23      25582  -5.9738000e+03  -8.2476865e+03      1s
#       24      26966  -6.1170952e+03  -6.8207985e+03      1s
#
# Sifting complete
#
#
# Root relaxation: objective 6.181579e+03, 28103 iterations, 0.75 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 6181.57895    0   46 1998.00000 6181.57895   209%     -    1s
# H    0     0                    6042.0000000 6181.57895  2.31%     -    1s
# H    0     0                    6169.0000000 6181.57895  0.20%     -    2s
# H    0     0                    6176.0000000 6181.57895  0.09%     -    2s
# H    0     0                    6177.0000000 6181.57895  0.07%     -    3s
# H    0     0                    6179.0000000 6181.57895  0.04%     -    3s
# H    0     0                    6180.0000000 6181.57895  0.03%     -    3s
#
# Cutting planes:
#   Mod-K: 12
#
# Explored 1 nodes (28104 simplex iterations) in 3.31 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 7: 6180 6179 6177 ... 1998
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.180000000000e+03, best bound 6.180000000000e+03, gap 0.0000%
# iterationnumber 700
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 701 rows, 195995 columns and 587981 nonzeros
# Model fingerprint: 0x4da08167
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve time: 0.23s
# Presolved: 701 rows, 195995 columns, 587981 nonzeros
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.967e+05
#  Factor NZ  : 2.461e+05 (roughly 80 MBytes of memory)
#  Factor Ops : 1.151e+08 (less than 1 second per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   3.92561397e+06  3.48110224e+03  4.79e+05 1.62e+01  1.89e+01     0s
#    1   3.15310382e+05  9.83548911e+03  3.30e+04 1.42e-14  1.24e+00     0s
#    2   1.87853492e+04  9.51549546e+03  1.54e+03 1.42e-14  6.94e-02     0s
#    3   6.53952857e+03  7.78315124e+03  2.09e+02 1.07e-14  1.49e-02     0s
#    4   5.47210132e+03  7.14551636e+03  2.61e+01 1.07e-14  5.62e-03     0s
#    5   5.74848081e+03  6.97577143e+03  1.69e+01 1.07e-14  3.96e-03     1s
#    6   5.98911662e+03  6.85423122e+03  9.60e+00 7.11e-15  2.66e-03     1s
#    7   6.20643249e+03  6.77353419e+03  5.50e+00 7.11e-15  1.70e-03     1s
#    8   6.41605958e+03  6.73440183e+03  2.68e+00 1.07e-14  9.35e-04     1s
#    9   6.58644108e+03  6.70572286e+03  8.42e-01 1.07e-14  3.43e-04     1s
#   10   6.66751598e+03  6.69248840e+03  1.32e-01 1.07e-14  6.96e-05     1s
#   11   6.68091799e+03  6.69024887e+03  3.73e-02 7.11e-15  2.55e-05     1s
#   12   6.68654691e+03  6.68763467e+03  2.50e-03 1.07e-14  2.88e-06     1s
#   13   6.68707715e+03  6.68714350e+03  2.10e-04 1.07e-14  1.79e-07     1s
#   14   6.68712490e+03  6.68712762e+03  3.86e-06 1.42e-14  7.12e-09     1s
#   15   6.68712726e+03  6.68712727e+03  1.26e-09 1.42e-14  2.69e-11     1s
#
# Barrier solved model in 15 iterations and 0.74 seconds
# Optimal objective 6.68712726e+03
#
# Crossover log...
#
#      622 DPushes remaining with DInf 1.2861338e-03                 1s
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#        5 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 3.8102854e-13      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      630    6.6871273e+03   0.000000e+00   0.000000e+00      1s
#
# Solved with barrier
# Solved in 630 iterations and 0.86 seconds
# Optimal objective  6.687127273e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 701 rows, 195995 columns and 587981 nonzeros
# Model fingerprint: 0x909d1b53
# Variable types: 0 continuous, 195995 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 2105.0000000
# Presolve time: 0.53s
# Presolved: 701 rows, 195995 columns, 587981 nonzeros
# Variable types: 0 continuous, 195995 integer (195995 binary)
#
# Starting sifting (using dual simplex for sub-problems)...
#
#     Iter     Pivots    Primal Obj      Dual Obj        Time
#        0          0     infinity     -2.7236600e+05      1s
#        1        701   8.1908992e+10  -2.0646383e+05      1s
#        2       2123   6.9552646e+10  -1.4266214e+05      1s
#        3       3215   6.3560160e+10  -1.2373721e+05      1s
#        4       4327   5.9246421e+10  -1.1411003e+05      1s
#        5       5433   5.6556053e+10  -1.0710348e+05      1s
#        6       6557   5.4836557e+10  -1.0180813e+05      1s
#        7       7651   5.2386063e+10  -9.6248019e+04      1s
#        8       8771   5.0460318e+10  -9.4341889e+04      1s
#        9       9895   4.9562572e+10  -9.1620146e+04      1s
#       10      10992   4.7694703e+10  -9.0432060e+04      1s
#       11      12131   4.7216579e+10  -8.7434265e+04      1s
#       12      13226   4.5790833e+10  -8.4375937e+04      1s
#       13      14343   4.3115090e+10  -7.8074500e+04      1s
#       14      15434   3.8256229e+10  -7.1549068e+04      1s
#       15      16513   3.3955619e+10  -6.4840309e+04      1s
#       16      17629   2.9977130e+10  -5.8936931e+04      1s
#       17      18710   2.3428779e+10  -5.3001974e+04      1s
#       18      19815   1.8508671e+10  -4.9063223e+04      1s
#       19      20914   1.4368187e+10  -4.3892580e+04      1s
#       20      22011   9.5823310e+09  -3.8865698e+04      1s
#       21      23073   4.4709767e+09  -3.4042397e+04      1s
#       22      24485   1.7199692e+08  -3.1342384e+04      1s
#       23      26351  -5.7920714e+03  -2.2913807e+04      1s
#       24      28121  -5.8341250e+03  -1.5944759e+04      1s
#       25      29704  -6.0349000e+03  -1.2423348e+04      1s
#       26      31362  -6.3900000e+03  -9.1659591e+03      2s
#       27      32916  -6.6129091e+03  -7.4168106e+03      2s
#       28      34124  -6.6869565e+03  -6.7063380e+03      2s
#
# Sifting complete
#
#
# Root relaxation: objective 6.687127e+03, 34862 iterations, 1.03 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 6687.12727    0   61 2105.00000 6687.12727   218%     -    1s
# H    0     0                    6524.0000000 6687.12727  2.50%     -    2s
# H    0     0                    6675.0000000 6687.12727  0.18%     -    2s
# H    0     0                    6677.0000000 6687.12727  0.15%     -    2s
# H    0     0                    6684.0000000 6687.12727  0.05%     -    3s
# H    0     0                    6687.0000000 6687.12727  0.00%     -    3s
#
# Cutting planes:
#   Mod-K: 26
#
# Explored 1 nodes (34866 simplex iterations) in 3.20 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 6: 6687 6684 6677 ... 2105
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.687000000000e+03, best bound 6.687000000000e+03, gap 0.0000%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-f1ff60a15b5d> in <module>
#      23         model.optimize()
#      24         sols_dense[n].append(model.objval)
# ---> 25         LDbin = bounds_LD_bin(g, 3*n)
#      26         LDs_bin_dense[n].append(LDbin)
#
# <ipython-input-14-a34df4e3a32c> in bounds_LD_bin(G, B)
#      90
#      91 def bounds_LD_bin(G, B):
# ---> 92     ans = minimize_LD_bin(G,B)
#      93     return (math.ceil(ans[-1]), math.floor(ans[1][1]))
#      94
#
# <ipython-input-14-a34df4e3a32c> in minimize_LD_bin(G, B)
#      82     def f(x):
#      83         return budgetedMatchingPenalized(G, B, x)
# ---> 84     x = binary_search(G, B, f, 0, maxLam, 0.0001)
#      85     return (x[0], f(x[0]), x[1])
#      86
#
# <ipython-input-14-a34df4e3a32c> in binary_search(G, B, f, a, b, eps)
#      57     while (b - a) > eps:
#      58         c = (a + b)/2
# ---> 59         fc = f(c)
#      60         sol_fc = sum(G[e[0]][e[1]]['realWeight'] for e in fc[2])
#      61         if (not(LB) or sol_fc > LB) and fc[0] <= B:
#
# <ipython-input-14-a34df4e3a32c> in f(x)
#      81     maxLam = maxWeight/max(1, minCost)
#      82     def f(x):
# ---> 83         return budgetedMatchingPenalized(G, B, x)
#      84     x = binary_search(G, B, f, 0, maxLam, 0.0001)
#      85     return (x[0], f(x[0]), x[1])
#
# <ipython-input-2-aa95e185ce6d> in budgetedMatchingPenalized(G, B, lamb)
#     287 def budgetedMatchingPenalized(G, B, lamb = 1):
#     288     graph = penalizedGraph(G, lamb)
# --> 289     matching = nx.max_weight_matching(graph)
#     290     cost = sum(G[e[0]][e[1]]["weight"] for e in matching) if matching != False else False
#     291     weight = lamb * B + sum(graph[e[0]][e[1]]["weight"] for e in matching) if matching != False else False
#
# ~\Anaconda3\lib\site-packages\networkx\algorithms\matching.py in max_weight_matching(G, maxcardinality, weight)
#     829                         # keep track of the least-slack non-allowable edge to
#     830                         # a different S-blossom.
# --> 831                         if bestedge.get(bv) is None or kslack < slack(*bestedge[bv]):
#     832                             bestedge[bv] = (v, w)
#     833                     elif label.get(w) is None:
#
# ~\Anaconda3\lib\site-packages\networkx\algorithms\matching.py in slack(v, w)
#     357     # Return 2 * slack of edge (v, w) (does not work inside blossoms).
#     358     def slack(v, w):
# --> 359         return dualvar[v] + dualvar[w] - 2 * G[v][w].get(weight, 1)
#     360
#     361     # Assign label t to the top-level blossom containing vertex w,
#
# ~\Anaconda3\lib\site-packages\networkx\classes\graph.py in __getitem__(self, n)
#     463         AtlasView({1: {}})
#     464         """
# --> 465         return self.adj[n]
#     466
#     467     def add_node(self, node_for_adding, **attr):
#
# ~\Anaconda3\lib\site-packages\networkx\classes\graph.py in adj(self)
#     354         For directed graphs, `G.adj` holds outgoing (successor) info.
#     355         """
# --> 356         return AdjacencyView(self._adj)
#     357
#     358     @property
#
# KeyboardInterrupt:

# %%
LRs_dense
# Out:
# {100: [(661, 809), (837, 837), (675, 811), (728, 780), (628, 795)],
#  150: [(949, 1256), (1190, 1257), (1034, 1268), (1052, 1248), (1171, 1281)],
#  200: [(1603, 1730), (1573, 1748), (1430, 1765), (1504, 1706), (1488, 1712)],
#  250: [(1914, 2202), (2122, 2206), (2059, 2209), (1909, 2206), (2019, 2205)],
#  300: [(2487, 2691), (2144, 2655), (2221, 2676), (2476, 2662), (2418, 2691)],
#  350: [(2726, 3186), (2896, 3196), (2697, 3162), (2777, 3161), (2783, 3190)],
#  400: [(3341, 3646), (3551, 3666), (3334, 3683), (3704, 3704), (3346, 3680)],
#  450: [(3817, 4138), (3643, 4180), (3703, 4160), (3870, 4204), (3744, 4138)],
#  500: [(4687, 4687), (4248, 4630), (4123, 4650), (4409, 4708), (4464, 4691)],
#  550: [(4608, 5207), (4818, 5175), (4690, 5150), (4722, 5198), (4631, 5159)],
#  600: [(5253, 5691), (5650, 5650), (5120, 5673), (5195, 5716), (5473, 5653)],
#  650: [(6068, 6213), (5501, 6153), (5631, 6150), (5805, 6192), (5769, 6181)],
#  700: [(6140, 6687)]}

# %%
LDs_bin_dense
# Out:
# {100: [(808, 809), (837, 837), (801, 811), (771, 780), (787, 795)],
#  150: [(1244, 1255), (1251, 1257), (1253, 1268), (1246, 1248), (1264, 1281)],
#  200: [(1724, 1730), (1738, 1748), (1749, 1765), (1698, 1705), (1710, 1712)],
#  250: [(2199, 2202), (2201, 2206), (2199, 2209), (2171, 2206), (2197, 2205)],
#  300: [(2684, 2691), (2647, 2655), (2663, 2675), (2654, 2662), (2681, 2690)],
#  350: [(3172, 3186), (3179, 3196), (3148, 3162), (3146, 3160), (3184, 3189)],
#  400: [(3641, 3646), (3661, 3666), (3676, 3681), (3704, 3704), (3674, 3680)],
#  450: [(4116, 4138), (4154, 4180), (4152, 4160), (4200, 4204), (4119, 4138)],
#  500: [(4687, 4687), (4607, 4630), (4629, 4650), (4691, 4708), (4679, 4691)],
#  550: [(5187, 5206), (5145, 5175), (5150, 5150), (5189, 5198), (5146, 5159)],
#  600: [(5678, 5691), (5650, 5650), (5667, 5673), (5712, 5716), (5645, 5653)],
#  650: [(6205, 6213), (6145, 6153), (6150, 6150), (6185, 6191), (6179, 6181)],
#  700: []}

# %%
sols_dense
# Out:
# {100: [809.0, 837.0, 810.0, 779.0, 794.0],
#  150: [1255.0, 1256.0, 1267.0, 1248.0, 1279.0],
#  200: [1730.0, 1748.0, 1764.0, 1705.0, 1711.0],
#  250: [2202.0, 2205.0, 2209.0, 2206.0, 2205.0],
#  300: [2691.0, 2655.000000042445, 2675.0, 2662.0, 2690.0],
#  350: [3186.0, 3196.0, 3162.0, 3160.0, 3189.0],
#  400: [3646.0, 3666.0, 3681.0, 3704.0, 3679.0],
#  450: [4138.0, 4180.0, 4160.0, 4204.0, 4138.0],
#  500: [4687.0, 4630.0, 4650.0, 4708.0, 4691.0],
#  550: [5206.0, 5175.0, 5150.0, 5198.0, 5159.0],
#  600: [5691.0, 5650.0, 5673.0, 5716.0, 5653.0],
#  650: [6213.0, 6152.0, 6150.0, 6191.0, 6180.0],
#  700: [6687.0]}

# %%
'''
Test of budgeted matching approximation on sparse bipartite graphs
LRs = Linear Relaxation bounds
LDs_bin = Lagrangian relaxation bounds
sols = Exact solutions
'''
import time
# Sparse Graphs
LRs = {}
LDs_bin = {}
sols = {}
for n in range(100, 1001, 50):
    print("iterationnumber", n)
    running_time_bruteforce = 0
    running_time_gurobi = 0
    LRs[n] = []
    LDs_bin[n] = []
    sols[n] = []
    for i in range(5):
        g = generateRandomUnrestrictedBipartite(n, 2/n, 10, 10)
        LR = bounds_LR(g, 2*n)
        LRs[n].append(LR)
        model = graph_to_gurobi(g, 2*n)
        model.optimize()
        sols[n].append(model.objval)
# Out:
# iterationnumber 100
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 101 rows, 55 columns and 165 nonzeros
# Model fingerprint: 0x63aebe7e
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [4e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Presolve removed 68 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 33 rows, 55 columns, 126 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.0300000e+02   2.925000e+01   0.000000e+00      0s
#       15    2.8355556e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 15 iterations and 0.01 seconds
# Optimal objective  2.835555556e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 101 rows, 55 columns and 165 nonzeros
# Model fingerprint: 0x0b8439a2
# Variable types: 0 continuous, 55 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [4e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 221.0000000
# Presolve removed 83 rows and 11 columns
# Presolve time: 0.00s
# Presolved: 18 rows, 44 columns, 81 nonzeros
# Found heuristic solution: objective 266.0000000
# Variable types: 0 continuous, 44 integer (44 binary)
#
# Root relaxation: objective 2.835556e+02, 11 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  283.55556    0    1  266.00000  283.55556  6.60%     -    0s
# H    0     0                     280.0000000  283.55556  1.27%     -    0s
# H    0     0                     281.0000000  283.55556  0.91%     -    0s
#      0     0  283.55556    0    1  281.00000  283.55556  0.91%     -    0s
#      0     0  283.55556    0    1  281.00000  283.55556  0.91%     -    0s
# H    0     0                     282.0000000  283.55556  0.55%     -    0s
#      0     0  282.00000    0    2  282.00000  282.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#
# Explored 1 nodes (15 simplex iterations) in 0.02 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 282 281 280 ... 221
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.820000000000e+02, best bound 2.820000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 101 rows, 48 columns and 144 nonzeros
# Model fingerprint: 0x1ae5fdc1
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Presolve removed 71 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 30 rows, 48 columns, 116 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.1100000e+02   1.975000e+01   0.000000e+00      0s
#        8    2.5553846e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 8 iterations and 0.01 seconds
# Optimal objective  2.555384615e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 101 rows, 48 columns and 144 nonzeros
# Model fingerprint: 0xd14177e8
# Variable types: 0 continuous, 48 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 166.0000000
# Presolve removed 82 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 19 rows, 39 columns, 81 nonzeros
# Found heuristic solution: objective 237.0000000
# Variable types: 0 continuous, 39 integer (39 binary)
#
# Root relaxation: objective 2.555385e+02, 5 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  255.53846    0    3  237.00000  255.53846  7.82%     -    0s
# H    0     0                     245.0000000  255.53846  4.30%     -    0s
# H    0     0                     251.0000000  255.53846  1.81%     -    0s
# H    0     0                     254.0000000  255.53846  0.61%     -    0s
#
# Cutting planes:
#   Cover: 1
#
# Explored 1 nodes (5 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 254 251 245 ... 166
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.540000000000e+02, best bound 2.540000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 101 rows, 46 columns and 138 nonzeros
# Model fingerprint: 0xd965206e
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [6e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Presolve removed 82 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 19 rows, 44 columns, 87 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.0800000e+02   1.537500e+01   0.000000e+00      0s
# Extra simplex iterations after uncrush: 2
#        5    2.5957143e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 5 iterations and 0.00 seconds
# Optimal objective  2.595714286e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 101 rows, 46 columns and 138 nonzeros
# Model fingerprint: 0xb9bde9d5
# Variable types: 0 continuous, 46 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [6e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 192.0000000
# Presolve removed 90 rows and 12 columns
# Presolve time: 0.00s
# Presolved: 11 rows, 34 columns, 55 nonzeros
# Found heuristic solution: objective 231.0000000
# Variable types: 0 continuous, 34 integer (34 binary)
#
# Root relaxation: objective 2.595714e+02, 3 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  259.57143    0    1  231.00000  259.57143  12.4%     -    0s
# H    0     0                     255.0000000  259.57143  1.79%     -    0s
# H    0     0                     257.0000000  259.57143  1.00%     -    0s
# H    0     0                     258.0000000  259.40000  0.54%     -    0s
#
# Cutting planes:
#   RLT: 1
#
# Explored 1 nodes (3 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 258 257 255 ... 192
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.580000000000e+02, best bound 2.580000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 101 rows, 53 columns and 159 nonzeros
# Model fingerprint: 0xbbd62d20
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [4e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Presolve removed 70 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 31 rows, 51 columns, 123 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.2800000e+02   2.012500e+01   0.000000e+00      0s
#        5    2.6407692e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 5 iterations and 0.01 seconds
# Optimal objective  2.640769231e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 101 rows, 53 columns and 159 nonzeros
# Model fingerprint: 0x3d0bd42d
# Variable types: 0 continuous, 53 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [4e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 170.0000000
# Presolve removed 77 rows and 8 columns
# Presolve time: 0.00s
# Presolved: 24 rows, 45 columns, 98 nonzeros
# Found heuristic solution: objective 237.0000000
# Variable types: 0 continuous, 45 integer (45 binary)
#
# Root relaxation: objective 2.640769e+02, 4 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  264.07692    0    1  237.00000  264.07692  11.4%     -    0s
# H    0     0                     264.0000000  264.07692  0.03%     -    0s
#      0     0  264.07692    0    1  264.00000  264.07692  0.03%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 264 237 170
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.640000000000e+02, best bound 2.640000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 101 rows, 46 columns and 138 nonzeros
# Model fingerprint: 0xfb872912
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Presolve removed 76 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 25 rows, 46 columns, 96 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.1300000e+02   1.575000e+01   0.000000e+00      0s
#        7    2.6553846e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 7 iterations and 0.00 seconds
# Optimal objective  2.655384615e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 101 rows, 46 columns and 138 nonzeros
# Model fingerprint: 0xaa575a3e
# Variable types: 0 continuous, 46 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 194.0000000
# Presolve removed 87 rows and 10 columns
# Presolve time: 0.00s
# Presolved: 14 rows, 36 columns, 62 nonzeros
# Found heuristic solution: objective 241.0000000
# Variable types: 0 continuous, 36 integer (35 binary)
#
# Root relaxation: objective 2.655385e+02, 6 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  265.53846    0    1  241.00000  265.53846  10.2%     -    0s
# H    0     0                     262.0000000  265.53846  1.35%     -    0s
# H    0     0                     264.0000000  265.53846  0.58%     -    0s
# H    0     0                     265.0000000  265.53846  0.20%     -    0s
#      0     0  265.53846    0    1  265.00000  265.53846  0.20%     -    0s
#
# Explored 1 nodes (6 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 265 264 262 ... 194
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.650000000000e+02, best bound 2.650000000000e+02, gap 0.0000%
# iterationnumber 150
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 151 rows, 70 columns and 210 nonzeros
# Model fingerprint: 0x8cff979c
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [4e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+02]
# Presolve removed 115 rows and 4 columns
# Presolve time: 0.00s
# Presolved: 36 rows, 66 columns, 147 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.7100000e+02   2.975000e+01   0.000000e+00      0s
# Extra simplex iterations after uncrush: 1
#       12    3.7254545e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 12 iterations and 0.01 seconds
# Optimal objective  3.725454545e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 151 rows, 70 columns and 210 nonzeros
# Model fingerprint: 0xb996a90b
# Variable types: 0 continuous, 70 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [4e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+02]
# Found heuristic solution: objective 308.0000000
# Presolve removed 133 rows and 23 columns
# Presolve time: 0.00s
# Presolved: 18 rows, 47 columns, 84 nonzeros
# Found heuristic solution: objective 352.0000000
# Variable types: 0 continuous, 47 integer (43 binary)
#
# Root relaxation: objective 3.725455e+02, 6 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  372.54545    0    3  352.00000  372.54545  5.84%     -    0s
# H    0     0                     368.0000000  372.54545  1.24%     -    0s
# H    0     0                     372.0000000  372.54545  0.15%     -    0s
#      0     0  372.54545    0    3  372.00000  372.54545  0.15%     -    0s
#
# Explored 1 nodes (6 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 372 368 352 308
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.720000000000e+02, best bound 3.720000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 151 rows, 64 columns and 192 nonzeros
# Model fingerprint: 0x38744dbb
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [4e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+02]
# Presolve removed 116 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 35 rows, 63 columns, 140 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.2600000e+02   1.775000e+01   0.000000e+00      0s
#        9    3.7900000e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 9 iterations and 0.01 seconds
# Optimal objective  3.790000000e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 151 rows, 64 columns and 192 nonzeros
# Model fingerprint: 0x1f0d7553
# Variable types: 0 continuous, 64 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [4e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+02]
# Found heuristic solution: objective 299.0000000
# Presolve removed 126 rows and 13 columns
# Presolve time: 0.00s
# Presolved: 25 rows, 51 columns, 102 nonzeros
# Found heuristic solution: objective 355.0000000
# Variable types: 0 continuous, 51 integer (50 binary)
#
# Root relaxation: objective 3.790000e+02, 8 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  379.00000    0    5  355.00000  379.00000  6.76%     -    0s
# H    0     0                     378.0000000  379.00000  0.26%     -    0s
#
# Explored 1 nodes (8 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 378 355 299
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.780000000000e+02, best bound 3.780000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 151 rows, 73 columns and 219 nonzeros
# Model fingerprint: 0x0685026f
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+02]
# Presolve removed 115 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 36 rows, 70 columns, 155 nonzeros
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.2600000e+02   1.537500e+01   0.000000e+00      0s
#        6    3.7207692e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 6 iterations and 0.00 seconds
# Optimal objective  3.720769231e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 151 rows, 73 columns and 219 nonzeros
# Model fingerprint: 0x3438e375
# Variable types: 0 continuous, 73 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+02]
# Found heuristic solution: objective 293.0000000
# Presolve removed 127 rows and 17 columns
# Presolve time: 0.00s
# Presolved: 24 rows, 56 columns, 106 nonzeros
# Found heuristic solution: objective 358.0000000
# Variable types: 0 continuous, 56 integer (55 binary)
#
# Root relaxation: objective 3.720769e+02, 6 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  372.07692    0    1  358.00000  372.07692  3.93%     -    0s
# H    0     0                     371.0000000  372.07692  0.29%     -    0s
# H    0     0                     372.0000000  372.07692  0.02%     -    0s
#      0     0  372.07692    0    1  372.00000  372.07692  0.02%     -    0s
#
# Explored 1 nodes (6 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 372 371 358 293
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.720000000000e+02, best bound 3.720000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 151 rows, 70 columns and 210 nonzeros
# Model fingerprint: 0xb2080081
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+02]
# Presolve removed 122 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 29 rows, 69 columns, 139 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.9000000e+02   3.625000e+01   0.000000e+00      0s
#       12    3.5675000e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 12 iterations and 0.01 seconds
# Optimal objective  3.567500000e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 151 rows, 70 columns and 210 nonzeros
# Model fingerprint: 0xf9f0b53a
# Variable types: 0 continuous, 70 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+02]
# Found heuristic solution: objective 266.0000000
# Presolve removed 133 rows and 16 columns
# Presolve time: 0.00s
# Presolved: 18 rows, 54 columns, 92 nonzeros
# Found heuristic solution: objective 330.0000000
# Variable types: 0 continuous, 54 integer (52 binary)
#
# Root relaxation: objective 3.567500e+02, 9 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  356.75000    0    1  330.00000  356.75000  8.11%     -    0s
# H    0     0                     353.0000000  356.75000  1.06%     -    0s
# H    0     0                     356.0000000  356.75000  0.21%     -    0s
#      0     0  356.75000    0    1  356.00000  356.75000  0.21%     -    0s
#
# Explored 1 nodes (9 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 356 353 330 266
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.560000000000e+02, best bound 3.560000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 151 rows, 87 columns and 261 nonzeros
# Model fingerprint: 0x588a6ae2
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [4e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+02]
# Presolve removed 100 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 51 rows, 87 columns, 210 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.3800000e+02   3.800000e+01   0.000000e+00      0s
#       17    4.2138462e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 17 iterations and 0.01 seconds
# Optimal objective  4.213846154e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 151 rows, 87 columns and 261 nonzeros
# Model fingerprint: 0xb255e6f1
# Variable types: 0 continuous, 87 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [4e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+02]
# Found heuristic solution: objective 302.0000000
# Presolve removed 121 rows and 22 columns
# Presolve time: 0.00s
# Presolved: 30 rows, 65 columns, 134 nonzeros
# Found heuristic solution: objective 382.0000000
# Variable types: 0 continuous, 65 integer (63 binary)
#
# Root relaxation: objective 4.213846e+02, 11 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  421.38462    0    1  382.00000  421.38462  10.3%     -    0s
# H    0     0                     420.0000000  421.38462  0.33%     -    0s
#      0     0  421.38462    0    1  420.00000  421.38462  0.33%     -    0s
#
# Explored 1 nodes (11 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 420 382 302
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.200000000000e+02, best bound 4.200000000000e+02, gap 0.0000%
# iterationnumber 200
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 201 rows, 113 columns and 339 nonzeros
# Model fingerprint: 0x5dcb568b
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [2e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+02]
# Presolve removed 143 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 58 rows, 108 columns, 253 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.7500000e+02   2.568750e+01   0.000000e+00      0s
# Extra simplex iterations after uncrush: 1
#       28    5.2400000e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 28 iterations and 0.01 seconds
# Optimal objective  5.240000000e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 201 rows, 113 columns and 339 nonzeros
# Model fingerprint: 0x42df8ae0
# Variable types: 0 continuous, 113 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [2e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+02]
# Found heuristic solution: objective 415.0000000
# Presolve removed 162 rows and 28 columns
# Presolve time: 0.00s
# Presolved: 39 rows, 85 columns, 178 nonzeros
# Found heuristic solution: objective 487.0000000
# Variable types: 0 continuous, 85 integer (80 binary)
#
# Root relaxation: objective 5.240000e+02, 21 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     524.0000000  524.00000  0.00%     -    0s
#
# Explored 0 nodes (21 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 524 487 415
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.240000000000e+02, best bound 5.240000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 201 rows, 98 columns and 294 nonzeros
# Model fingerprint: 0x80b237e2
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+02]
# Presolve removed 149 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 52 rows, 96 columns, 214 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.9100000e+02   4.525000e+01   0.000000e+00      0s
# Extra simplex iterations after uncrush: 1
#       13    5.3085714e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 13 iterations and 0.01 seconds
# Optimal objective  5.308571429e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 201 rows, 98 columns and 294 nonzeros
# Model fingerprint: 0x4183bc42
# Variable types: 0 continuous, 98 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+02]
# Found heuristic solution: objective 379.0000000
# Presolve removed 170 rows and 21 columns
# Presolve time: 0.00s
# Presolved: 31 rows, 77 columns, 143 nonzeros
# Found heuristic solution: objective 491.0000000
# Variable types: 0 continuous, 77 integer (76 binary)
#
# Root relaxation: objective 5.308571e+02, 9 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  530.85714    0    1  491.00000  530.85714  8.12%     -    0s
# H    0     0                     528.0000000  530.85714  0.54%     -    0s
# H    0     0                     530.0000000  530.85714  0.16%     -    0s
#      0     0  530.85714    0    1  530.00000  530.85714  0.16%     -    0s
#
# Explored 1 nodes (9 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 530 528 491 379
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.300000000000e+02, best bound 5.300000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 201 rows, 105 columns and 315 nonzeros
# Model fingerprint: 0x18eed0e4
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+02]
# Presolve removed 147 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 54 rows, 102 columns, 232 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    7.1800000e+02   2.975000e+01   0.000000e+00      0s
# Extra simplex iterations after uncrush: 1
#       25    5.4783333e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 25 iterations and 0.01 seconds
# Optimal objective  5.478333333e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 201 rows, 105 columns and 315 nonzeros
# Model fingerprint: 0xcc3b56d1
# Variable types: 0 continuous, 105 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+02]
# Found heuristic solution: objective 404.0000000
# Presolve removed 167 rows and 24 columns
# Presolve time: 0.00s
# Presolved: 34 rows, 81 columns, 154 nonzeros
# Found heuristic solution: objective 520.0000000
# Variable types: 0 continuous, 81 integer (79 binary)
#
# Root relaxation: objective 5.478333e+02, 22 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  547.83333    0    1  520.00000  547.83333  5.35%     -    0s
# H    0     0                     545.0000000  547.83333  0.52%     -    0s
# H    0     0                     546.0000000  547.83333  0.34%     -    0s
#      0     0  547.60000    0    3  546.00000  547.60000  0.29%     -    0s
#
# Cutting planes:
#   StrongCG: 1
#
# Explored 1 nodes (23 simplex iterations) in 0.02 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 546 545 520 404
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.460000000000e+02, best bound 5.460000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 201 rows, 99 columns and 297 nonzeros
# Model fingerprint: 0x75cb0703
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+02]
# Presolve removed 144 rows and 4 columns
# Presolve time: 0.00s
# Presolved: 57 rows, 95 columns, 225 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.8800000e+02   3.843750e+01   0.000000e+00      0s
#       19    5.2910000e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 19 iterations and 0.01 seconds
# Optimal objective  5.291000000e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 201 rows, 99 columns and 297 nonzeros
# Model fingerprint: 0x01233d25
# Variable types: 0 continuous, 99 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+02]
# Found heuristic solution: objective 425.0000000
# Presolve removed 154 rows and 13 columns
# Presolve time: 0.00s
# Presolved: 47 rows, 86 columns, 188 nonzeros
# Found heuristic solution: objective 485.0000000
# Variable types: 0 continuous, 86 integer (84 binary)
#
# Root relaxation: objective 5.291000e+02, 20 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  529.10000    0    3  485.00000  529.10000  9.09%     -    0s
# H    0     0                     527.0000000  529.10000  0.40%     -    0s
# H    0     0                     528.0000000  529.10000  0.21%     -    0s
#      0     0  529.10000    0    3  528.00000  529.10000  0.21%     -    0s
#
# Explored 1 nodes (20 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 528 527 485 425
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.280000000000e+02, best bound 5.280000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 201 rows, 89 columns and 267 nonzeros
# Model fingerprint: 0xb6ea8a27
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+02]
# Presolve removed 158 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 43 rows, 84 columns, 179 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.9800000e+02   2.875000e+01   0.000000e+00      0s
#       15    5.0238462e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 15 iterations and 0.01 seconds
# Optimal objective  5.023846154e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 201 rows, 89 columns and 267 nonzeros
# Model fingerprint: 0x9b684227
# Variable types: 0 continuous, 89 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+02]
# Found heuristic solution: objective 406.0000000
# Presolve removed 179 rows and 24 columns
# Presolve time: 0.00s
# Presolved: 22 rows, 65 columns, 110 nonzeros
# Found heuristic solution: objective 494.0000000
# Variable types: 0 continuous, 65 integer (64 binary)
#
# Root relaxation: objective 5.023846e+02, 14 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  502.38462    0    1  494.00000  502.38462  1.70%     -    0s
# H    0     0                     502.0000000  502.38462  0.08%     -    0s
#      0     0  502.38462    0    1  502.00000  502.38462  0.08%     -    0s
#
# Explored 1 nodes (14 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 502 494 406
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.020000000000e+02, best bound 5.020000000000e+02, gap 0.0000%
# iterationnumber 250
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 251 rows, 122 columns and 366 nonzeros
# Model fingerprint: 0xbabb97f0
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Presolve removed 193 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 58 rows, 116 columns, 257 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    7.9800000e+02   4.168750e+01   0.000000e+00      0s
# Extra simplex iterations after uncrush: 2
#       26    6.1542857e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 26 iterations and 0.01 seconds
# Optimal objective  6.154285714e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 251 rows, 122 columns and 366 nonzeros
# Model fingerprint: 0x39b7656c
# Variable types: 0 continuous, 122 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 484.0000000
# Presolve removed 221 rows and 38 columns
# Presolve time: 0.00s
# Presolved: 30 rows, 84 columns, 148 nonzeros
# Found heuristic solution: objective 589.0000000
# Variable types: 0 continuous, 84 integer (81 binary)
#
# Root relaxation: objective 6.154286e+02, 14 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  615.42857    0    4  589.00000  615.42857  4.49%     -    0s
# H    0     0                     614.0000000  615.42857  0.23%     -    0s
# H    0     0                     615.0000000  615.42857  0.07%     -    0s
#      0     0  615.42857    0    4  615.00000  615.42857  0.07%     -    0s
#
# Explored 1 nodes (14 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 615 614 589 484
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.150000000000e+02, best bound 6.150000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 251 rows, 116 columns and 348 nonzeros
# Model fingerprint: 0xc9d0b10c
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [2e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Presolve removed 193 rows and 7 columns
# Presolve time: 0.00s
# Presolved: 58 rows, 109 columns, 244 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    7.5100000e+02   2.631250e+01   0.000000e+00      0s
# Extra simplex iterations after uncrush: 2
#       27    6.3530769e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 27 iterations and 0.01 seconds
# Optimal objective  6.353076923e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 251 rows, 116 columns and 348 nonzeros
# Model fingerprint: 0x3bd77629
# Variable types: 0 continuous, 116 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [2e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 500.0000000
# Presolve removed 219 rows and 30 columns
# Presolve time: 0.00s
# Presolved: 32 rows, 86 columns, 154 nonzeros
# Found heuristic solution: objective 599.0000000
# Variable types: 0 continuous, 86 integer (82 binary)
#
# Root relaxation: objective 6.353077e+02, 13 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  635.30769    0    1  599.00000  635.30769  6.06%     -    0s
# H    0     0                     630.0000000  635.30769  0.84%     -    0s
# H    0     0                     632.0000000  635.30769  0.52%     -    0s
# H    0     0                     634.0000000  635.30769  0.21%     -    0s
#      0     0  635.30769    0    1  634.00000  635.30769  0.21%     -    0s
#
# Explored 1 nodes (13 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 634 632 630 ... 500
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.340000000000e+02, best bound 6.340000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 251 rows, 143 columns and 429 nonzeros
# Model fingerprint: 0xe2e9fa2c
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Presolve removed 174 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 77 rows, 141 columns, 331 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.2600000e+02   6.687500e+01   0.000000e+00      0s
#       40    6.7492308e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 40 iterations and 0.01 seconds
# Optimal objective  6.749230769e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 251 rows, 143 columns and 429 nonzeros
# Model fingerprint: 0x47642d04
# Variable types: 0 continuous, 143 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 489.0000000
# Presolve removed 203 rows and 34 columns
# Presolve time: 0.00s
# Presolved: 48 rows, 109 columns, 220 nonzeros
# Found heuristic solution: objective 611.0000000
# Variable types: 0 continuous, 109 integer (105 binary)
#
# Root relaxation: objective 6.749231e+02, 24 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  674.92308    0    1  611.00000  674.92308  10.5%     -    0s
# H    0     0                     671.0000000  674.92308  0.58%     -    0s
# H    0     0                     673.0000000  674.92308  0.29%     -    0s
# H    0     0                     674.0000000  674.92308  0.14%     -    0s
#      0     0  674.92308    0    1  674.00000  674.92308  0.14%     -    0s
#
# Explored 1 nodes (24 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 674 673 671 ... 489
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.740000000000e+02, best bound 6.740000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 251 rows, 136 columns and 408 nonzeros
# Model fingerprint: 0x2175d5fe
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Presolve removed 179 rows and 7 columns
# Presolve time: 0.00s
# Presolved: 72 rows, 129 columns, 298 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    8.6300000e+02   4.206250e+01   0.000000e+00      0s
#       25    6.3328571e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 25 iterations and 0.01 seconds
# Optimal objective  6.332857143e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 251 rows, 136 columns and 408 nonzeros
# Model fingerprint: 0x91dea6db
# Variable types: 0 continuous, 136 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 488.0000000
# Presolve removed 197 rows and 26 columns
# Presolve time: 0.00s
# Presolved: 54 rows, 110 columns, 231 nonzeros
# Found heuristic solution: objective 584.0000000
# Variable types: 0 continuous, 110 integer (105 binary)
#
# Root relaxation: objective 6.332857e+02, 19 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  633.28571    0    3  584.00000  633.28571  8.44%     -    0s
# H    0     0                     629.0000000  633.28571  0.68%     -    0s
# H    0     0                     630.0000000  633.28571  0.52%     -    0s
# H    0     0                     631.0000000  633.28571  0.36%     -    0s
# H    0     0                     633.0000000  633.28571  0.05%     -    0s
#
# Cutting planes:
#   MIR: 1
#
# Explored 1 nodes (19 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 6: 633 631 630 ... 488
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.330000000000e+02, best bound 6.330000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 251 rows, 95 columns and 285 nonzeros
# Model fingerprint: 0x5bc5b010
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Presolve removed 205 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 46 rows, 89 columns, 196 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.1500000e+02   1.000000e+01   0.000000e+00      0s
# Extra simplex iterations after uncrush: 1
#        9    5.7980000e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 9 iterations and 0.01 seconds
# Optimal objective  5.798000000e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 251 rows, 95 columns and 285 nonzeros
# Model fingerprint: 0x7f59babc
# Variable types: 0 continuous, 95 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 512.0000000
# Presolve removed 228 rows and 27 columns
# Presolve time: 0.00s
# Presolved: 23 rows, 68 columns, 114 nonzeros
# Found heuristic solution: objective 571.0000000
# Variable types: 0 continuous, 68 integer (66 binary)
#
# Root relaxation: objective 5.798000e+02, 8 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  579.80000    0    1  571.00000  579.80000  1.54%     -    0s
# H    0     0                     573.0000000  579.80000  1.19%     -    0s
# H    0     0                     577.0000000  579.80000  0.49%     -    0s
# H    0     0                     578.0000000  579.80000  0.31%     -    0s
#
# Explored 1 nodes (8 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 578 577 573 ... 512
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.780000000000e+02, best bound 5.780000000000e+02, gap 0.0000%
# iterationnumber 300
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 301 rows, 153 columns and 459 nonzeros
# Model fingerprint: 0x152fe203
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [4e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+02]
# Presolve removed 217 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 84 rows, 150 columns, 346 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.5700000e+02   3.637500e+01   0.000000e+00      0s
# Extra simplex iterations after uncrush: 1
#       21    7.6675000e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 21 iterations and 0.01 seconds
# Optimal objective  7.667500000e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 301 rows, 153 columns and 459 nonzeros
# Model fingerprint: 0xb4a09f5c
# Variable types: 0 continuous, 153 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [4e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+02]
# Found heuristic solution: objective 533.0000000
# Presolve removed 249 rows and 36 columns
# Presolve time: 0.00s
# Presolved: 52 rows, 117 columns, 228 nonzeros
# Found heuristic solution: objective 711.0000000
# Variable types: 0 continuous, 117 integer (114 binary)
#
# Root relaxation: objective 7.667500e+02, 14 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  766.75000    0    1  711.00000  766.75000  7.84%     -    0s
# H    0     0                     764.0000000  766.75000  0.36%     -    0s
# H    0     0                     766.0000000  766.75000  0.10%     -    0s
#      0     0  766.75000    0    1  766.00000  766.75000  0.10%     -    0s
#
# Explored 1 nodes (14 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 766 764 711 533
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.660000000000e+02, best bound 7.660000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 301 rows, 139 columns and 417 nonzeros
# Model fingerprint: 0x5406712d
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [2e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+02]
# Presolve removed 227 rows and 4 columns
# Presolve time: 0.00s
# ...
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 951 rows, 464 columns and 1392 nonzeros
# Model fingerprint: 0xc56eb216
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [2e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 703 rows and 24 columns
# Presolve time: 0.00s
# Presolved: 248 rows, 440 columns, 1028 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.0060000e+03   1.004375e+02   0.000000e+00      0s
#      104    2.4667143e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 104 iterations and 0.01 seconds
# Optimal objective  2.466714286e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 951 rows, 464 columns and 1392 nonzeros
# Model fingerprint: 0x827c32c5
# Variable types: 0 continuous, 464 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [2e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 1958.0000000
# Presolve removed 790 rows and 140 columns
# Presolve time: 0.00s
# Presolved: 161 rows, 324 columns, 679 nonzeros
# Found heuristic solution: objective 2258.0000000
# Variable types: 0 continuous, 324 integer (292 binary)
# Root relaxation: objective 2.466714e+03, 75 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2466.71429    0    1 2258.00000 2466.71429  9.24%     -    0s
# H    0     0                    2458.0000000 2466.71429  0.35%     -    0s
# H    0     0                    2466.0000000 2466.71429  0.03%     -    0s
#      0     0 2466.71429    0    1 2466.00000 2466.71429  0.03%     -    0s
#
# Explored 1 nodes (75 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 2466 2458 2258 1958
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.466000000000e+03, best bound 2.466000000000e+03, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 951 rows, 467 columns and 1401 nonzeros
# Model fingerprint: 0x404dfdd7
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [2e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 711 rows and 30 columns
# Presolve time: 0.00s
# Presolved: 240 rows, 437 columns, 998 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.0290000e+03   1.285625e+02   0.000000e+00      0s
#       99    2.4216364e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 99 iterations and 0.01 seconds
# Optimal objective  2.421636364e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 951 rows, 467 columns and 1401 nonzeros
# Model fingerprint: 0xcb68b098
# Variable types: 0 continuous, 467 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [2e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 1821.0000000
# Presolve removed 792 rows and 126 columns
# Presolve time: 0.00s
# Presolved: 159 rows, 341 columns, 689 nonzeros
# Found heuristic solution: objective 2238.0000000
# Variable types: 0 continuous, 341 integer (315 binary)
#
# Root relaxation: objective 2.421636e+03, 80 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2421.63636    0    1 2238.00000 2421.63636  8.21%     -    0s
# H    0     0                    2421.0000000 2421.63636  0.03%     -    0s
#      0     0 2421.63636    0    1 2421.00000 2421.63636  0.03%     -    0s
#
# Explored 1 nodes (80 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 2421 2238 1821
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.421000000000e+03, best bound 2.421000000000e+03, gap 0.0000%
# iterationnumber 1000
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1001 rows, 514 columns and 1542 nonzeros
# Model fingerprint: 0x421ddd84
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 728 rows and 17 columns
# Presolve time: 0.00s
# Presolved: 273 rows, 497 columns, 1155 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.2970000e+03   1.433750e+02   0.000000e+00      0s
# Extra simplex iterations after uncrush: 1
#      106    2.6545000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 106 iterations and 0.01 seconds
# Optimal objective  2.654500000e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1001 rows, 514 columns and 1542 nonzeros
# Model fingerprint: 0x94830757
# Variable types: 0 continuous, 514 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 1917.0000000
# Presolve removed 826 rows and 155 columns
# Presolve time: 0.00s
# Presolved: 175 rows, 359 columns, 747 nonzeros
# Found heuristic solution: objective 2407.0000000
# Variable types: 0 continuous, 359 integer (326 binary)
#
# Root relaxation: objective 2.654500e+03, 79 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2654.50000    0    1 2407.00000 2654.50000  10.3%     -    0s
# H    0     0                    2643.0000000 2654.50000  0.44%     -    0s
# H    0     0                    2650.0000000 2654.50000  0.17%     -    0s
# H    0     0                    2653.0000000 2654.50000  0.06%     -    0s
# H    0     0                    2654.0000000 2654.50000  0.02%     -    0s
#      0     0 2654.50000    0    1 2654.00000 2654.50000  0.02%     -    0s
#
# Explored 1 nodes (79 simplex iterations) in 0.02 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 6: 2654 2653 2650 ... 1917
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.654000000000e+03, best bound 2.654000000000e+03, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1001 rows, 488 columns and 1464 nonzeros
# Model fingerprint: 0xb71db9d4
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [2e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 759 rows and 34 columns
# Presolve time: 0.00s
# Presolved: 242 rows, 454 columns, 1033 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.2110000e+03   1.384375e+02   0.000000e+00      0s
# Extra simplex iterations after uncrush: 1
#       83    2.5336923e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 83 iterations and 0.01 seconds
# Optimal objective  2.533692308e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1001 rows, 488 columns and 1464 nonzeros
# Model fingerprint: 0x3b79e757
# Variable types: 0 continuous, 488 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [2e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 1958.0000000
# Presolve removed 834 rows and 153 columns
# Presolve time: 0.00s
# Presolved: 167 rows, 335 columns, 702 nonzeros
# Found heuristic solution: objective 2339.0000000
# Variable types: 0 continuous, 335 integer (297 binary)
#
# Root relaxation: objective 2.533692e+03, 54 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2533.69231    0    1 2339.00000 2533.69231  8.32%     -    0s
# H    0     0                    2525.0000000 2533.69231  0.34%     -    0s
# H    0     0                    2533.0000000 2533.69231  0.03%     -    0s
#      0     0 2533.69231    0    1 2533.00000 2533.69231  0.03%     -    0s
#
# Explored 1 nodes (54 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 2533 2525 2339 1958
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.533000000000e+03, best bound 2.533000000000e+03, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1001 rows, 474 columns and 1422 nonzeros
# Model fingerprint: 0x44ae41a1
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 767 rows and 32 columns
# Presolve time: 0.00s
# Presolved: 234 rows, 442 columns, 1001 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.0870000e+03   1.325625e+02   0.000000e+00      0s
# Extra simplex iterations after uncrush: 2
#       91    2.5413333e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 91 iterations and 0.01 seconds
# Optimal objective  2.541333333e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1001 rows, 474 columns and 1422 nonzeros
# Model fingerprint: 0xa383e9ba
# Variable types: 0 continuous, 474 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 2032.0000000
# Presolve removed 854 rows and 153 columns
# Presolve time: 0.00s
# Presolved: 147 rows, 321 columns, 642 nonzeros
# Found heuristic solution: objective 2378.0000000
# Variable types: 0 continuous, 321 integer (287 binary)
#
# Root relaxation: objective 2.541333e+03, 51 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2541.33333    0    1 2378.00000 2541.33333  6.87%     -    0s
# H    0     0                    2541.0000000 2541.33333  0.01%     -    0s
#      0     0 2541.33333    0    1 2541.00000 2541.33333  0.01%     -    0s
#
# Explored 1 nodes (51 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 2541 2378 2032
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.541000000000e+03, best bound 2.541000000000e+03, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1001 rows, 528 columns and 1584 nonzeros
# Model fingerprint: 0xb3d158bc
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 718 rows and 21 columns
# Presolve time: 0.00s
# Presolved: 283 rows, 507 columns, 1195 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.2650000e+03   1.351250e+02   0.000000e+00      0s
#       89    2.6022308e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 89 iterations and 0.01 seconds
# Optimal objective  2.602230769e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1001 rows, 528 columns and 1584 nonzeros
# Model fingerprint: 0xcccd5713
# Variable types: 0 continuous, 528 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 1941.0000000
# Presolve removed 814 rows and 158 columns
# Presolve time: 0.00s
# Presolved: 187 rows, 370 columns, 790 nonzeros
# Found heuristic solution: objective 2332.0000000
# Variable types: 0 continuous, 370 integer (336 binary)
#
# Root relaxation: objective 2.602231e+03, 72 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2602.23077    0    3 2332.00000 2602.23077  11.6%     -    0s
# H    0     0                    2601.0000000 2602.23077  0.05%     -    0s
# H    0     0                    2602.0000000 2602.23077  0.01%     -    0s
#      0     0 2602.23077    0    3 2602.00000 2602.23077  0.01%     -    0s
#
# Explored 1 nodes (72 simplex iterations) in 0.02 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 2602 2601 2332 1941
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.602000000000e+03, best bound 2.602000000000e+03, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1001 rows, 489 columns and 1467 nonzeros
# Model fingerprint: 0x66e692e9
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 759 rows and 37 columns
# Presolve time: 0.00s
# Presolved: 242 rows, 452 columns, 1028 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.1910000e+03   1.228750e+02   0.000000e+00      0s
# Extra simplex iterations after uncrush: 6
#       73    2.6327500e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 73 iterations and 0.01 seconds
# Optimal objective  2.632750000e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1001 rows, 489 columns and 1467 nonzeros
# Model fingerprint: 0xdcf3d37d
# Variable types: 0 continuous, 489 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 1998.0000000
# Presolve removed 846 rows and 166 columns
# Presolve time: 0.00s
# Presolved: 155 rows, 323 columns, 663 nonzeros
# Found heuristic solution: objective 2436.0000000
# Variable types: 0 continuous, 323 integer (286 binary)
#
# Root relaxation: objective 2.632750e+03, 63 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2632.75000    0    1 2436.00000 2632.75000  8.08%     -    0s
# H    0     0                    2631.0000000 2632.75000  0.07%     -    0s
# H    0     0                    2632.0000000 2632.75000  0.03%     -    0s
#      0     0 2632.75000    0    1 2632.00000 2632.75000  0.03%     -    0s
#
# Explored 1 nodes (63 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 2632 2631 2436 1998
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.632000000000e+03, best bound 2.632000000000e+03, gap 0.0000%

# %%
sols
# Out:
# {100: [282.0, 254.0, 258.0, 264.0, 265.0],
#  150: [372.0, 378.0, 372.0, 356.0, 420.0],
#  200: [524.0, 530.0, 546.0, 528.0, 502.0],
#  250: [615.0, 634.0, 674.0, 633.0, 578.0],
#  300: [766.0, 745.0, 833.0, 817.0, 825.0],
#  350: [1027.0, 899.0, 949.0, 900.0, 914.0],
#  400: [1015.0, 1068.0, 1016.0, 1068.0, 988.0],
#  450: [1192.0, 1198.0, 1165.0, 1182.0, 1131.0],
#  500: [1270.0, 1232.0, 1279.0, 1331.0, 1242.0],
#  550: [1472.0, 1443.0, 1449.0, 1508.0, 1476.0],
#  600: [1570.0, 1649.0, 1513.0, 1542.0, 1548.0],
#  650: [1680.0, 1769.0, 1703.0, 1799.0, 1712.0],
#  700: [1807.0, 1819.0, 1801.0, 1835.0, 1763.0],
#  750: [1940.0, 1931.0, 1999.0, 1833.0, 1994.0],
#  800: [2136.0, 1987.0, 2004.0, 2040.0, 2101.0],
#  850: [2319.0, 2262.0, 2211.0, 2046.0, 2119.0],
#  900: [2302.0, 2389.0, 2303.0, 2333.0, 2418.0],
#  950: [2527.0, 2496.0, 2513.0, 2466.0, 2421.0],
#  1000: [2654.0, 2533.0, 2541.0, 2602.0, 2632.0]}

# %%
LRs
# Out:
# {100: [(280, 283), (240, 255), (251, 259), (261, 264), (260, 265)],
#  150: [(351, 372), (354, 379), (369, 372), (353, 356), (420, 421)],
#  200: [(524, 524), (523, 530), (542, 547), (514, 529), (501, 502)],
#  250: [(595, 615), (627, 635), (668, 674), (612, 633), (578, 579)],
#  300: [(757, 766), (732, 745), (818, 834), (812, 818), (806, 825)],
#  350: [(1024, 1027), (891, 899), (943, 949), (894, 900), (912, 914)],
#  400: [(1011, 1015), (1066, 1069), (1012, 1016), (1063, 1068), (977, 988)],
#  450: [(1182, 1192), (1197, 1198), (1163, 1165), (1180, 1182), (1130, 1131)],
#  500: [(1264, 1270), (1229, 1232), (1272, 1279), (1323, 1331), (1239, 1242)],
#  550: [(1436, 1472), (1439, 1443), (1444, 1449), (1499, 1508), (1476, 1476)],
#  600: [(1561, 1571), (1633, 1649), (1509, 1513), (1542, 1542), (1542, 1548)],
#  650: [(1678, 1680), (1769, 1769), (1699, 1703), (1792, 1799), (1707, 1712)],
#  700: [(1803, 1807), (1819, 1819), (1795, 1801), (1834, 1835), (1763, 1763)],
#  750: [(1938, 1940), (1931, 1931), (1982, 1999), (1812, 1833), (1985, 1994)],
#  800: [(2133, 2136), (1986, 1987), (1986, 2004), (2036, 2040), (2094, 2101)],
#  850: [(2304, 2319), (2257, 2262), (2209, 2211), (2043, 2046), (2111, 2119)],
#  900: [(2297, 2302), (2388, 2389), (2302, 2303), (2326, 2333), (2416, 2418)],
#  950: [(2525, 2527), (2496, 2496), (2491, 2513), (2461, 2466), (2418, 2421)],
#  1000: [(2649, 2654), (2533, 2533), (2525, 2541), (2581, 2602), (2624, 2632)]}

# %%
'''
Test of budgeted matching approximation on dense bipartite graphs
LRs = Linear Relaxation bounds
LDs_bin = Lagrangian relaxation bounds
sols = Exact solutions
'''
import time
# dense Graphs
LRs = {}
LDs_bin = {}
sols = {}
for n in range(100, 1001, 50):
    print("iterationnumber", n)
    running_time_bruteforce = 0
    running_time_gurobi = 0
    LRs[n] = []
    LDs_bin[n] = []
    sols[n] = []
    for i in range(5):
        g = generateRandomUnrestrictedBipartite(n, 0.8, 10, 10)
        LR = bounds_LR(g, 2*n)
        LRs[n].append(LR)
        model = graph_to_gurobi(g, 2*n)
        model.optimize()
        sols[n].append(model.objval)
# Out:
# iterationnumber 100
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 101 rows, 1964 columns and 5892 nonzeros
# Model fingerprint: 0x451ba38f
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Presolve time: 0.00s
# Presolved: 101 rows, 1964 columns, 5892 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    8.9000000e+02   6.550000e+01   0.000000e+00      0s
#      130    5.5400000e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 130 iterations and 0.01 seconds
# Optimal objective  5.540000000e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 101 rows, 1964 columns and 5892 nonzeros
# Model fingerprint: 0xeab8a4ce
# Variable types: 0 continuous, 1964 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 222.0000000
# Presolve time: 0.01s
# Presolved: 101 rows, 1964 columns, 5892 nonzeros
# Variable types: 0 continuous, 1964 integer (1964 binary)
#
# Root relaxation: objective 5.540000e+02, 127 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  554.00000    0    7  222.00000  554.00000   150%     -    0s
# H    0     0                     547.0000000  554.00000  1.28%     -    0s
# H    0     0                     552.0000000  554.00000  0.36%     -    0s
# H    0     0                     553.0000000  554.00000  0.18%     -    0s
#      0     0  554.00000    0    4  553.00000  554.00000  0.18%     -    0s
#
# Cutting planes:
#   GUB cover: 1
#
# Explored 1 nodes (129 simplex iterations) in 0.04 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 553 552 547 222
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.530000000000e+02, best bound 5.530000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 101 rows, 1966 columns and 5898 nonzeros
# Model fingerprint: 0x1b3beae9
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Presolve time: 0.00s
# Presolved: 101 rows, 1966 columns, 5898 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    8.6900000e+02   5.862500e+01   0.000000e+00      0s
#      101    5.5800000e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 101 iterations and 0.01 seconds
# Optimal objective  5.580000000e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 101 rows, 1966 columns and 5898 nonzeros
# Model fingerprint: 0xcc3701c3
# Variable types: 0 continuous, 1966 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 217.0000000
# Presolve time: 0.01s
# Presolved: 101 rows, 1966 columns, 5898 nonzeros
# Variable types: 0 continuous, 1966 integer (1966 binary)
#
# Root relaxation: objective 5.580000e+02, 96 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  558.00000    0    1  217.00000  558.00000   157%     -    0s
# H    0     0                     556.0000000  558.00000  0.36%     -    0s
# H    0     0                     557.0000000  558.00000  0.18%     -    0s
# H    0     0                     558.0000000  558.00000  0.00%     -    0s
#      0     0  558.00000    0    1  558.00000  558.00000  0.00%     -    0s
#
# Explored 1 nodes (96 simplex iterations) in 0.03 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 558 557 556 217
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.580000000000e+02, best bound 5.580000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 101 rows, 2022 columns and 6066 nonzeros
# Model fingerprint: 0x9564ed2e
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [2e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Presolve time: 0.00s
# Presolved: 101 rows, 2022 columns, 6066 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.0600000e+02   5.525000e+01   0.000000e+00      0s
#      120    5.9100000e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 120 iterations and 0.01 seconds
# Optimal objective  5.910000000e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 101 rows, 2022 columns and 6066 nonzeros
# Model fingerprint: 0x0a00944c
# Variable types: 0 continuous, 2022 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [2e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 222.0000000
# Presolve time: 0.01s
# Presolved: 101 rows, 2022 columns, 6066 nonzeros
# Variable types: 0 continuous, 2022 integer (2022 binary)
#
# Root relaxation: objective 5.910000e+02, 109 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  591.00000    0    1  222.00000  591.00000   166%     -    0s
# H    0     0                     586.0000000  591.00000  0.85%     -    0s
# H    0     0                     591.0000000  591.00000  0.00%     -    0s
#      0     0  591.00000    0    1  591.00000  591.00000  0.00%     -    0s
#
# Explored 1 nodes (109 simplex iterations) in 0.02 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 591 586 222
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.910000000000e+02, best bound 5.910000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 101 rows, 2017 columns and 6051 nonzeros
# Model fingerprint: 0x7b0c01f2
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [2e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Presolve time: 0.00s
# Presolved: 101 rows, 2017 columns, 6051 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    8.6900000e+02   5.825000e+01   0.000000e+00      0s
#      119    5.6500000e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 119 iterations and 0.01 seconds
# Optimal objective  5.650000000e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 101 rows, 2017 columns and 6051 nonzeros
# Model fingerprint: 0x357f6ed7
# Variable types: 0 continuous, 2017 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [2e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 227.0000000
# Presolve time: 0.01s
# Presolved: 101 rows, 2017 columns, 6051 nonzeros
# Variable types: 0 continuous, 2017 integer (2017 binary)
#
# Root relaxation: objective 5.650000e+02, 106 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  565.00000    0    1  227.00000  565.00000   149%     -    0s
# H    0     0                     565.0000000  565.00000  0.00%     -    0s
#      0     0  565.00000    0    1  565.00000  565.00000  0.00%     -    0s
#
# Explored 1 nodes (106 simplex iterations) in 0.02 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 565 227
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.650000000000e+02, best bound 5.650000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 101 rows, 2027 columns and 6081 nonzeros
# Model fingerprint: 0xc328c9aa
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [2e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Presolve time: 0.00s
# Presolved: 101 rows, 2027 columns, 6081 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    8.7400000e+02   5.925000e+01   0.000000e+00      0s
#      120    5.6800000e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 120 iterations and 0.01 seconds
# Optimal objective  5.680000000e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 101 rows, 2027 columns and 6081 nonzeros
# Model fingerprint: 0x7ceb8513
# Variable types: 0 continuous, 2027 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [2e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 203.0000000
# Presolve time: 0.01s
# Presolved: 101 rows, 2027 columns, 6081 nonzeros
# Variable types: 0 continuous, 2027 integer (2027 binary)
#
# Root relaxation: objective 5.680000e+02, 109 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     568.0000000  568.00000  0.00%     -    0s
#
# Explored 0 nodes (109 simplex iterations) in 0.02 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 568 203
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.680000000000e+02, best bound 5.680000000000e+02, gap 0.0000%
# iterationnumber 150
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 151 rows, 4534 columns and 13602 nonzeros
# Model fingerprint: 0x6cdc0349
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+02]
# Presolve time: 0.00s
# Presolved: 151 rows, 4534 columns, 13602 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.3820000e+03   8.475000e+01   0.000000e+00      0s
#      216    9.6575000e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 216 iterations and 0.01 seconds
# Optimal objective  9.657500000e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 151 rows, 4534 columns and 13602 nonzeros
# Model fingerprint: 0x91efb653
# Variable types: 0 continuous, 4534 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+02]
# Found heuristic solution: objective 332.0000000
# Presolve time: 0.01s
# Presolved: 151 rows, 4534 columns, 13602 nonzeros
# Variable types: 0 continuous, 4534 integer (4534 binary)
#
# Root relaxation: objective 9.657500e+02, 175 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  965.75000    0    1  332.00000  965.75000   191%     -    0s
# H    0     0                     963.0000000  965.75000  0.29%     -    0s
# H    0     0                     965.0000000  965.75000  0.08%     -    0s
#      0     0  965.75000    0    1  965.00000  965.75000  0.08%     -    0s
#
# Explored 1 nodes (175 simplex iterations) in 0.05 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 965 963 332
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.650000000000e+02, best bound 9.650000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 151 rows, 4461 columns and 13382 nonzeros
# Model fingerprint: 0x40793e2d
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+02]
# Presolve time: 0.00s
# Presolved: 151 rows, 4461 columns, 13382 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.3410000e+03   8.337500e+01   0.000000e+00      0s
#      171    9.6700000e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 171 iterations and 0.01 seconds
# Optimal objective  9.670000000e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 151 rows, 4461 columns and 13382 nonzeros
# Model fingerprint: 0x926b17d0
# Variable types: 0 continuous, 4461 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+02]
# Found heuristic solution: objective 279.0000000
# Presolve time: 0.01s
# Presolved: 151 rows, 4461 columns, 13382 nonzeros
# Variable types: 0 continuous, 4461 integer (4461 binary)
#
# Root relaxation: objective 9.670000e+02, 161 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     967.0000000  967.00000  0.00%     -    0s
#
# Explored 0 nodes (161 simplex iterations) in 0.04 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 967 279
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.670000000000e+02, best bound 9.670000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 151 rows, 4484 columns and 13452 nonzeros
# Model fingerprint: 0x54f7b03a
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [2e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+02]
# Presolve time: 0.00s
# Presolved: 151 rows, 4484 columns, 13452 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.3410000e+03   8.375000e+01   0.000000e+00      0s
#      172    9.3000000e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 172 iterations and 0.01 seconds
# Optimal objective  9.300000000e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 151 rows, 4484 columns and 13452 nonzeros
# Model fingerprint: 0xdf624960
# Variable types: 0 continuous, 4484 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [2e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+02]
# Found heuristic solution: objective 276.0000000
# Presolve time: 0.01s
# Presolved: 151 rows, 4484 columns, 13452 nonzeros
# Variable types: 0 continuous, 4484 integer (4484 binary)
#
# Root relaxation: objective 9.300000e+02, 186 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     930.0000000  930.00000  0.00%     -    0s
#
# Explored 0 nodes (186 simplex iterations) in 0.04 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 930 276
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.300000000000e+02, best bound 9.300000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 151 rows, 4551 columns and 13652 nonzeros
# Model fingerprint: 0x11a0739a
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+02]
# Presolve time: 0.01s
# Presolved: 151 rows, 4551 columns, 13652 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.3440000e+03   8.512500e+01   0.000000e+00      0s
#      184    9.7812500e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 184 iterations and 0.01 seconds
# Optimal objective  9.781250000e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 151 rows, 4551 columns and 13652 nonzeros
# Model fingerprint: 0xff4c852c
# Variable types: 0 continuous, 4551 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+02]
# Found heuristic solution: objective 280.0000000
# Presolve time: 0.01s
# Presolved: 151 rows, 4551 columns, 13652 nonzeros
# Variable types: 0 continuous, 4551 integer (4551 binary)
#
# Root relaxation: objective 9.781250e+02, 180 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  978.12500    0    7  280.00000  978.12500   249%     -    0s
# H    0     0                     972.0000000  978.12500  0.63%     -    0s
# H    0     0                     977.0000000  978.12500  0.12%     -    0s
#      0     0  978.12500    0    7  977.00000  978.12500  0.12%     -    0s
#
# Explored 1 nodes (180 simplex iterations) in 0.06 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 977 972 280
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.770000000000e+02, best bound 9.770000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 151 rows, 4478 columns and 13434 nonzeros
# Model fingerprint: 0xcb10f4c1
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+02]
# Presolve time: 0.00s
# Presolved: 151 rows, 4478 columns, 13434 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.3410000e+03   7.712500e+01   0.000000e+00      0s
#      164    9.2900000e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 164 iterations and 0.01 seconds
# Optimal objective  9.290000000e+02
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 151 rows, 4478 columns and 13434 nonzeros
# Model fingerprint: 0x8d787eef
# Variable types: 0 continuous, 4478 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+02]
# Found heuristic solution: objective 323.0000000
# Presolve time: 0.01s
# Presolved: 151 rows, 4478 columns, 13434 nonzeros
# Variable types: 0 continuous, 4478 integer (4478 binary)
#
# Root relaxation: objective 9.290000e+02, 287 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  929.00000    0    5  323.00000  929.00000   188%     -    0s
# H    0     0                     921.0000000  929.00000  0.87%     -    0s
# H    0     0                     927.0000000  929.00000  0.22%     -    0s
# H    0     0                     929.0000000  929.00000  0.00%     -    0s
#      0     0  929.00000    0    5  929.00000  929.00000  0.00%     -    0s
#
# Explored 1 nodes (287 simplex iterations) in 0.05 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 929 927 921 323
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.290000000000e+02, best bound 9.290000000000e+02, gap 0.0000%
# iterationnumber 200
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 201 rows, 8067 columns and 24201 nonzeros
# Model fingerprint: 0x21508396
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+02]
# Presolve time: 0.01s
# Presolved: 201 rows, 8067 columns, 24201 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.8560000e+03   1.246250e+02   0.000000e+00      0s
#      283    1.3130000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 283 iterations and 0.02 seconds
# Optimal objective  1.313000000e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 201 rows, 8067 columns and 24201 nonzeros
# Model fingerprint: 0x729e02d0
# Variable types: 0 continuous, 8067 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+02]
# Found heuristic solution: objective 422.0000000
# Presolve time: 0.02s
# Presolved: 201 rows, 8067 columns, 24201 nonzeros
# Variable types: 0 continuous, 8067 integer (8067 binary)
#
# Root relaxation: objective 1.313000e+03, 258 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1313.00000    0    1  422.00000 1313.00000   211%     -    0s
# H    0     0                    1312.0000000 1313.00000  0.08%     -    0s
# H    0     0                    1313.0000000 1313.00000  0.00%     -    0s
#      0     0 1313.00000    0    1 1313.00000 1313.00000  0.00%     -    0s
#
# Explored 1 nodes (258 simplex iterations) in 0.06 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 1313 1312 422
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.313000000000e+03, best bound 1.313000000000e+03, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 201 rows, 7984 columns and 23952 nonzeros
# Model fingerprint: 0x1a9e8641
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+02]
# Presolve time: 0.01s
# Presolved: 201 rows, 7984 columns, 23952 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.8710000e+03   1.136250e+02   0.000000e+00      0s
#      275    1.3297500e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 275 iterations and 0.02 seconds
# Optimal objective  1.329750000e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 201 rows, 7984 columns and 23952 nonzeros
# Model fingerprint: 0x1205a80c
# Variable types: 0 continuous, 7984 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+02]
# Found heuristic solution: objective 415.0000000
# Presolve time: 0.02s
# Presolved: 201 rows, 7984 columns, 23952 nonzeros
# Variable types: 0 continuous, 7984 integer (7984 binary)
#
# Root relaxation: objective 1.329750e+03, 280 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1329.75000    0    1  415.00000 1329.75000   220%     -    0s
# H    0     0                    1328.0000000 1329.75000  0.13%     -    0s
# H    0     0                    1329.0000000 1329.75000  0.06%     -    0s
#      0     0 1329.75000    0    1 1329.00000 1329.75000  0.06%     -    0s
#
# Explored 1 nodes (280 simplex iterations) in 0.06 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 1329 1328 415
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.329000000000e+03, best bound 1.329000000000e+03, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 201 rows, 8056 columns and 24168 nonzeros
# Model fingerprint: 0x13187632
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+02]
# Presolve time: 0.01s
# Presolved: 201 rows, 8056 columns, 24168 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.8350000e+03   1.161250e+02   0.000000e+00      0s
#      270    1.3250000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 270 iterations and 0.02 seconds
# Optimal objective  1.325000000e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 201 rows, 8056 columns and 24168 nonzeros
# Model fingerprint: 0x5858bd46
# Variable types: 0 continuous, 8056 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+02]
# Found heuristic solution: objective 458.0000000
# Presolve time: 0.02s
# Presolved: 201 rows, 8056 columns, 24168 nonzeros
# Variable types: 0 continuous, 8056 integer (8056 binary)
#
# Root relaxation: objective 1.325000e+03, 299 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1325.00000    0    3  458.00000 1325.00000   189%     -    0s
# H    0     0                    1318.0000000 1325.00000  0.53%     -    0s
# H    0     0                    1322.0000000 1325.00000  0.23%     -    0s
# H    0     0                    1325.0000000 1325.00000  0.00%     -    0s
#      0     0 1325.00000    0    3 1325.00000 1325.00000  0.00%     -    0s
#
# Explored 1 nodes (322 simplex iterations) in 0.08 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 1325 1322 1318 458
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.325000000000e+03, best bound 1.325000000000e+03, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 201 rows, 7979 columns and 23937 nonzeros
# Model fingerprint: 0xf6efd5f3
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+02]
# Presolve time: 0.01s
# Presolved: 201 rows, 7979 columns, 23937 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.8270000e+03   1.088750e+02   0.000000e+00      0s
#      236    1.2970000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 236 iterations and 0.01 seconds
# Optimal objective  1.297000000e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 201 rows, 7979 columns and 23937 nonzeros
# Model fingerprint: 0x1ff68a08
# Variable types: 0 continuous, 7979 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+02]
# Found heuristic solution: objective 396.0000000
# Presolve time: 0.02s
# Presolved: 201 rows, 7979 columns, 23937 nonzeros
# Variable types: 0 continuous, 7979 integer (7979 binary)
#
# Root relaxation: objective 1.297000e+03, 239 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1297.00000    0    8  396.00000 1297.00000   228%     -    0s
# H    0     0                    1291.0000000 1297.00000  0.46%     -    0s
# H    0     0                    1295.0000000 1297.00000  0.15%     -    0s
# H    0     0                    1297.0000000 1297.00000  0.00%     -    0s
#      0     0 1297.00000    0    8 1297.00000 1297.00000  0.00%     -    0s
#
# Explored 1 nodes (239 simplex iterations) in 0.07 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 1297 1295 1291 396
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.297000000000e+03, best bound 1.297000000000e+03, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 201 rows, 7964 columns and 23892 nonzeros
# Model fingerprint: 0xf947657a
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+02]
# Presolve time: 0.01s
# Presolved: 201 rows, 7964 columns, 23892 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.8290000e+03   1.065000e+02   0.000000e+00      0s
#      261    1.2538571e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 261 iterations and 0.01 seconds
# Optimal objective  1.253857143e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 201 rows, 7964 columns and 23892 nonzeros
# Model fingerprint: 0xd9255785
# Variable types: 0 continuous, 7964 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+02]
# Found heuristic solution: objective 379.0000000
# Presolve time: 0.02s
# Presolved: 201 rows, 7964 columns, 23892 nonzeros
# Variable types: 0 continuous, 7964 integer (7964 binary)
#
# Root relaxation: objective 1.253857e+03, 274 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1253.85714    0    3  379.00000 1253.85714   231%     -    0s
# H    0     0                    1251.0000000 1253.85714  0.23%     -    0s
# H    0     0                    1253.0000000 1253.85714  0.07%     -    0s
#      0     0 1253.85714    0    3 1253.00000 1253.85714  0.07%     -    0s
#
# Explored 1 nodes (274 simplex iterations) in 0.06 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 1253 1251 379
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.253000000000e+03, best bound 1.253000000000e+03, gap 0.0000%
# iterationnumber 250
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 251 rows, 12404 columns and 37212 nonzeros
# Model fingerprint: 0x3185b94a
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve time: 0.02s
# Presolved: 251 rows, 12404 columns, 37212 nonzeros
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.265e+04
#  Factor NZ  : 2.761e+04 (roughly 5 MBytes of memory)
#  Factor Ops : 3.953e+06 (less than 1 second per iteration)
#  Threads    : 4
#
# Barrier performed 0 iterations in 0.03 seconds
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 349 iterations and 0.04 seconds
# Optimal objective  1.700750000e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 251 rows, 12404 columns and 37212 nonzeros
# Model fingerprint: 0xb4b8bc1a
# Variable types: 0 continuous, 12404 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 546.0000000
# Presolve time: 0.04s
# Presolved: 251 rows, 12404 columns, 37212 nonzeros
# Variable types: 0 continuous, 12404 integer (12404 binary)
#
# Root relaxation: objective 1.700750e+03, 339 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1700.75000    0    1  546.00000 1700.75000   211%     -    0s
# H    0     0                    1697.0000000 1700.75000  0.22%     -    0s
# H    0     0                    1699.0000000 1700.75000  0.10%     -    0s
# H    0     0                    1700.0000000 1700.75000  0.04%     -    0s
#      0     0 1700.75000    0    1 1700.00000 1700.75000  0.04%     -    0s
#
# Explored 1 nodes (339 simplex iterations) in 0.10 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 1700 1699 1697 546
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.700000000000e+03, best bound 1.700000000000e+03, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 251 rows, 12450 columns and 37348 nonzeros
# Model fingerprint: 0x27d0d884
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve time: 0.01s
# Presolved: 251 rows, 12450 columns, 37348 nonzeros
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.270e+04
#  Factor NZ  : 2.750e+04 (roughly 5 MBytes of memory)
#  Factor Ops : 3.918e+06 (less than 1 second per iteration)
#  Threads    : 4
#
# Barrier performed 0 iterations in 0.03 seconds
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 387 iterations and 0.03 seconds
# Optimal objective  1.694000000e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 251 rows, 12450 columns and 37348 nonzeros
# Model fingerprint: 0x3fa80982
# Variable types: 0 continuous, 12450 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 540.0000000
# Presolve time: 0.04s
# Presolved: 251 rows, 12450 columns, 37348 nonzeros
# Variable types: 0 continuous, 12450 integer (12450 binary)
#
# Root relaxation: objective 1.694000e+03, 391 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1694.00000    0    3  540.00000 1694.00000   214%     -    0s
# H    0     0                    1691.0000000 1694.00000  0.18%     -    0s
# H    0     0                    1694.0000000 1694.00000  0.00%     -    0s
#      0     0 1694.00000    0    3 1694.00000 1694.00000  0.00%     -    0s
#
# Explored 1 nodes (421 simplex iterations) in 0.11 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 1694 1691 540
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.694000000000e+03, best bound 1.694000000000e+03, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 251 rows, 12455 columns and 37364 nonzeros
# Model fingerprint: 0xf412449c
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve time: 0.02s
# Presolved: 251 rows, 12455 columns, 37364 nonzeros
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.271e+04
#  Factor NZ  : 2.794e+04 (roughly 5 MBytes of memory)
#  Factor Ops : 4.036e+06 (less than 1 second per iteration)
#  Threads    : 4
#
# Barrier performed 0 iterations in 0.03 seconds
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 337 iterations and 0.03 seconds
# Optimal objective  1.690000000e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 251 rows, 12455 columns and 37364 nonzeros
# Model fingerprint: 0xf4f3147f
# Variable types: 0 continuous, 12455 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 504.0000000
# Presolve time: 0.04s
# Presolved: 251 rows, 12455 columns, 37364 nonzeros
# Variable types: 0 continuous, 12455 integer (12455 binary)
#
# Root relaxation: objective 1.690000e+03, 350 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1690.00000    0    7  504.00000 1690.00000   235%     -    0s
# H    0     0                    1679.0000000 1690.00000  0.66%     -    0s
# H    0     0                    1688.0000000 1690.00000  0.12%     -    0s
# H    0     0                    1690.0000000 1690.00000  0.00%     -    0s
#      0     0 1690.00000    0    7 1690.00000 1690.00000  0.00%     -    0s
#
# Explored 1 nodes (350 simplex iterations) in 0.10 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 1690 1688 1679 504
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.690000000000e+03, best bound 1.690000000000e+03, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 251 rows, 12485 columns and 37453 nonzeros
# Model fingerprint: 0xab8fd872
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve time: 0.01s
# Presolved: 251 rows, 12485 columns, 37453 nonzeros
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.274e+04
#  Factor NZ  : 2.782e+04 (roughly 5 MBytes of memory)
#  Factor Ops : 3.996e+06 (less than 1 second per iteration)
#  Threads    : 4
#
# Barrier performed 0 iterations in 0.02 seconds
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 350 iterations and 0.03 seconds
# Optimal objective  1.685285714e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 251 rows, 12485 columns and 37453 nonzeros
# Model fingerprint: 0xd7a1b4fb
# Variable types: 0 continuous, 12485 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 500.0000000
# Presolve time: 0.03s
# Presolved: 251 rows, 12485 columns, 37453 nonzeros
# Variable types: 0 continuous, 12485 integer (12485 binary)
#
# Root relaxation: objective 1.685286e+03, 332 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1685.28571    0    1  500.00000 1685.28571   237%     -    0s
# H    0     0                    1680.0000000 1685.28571  0.31%     -    0s
# H    0     0                    1682.0000000 1685.28571  0.20%     -    0s
# H    0     0                    1684.0000000 1685.28571  0.08%     -    0s
# H    0     0                    1685.0000000 1685.28571  0.02%     -    0s
#      0     0 1685.28571    0    1 1685.00000 1685.28571  0.02%     -    0s
#
# Explored 1 nodes (332 simplex iterations) in 0.09 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 1685 1684 1682 ... 500
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.685000000000e+03, best bound 1.685000000000e+03, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 251 rows, 12440 columns and 37320 nonzeros
# Model fingerprint: 0xc0fb8510
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve time: 0.01s
# Presolved: 251 rows, 12440 columns, 37320 nonzeros
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.269e+04
#  Factor NZ  : 2.972e+04 (roughly 5 MBytes of memory)
#  Factor Ops : 4.649e+06 (less than 1 second per iteration)
#  Threads    : 4
#
# Barrier performed 0 iterations in 0.02 seconds
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 343 iterations and 0.03 seconds
# Optimal objective  1.652000000e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 251 rows, 12440 columns and 37320 nonzeros
# Model fingerprint: 0x9979a907
# Variable types: 0 continuous, 12440 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 535.0000000
# Presolve time: 0.03s
# Presolved: 251 rows, 12440 columns, 37320 nonzeros
# Variable types: 0 continuous, 12440 integer (12440 binary)
#
# Root relaxation: objective 1.652000e+03, 385 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1652.00000    0    5  535.00000 1652.00000   209%     -    0s
# H    0     0                    1639.0000000 1652.00000  0.79%     -    0s
# H    0     0                    1647.0000000 1652.00000  0.30%     -    0s
# H    0     0                    1652.0000000 1652.00000  0.00%     -    0s
#      0     0 1652.00000    0    5 1652.00000 1652.00000  0.00%     -    0s
#
# Explored 1 nodes (385 simplex iterations) in 0.10 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 1652 1647 1639 535
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.652000000000e+03, best bound 1.652000000000e+03, gap 0.0000%
# iterationnumber 300
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 301 rows, 18017 columns and 54051 nonzeros
# Model fingerprint: 0x4f8a00b5
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+02]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve time: 0.02s
# Presolved: 301 rows, 18017 columns, 54051 nonzeros
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.832e+04
#  Factor NZ  : 3.951e+04 (roughly 8 MBytes of memory)
#  Factor Ops : 6.704e+06 (less than 1 second per iteration)
#  Threads    : 4
#
# Barrier performed 0 iterations in 0.04 seconds
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 441 iterations and 0.04 seconds
# Optimal objective  2.118000000e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 301 rows, 18017 columns and 54051 nonzeros
# Model fingerprint: 0xa0cee91c
# Variable types: 0 continuous, 18017 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+02]
# Found heuristic solution: objective 663.0000000
# Presolve time: 0.05s
# Presolved: 301 rows, 18017 columns, 54051 nonzeros
# Variable types: 0 continuous, 18017 integer (18017 binary)
#
# Root relaxation: objective 2.118000e+03, 451 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2118.00000    0    9  663.00000 2118.00000   219%     -    0s
# H    0     0                    2107.0000000 2118.00000  0.52%     -    0s
# H    0     0                    2116.0000000 2118.00000  0.09%     -    0s
# H    0     0                    2118.0000000 2118.00000  0.00%     -    0s
#      0     0 2118.00000    0    9 2118.00000 2118.00000  0.00%     -    0s
#
# Explored 1 nodes (451 simplex iterations) in 0.14 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 2118 2116 2107 663
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.118000000000e+03, best bound 2.118000000000e+03, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 301 rows, 17983 columns and 53949 nonzeros
# Model fingerprint: 0x328c52cf
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+02]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve time: 0.02s
# Presolved: 301 rows, 17983 columns, 53949 nonzeros
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.828e+04
#  Factor NZ  : 3.953e+04 (roughly 8 MBytes of memory)
#  Factor Ops : 6.708e+06 (less than 1 second per iteration)
#  Threads    : 4
#
# Barrier performed 0 iterations in 0.04 seconds
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 509 iterations and 0.04 seconds
# Optimal objective  2.096000000e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 301 rows, 17983 columns and 53949 nonzeros
# Model fingerprint: 0x9a05b92e
# Variable types: 0 continuous, 17983 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+02]
# Found heuristic solution: objective 596.0000000
# Presolve time: 0.05s
# Presolved: 301 rows, 17983 columns, 53949 nonzeros
# ...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 2.010e+05
#  Factor NZ  : 4.144e+05 (roughly 80 MBytes of memory)
#  Factor Ops : 2.198e+08 (less than 1 second per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   5.67515474e+06  4.94246776e+03  6.93e+05 1.67e+01  2.78e+01     0s
#    1   4.50421860e+05  1.40268386e+04  4.76e+04 1.42e-14  1.82e+00     1s
#    2   2.52616094e+04  1.31927853e+04  2.08e+03 1.42e-14  9.60e-02     1s
#    3   1.15456117e+04  9.68904733e+03  5.65e+02 2.13e-14  3.03e-02     1s
#
# Barrier performed 3 iterations in 0.60 seconds
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 6846 iterations and 0.60 seconds
# Optimal objective  8.155769231e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1001 rows, 199981 columns and 599931 nonzeros
# Model fingerprint: 0x73b71be2
# Variable types: 0 continuous, 199981 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 1984.0000000
# Presolve time: 0.66s
# Presolved: 1001 rows, 199981 columns, 599931 nonzeros
# Variable types: 0 continuous, 199981 integer (199981 binary)
#
# Starting sifting (using dual simplex for sub-problems)...
#
#     Iter     Pivots    Primal Obj      Dual Obj        Time
#        0          0     infinity     -1.0299000e+04      1s
#        1        688  -6.4453333e+03  -9.5823168e+03      1s
#        2       1986  -7.5086667e+03  -9.0267929e+03      1s
#        3       4065  -8.0936667e+03  -8.6223737e+03      1s
#        4       5822  -8.1557692e+03  -8.1858600e+03      1s
#
# Sifting complete
#
#
# Root relaxation: objective 8.155769e+03, 6846 iterations, 0.27 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 8155.76923    0   44 1984.00000 8155.76923   311%     -    1s
# H    0     0                    7977.0000000 8155.76923  2.24%     -    1s
# H    0     0                    8154.0000000 8155.76923  0.02%     -    1s
# H    0     0                    8155.0000000 8155.76923  0.01%     -    2s
#      0     0 8155.76923    0   44 8155.00000 8155.76923  0.01%     -    2s
#
# Explored 1 nodes (6859 simplex iterations) in 2.07 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 8155 8154 7977 1984
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.155000000000e+03, best bound 8.155000000000e+03, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1001 rows, 199855 columns and 599562 nonzeros
# Model fingerprint: 0x25437531
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve time: 0.26s
# Presolved: 1001 rows, 199855 columns, 599562 nonzeros
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 2.009e+05
#  Factor NZ  : 4.143e+05 (roughly 80 MBytes of memory)
#  Factor Ops : 2.197e+08 (less than 1 second per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   5.69457267e+06  4.95182690e+03  6.95e+05 1.87e+01  3.11e+01     0s
#    1   4.16969918e+05  1.50410169e+04  4.47e+04 1.78e-14  1.93e+00     0s
#    2   1.99389973e+04  1.40479588e+04  1.55e+03 1.78e-14  8.61e-02     1s
#
# Barrier performed 2 iterations in 0.51 seconds
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 5618 iterations and 0.52 seconds
# Optimal objective  8.154100000e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1001 rows, 199855 columns and 599562 nonzeros
# Model fingerprint: 0x9936c75f
# Variable types: 0 continuous, 199855 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 1899.0000000
# Presolve time: 0.62s
# Presolved: 1001 rows, 199855 columns, 599562 nonzeros
# Variable types: 0 continuous, 199855 integer (199855 binary)
#
# Starting sifting (using dual simplex for sub-problems)...
#
#     Iter     Pivots    Primal Obj      Dual Obj        Time
#        0          0     infinity     -1.0282000e+04      1s
#        1        670  -6.4853333e+03  -9.4683286e+03      1s
#        2       2040  -7.6123333e+03  -8.9476457e+03      1s
#        3       4113  -8.1225556e+03  -8.4692892e+03      1s
#
# Sifting complete
#
#
# Root relaxation: objective 8.154100e+03, 5618 iterations, 0.23 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 8154.10000    0   28 1899.00000 8154.10000   329%     -    1s
# H    0     0                    8055.0000000 8154.10000  1.23%     -    1s
# H    0     0                    8149.0000000 8154.10000  0.06%     -    1s
# H    0     0                    8151.0000000 8154.10000  0.04%     -    1s
# H    0     0                    8154.0000000 8154.10000  0.00%     -    1s
#      0     0 8154.10000    0   28 8154.00000 8154.10000  0.00%     -    2s
#
# Explored 1 nodes (5630 simplex iterations) in 2.04 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 8154 8151 8149 ... 1899
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.154000000000e+03, best bound 8.154000000000e+03, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1001 rows, 199938 columns and 599805 nonzeros
# Model fingerprint: 0xfd27fe58
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve time: 0.27s
# Presolved: 1001 rows, 199938 columns, 599805 nonzeros
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 2.009e+05
#  Factor NZ  : 4.135e+05 (roughly 80 MBytes of memory)
#  Factor Ops : 2.187e+08 (less than 1 second per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   5.67393978e+06  4.93800245e+03  6.92e+05 1.70e+01  2.82e+01     0s
#    1   4.55211100e+05  1.41707915e+04  4.82e+04 1.07e-14  1.88e+00     0s
#    2   2.77397813e+04  1.33291773e+04  2.36e+03 1.42e-14  1.08e-01     1s
#    3   1.13104877e+04  9.61846735e+03  5.36e+02 1.78e-14  2.88e-02     1s
#
# Barrier performed 3 iterations in 0.58 seconds
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 5616 iterations and 0.60 seconds
# Optimal objective  8.172882353e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1001 rows, 199938 columns and 599805 nonzeros
# Model fingerprint: 0xe0af8ee9
# Variable types: 0 continuous, 199938 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 2034.0000000
# Presolve time: 0.64s
# Presolved: 1001 rows, 199938 columns, 599805 nonzeros
# Variable types: 0 continuous, 199938 integer (199938 binary)
#
# Starting sifting (using dual simplex for sub-problems)...
#
#     Iter     Pivots    Primal Obj      Dual Obj        Time
#        0          0     infinity     -1.0276000e+04      1s
#        1        688  -6.4965000e+03  -9.6240769e+03      1s
#        2       2050  -7.4275714e+03  -8.9666425e+03      1s
#        3       4095  -8.1435000e+03  -8.5332582e+03      1s
#
# Sifting complete
#
#
# Root relaxation: objective 8.172882e+03, 5616 iterations, 0.24 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 8172.88235    0   48 2034.00000 8172.88235   302%     -    1s
# H    0     0                    8011.0000000 8172.88235  2.02%     -    1s
# H    0     0                    8163.0000000 8172.88235  0.12%     -    1s
# H    0     0                    8168.0000000 8172.88235  0.06%     -    2s
# H    0     0                    8172.0000000 8172.88235  0.01%     -    2s
#      0     0 8172.88235    0   48 8172.00000 8172.88235  0.01%     -    2s
#
# Explored 1 nodes (5631 simplex iterations) in 2.23 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 8172 8168 8163 ... 2034
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.172000000000e+03, best bound 8.172000000000e+03, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1001 rows, 199978 columns and 599924 nonzeros
# Model fingerprint: 0x7d5f3d4c
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve time: 0.28s
# Presolved: 1001 rows, 199978 columns, 599924 nonzeros
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 2.010e+05
#  Factor NZ  : 4.136e+05 (roughly 80 MBytes of memory)
#  Factor Ops : 2.188e+08 (less than 1 second per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   5.67033134e+06  4.94649540e+03  6.92e+05 2.01e+01  3.33e+01     0s
#    1   3.89261550e+05  1.57557600e+04  4.20e+04 1.78e-14  1.96e+00     0s
#    2   2.09049495e+04  1.46450256e+04  1.68e+03 2.13e-14  9.86e-02     1s
#    3   1.05969747e+04  1.05720549e+04  5.22e+02 1.78e-14  3.54e-02     1s
#
# Barrier performed 3 iterations in 0.58 seconds
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 5879 iterations and 0.59 seconds
# Optimal objective  8.165500000e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1001 rows, 199978 columns and 599924 nonzeros
# Model fingerprint: 0x36047118
# Variable types: 0 continuous, 199978 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 2012.0000000
# Presolve time: 0.64s
# Presolved: 1001 rows, 199978 columns, 599924 nonzeros
# Variable types: 0 continuous, 199978 integer (199978 binary)
#
# Starting sifting (using dual simplex for sub-problems)...
#
#     Iter     Pivots    Primal Obj      Dual Obj        Time
#        0          0     infinity     -1.0313000e+04      1s
#        1        821  -6.4364444e+03  -9.5400604e+03      1s
#        2       2179  -7.5887500e+03  -8.9987832e+03      1s
#        3       4261  -8.1327000e+03  -8.5833023e+03      1s
#
# Sifting complete
#
#
# Root relaxation: objective 8.165500e+03, 5879 iterations, 0.24 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 8165.50000    0   38 2012.00000 8165.50000   306%     -    1s
# H    0     0                    8007.0000000 8165.50000  1.98%     -    1s
# H    0     0                    8162.0000000 8165.50000  0.04%     -    2s
# H    0     0                    8165.0000000 8165.50000  0.01%     -    2s
#      0     0 8165.50000    0   38 8165.00000 8165.50000  0.01%     -    2s
#
# Explored 1 nodes (5891 simplex iterations) in 2.10 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 8165 8162 8007 2012
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.165000000000e+03, best bound 8.165000000000e+03, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1001 rows, 199691 columns and 599067 nonzeros
# Model fingerprint: 0x2d05e052
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve time: 0.32s
# Presolved: 1001 rows, 199691 columns, 599067 nonzeros
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 2.007e+05
#  Factor NZ  : 4.117e+05 (roughly 80 MBytes of memory)
#  Factor Ops : 2.165e+08 (less than 1 second per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   5.65909987e+06  4.94058836e+03  6.90e+05 1.79e+01  2.96e+01     1s
#    1   4.44354116e+05  1.45873002e+04  4.75e+04 1.42e-14  1.96e+00     1s
#    2   2.48213542e+04  1.36908008e+04  2.07e+03 1.78e-14  1.03e-01     1s
#
# Barrier performed 2 iterations in 0.60 seconds
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 5426 iterations and 0.62 seconds
# Optimal objective  8.102205128e+03
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1001 rows, 199691 columns and 599067 nonzeros
# Model fingerprint: 0xdab521be
# Variable types: 0 continuous, 199691 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 1886.0000000
# Presolve time: 0.67s
# Presolved: 1001 rows, 199691 columns, 599067 nonzeros
# Variable types: 0 continuous, 199691 integer (199691 binary)
#
# Starting sifting (using dual simplex for sub-problems)...
#
#     Iter     Pivots    Primal Obj      Dual Obj        Time
#        0          0     infinity     -1.0290000e+04      1s
#        1        656  -6.2992222e+03  -9.4383261e+03      1s
#        2       2059  -7.5750000e+03  -8.8100102e+03      1s
#        3       4013  -8.1002500e+03  -8.3374576e+03      1s
#
# Sifting complete
#
#
# Root relaxation: objective 8.102205e+03, 5426 iterations, 0.24 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 8102.20513    0   88 1886.00000 8102.20513   330%     -    1s
# H    0     0                    7806.0000000 8102.20513  3.79%     -    1s
# H    0     0                    8090.0000000 8102.20513  0.15%     -    2s
# H    0     0                    8097.0000005 8102.20513  0.06%     -    2s
# H    0     0                    8102.0000000 8102.20513  0.00%     -    2s
#      0     0 8102.20513    0   88 8102.00000 8102.20513  0.00%     -    2s
#
# Explored 1 nodes (5427 simplex iterations) in 2.37 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 8102 8097 8090 ... 1886
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.102000000000e+03, best bound 8.102000000000e+03, gap 0.0000%

# %%
sols
# Out:
# {100: [553.0, 558.0, 591.0, 565.0, 568.0],
#  150: [965.0, 967.0, 930.0, 977.0, 929.0],
#  200: [1313.0, 1329.0, 1325.0, 1297.0, 1253.0],
#  250: [1700.0, 1694.0, 1690.0, 1685.0, 1652.0],
#  300: [2118.0, 2096.0, 2135.0, 2093.0, 2129.0],
#  350: [2489.0, 2519.0, 2520.0, 2460.0, 2476.0],
#  400: [2876.0, 2898.0, 2865.0, 2892.0, 2847.0],
#  450: [3348.0, 3341.0, 3318.0, 3276.0, 3308.0],
#  500: [3779.0, 3723.0, 3720.0, 3753.0, 3802.0],
#  550: [4150.0, 4161.0, 4220.0, 4195.0, 4224.0],
#  600: [4628.0, 4596.0, 4672.0, 4658.0, 4569.0],
#  650: [5070.0, 5081.0, 5053.0, 5058.0, 5032.0],
#  700: [5481.0, 5496.000000051551, 5512.0, 5504.0, 5423.0],
#  750: [5849.0, 5922.0, 5952.0, 5936.0, 5930.0],
#  800: [6326.0, 6410.0, 6336.0, 6349.0, 6350.0],
#  850: [6807.0, 6937.0, 6808.0, 6798.0, 6862.0],
#  900: [7270.0, 7330.0, 7337.0, 7290.0, 7282.0],
#  950: [7649.0, 7700.000000068727, 7732.0, 7773.0, 7700.0],
#  1000: [8155.0, 8154.0, 8172.0, 8165.0, 8102.0]}

# %%
LRs
# Out:
# {100: [(546, 554), (556, 558), (585, 591), (551, 565), (568, 568)],
#  150: [(953, 965), (967, 967), (930, 930), (927, 978), (902, 929)],
#  200: [(1250, 1313), (1317, 1329), (1325, 1325), (1236, 1297), (1228, 1253)],
#  250: [(1688, 1700), (1563, 1694), (1668, 1690), (1681, 1685), (1637, 1651)],
#  300: [(2047, 2118), (2059, 2096), (2101, 2135), (2013, 2093), (2032, 2129)],
#  350: [(2434, 2489), (2417, 2519), (2429, 2520), (2456, 2460), (2350, 2476)],
#  400: [(2861, 2876), (2825, 2898), (2707, 2865), (2847, 2892), (2767, 2846)],
#  450: [(3232, 3348), (3339, 3341), (3073, 3318), (3154, 3275), (3308, 3308)],
#  500: [(3584, 3779), (3655, 3723), (3455, 3720), (3554, 3752), (3609, 3802)],
#  550: [(3686, 4150), (4036, 4161), (3961, 4220), (4187, 4195), (4207, 4224)],
#  600: [(4421, 4628), (4273, 4596), (4605, 4672), (4389, 4658), (4283, 4570)],
#  650: [(4930, 5070), (4746, 5081), (4725, 5053), (5058, 5058), (4594, 5032)],
#  700: [(5303, 5481), (5198, 5496), (5295, 5512), (5415, 5504), (5221, 5423)],
#  750: [(5722, 5849), (5823, 5922), (5670, 5952), (5770, 5937), (5755, 5930)],
#  800: [(6167, 6326), (5943, 6410), (6336, 6336), (5778, 6349), (6065, 6349)],
#  850: [(6631, 6807), (6739, 6937), (6331, 6808), (6567, 6798), (6762, 6862)],
#  900: [(7016, 7270), (7145, 7330), (7337, 7337), (6690, 7290), (6973, 7282)],
#  950: [(7525, 7649), (7520, 7700), (7604, 7732), (7452, 7773), (7362, 7700)],
#  1000: [(7625, 8155), (7937, 8154), (7798, 8172), (7862, 8165), (7425, 8102)]}
