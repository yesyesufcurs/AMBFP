# %%
# import libraries needed
import time
import networkx as nx
from sortedcontainers import SortedList, SortedSet, SortedDict
import random
import numpy as np
import math
from itertools import chain, combinations
from networkx.generators.random_graphs import erdos_renyi_graph
import matplotlib.pylab as plt

# %%
# Create new edge and set edge weight and cost
def setEdgeData(G, edge, weight, cost):
    G.add_edge(edge[0], edge[1])
    G[edge[0]][edge[1]]['weight'] = weight
    G[edge[0]][edge[1]]['cost'] = cost

def getEdgeCost(G, edge):
    return G[edge[0]][edge[1]]['cost']

def getEdgeWeight(G, edge):
    return G[edge[0]][edge[1]]['weight']

def zerotruncatedPoisson(p):
    #source: https://web.archive.org/web/20180826164029/http://giocc.com/zero_truncated_poisson_sampling_algorithm.html
    k = 1
    t = math.e**(-p) / (1 - math.e**(-p)) * p
    s = t
    u = random.random()
    while s < u:
        k += 1
        t *= p / k
        s += t
    return k

def isMatching(edges):
    # Check if set of edges is matching
    seen = []
    for e in edges:
        if e[0] in seen:
            return False
        seen.append(e[0])
        if e[1] in seen:
            return False
        seen.append(e[1])
    return True

def powerset(iterable, maxSize):
    "Source: https://docs.python.org/3/library/itertools.html#itertools-recipes"
    "powerset([1,2,3]) --> () (1,) (2,) (3,) (1,2) (1,3) (2,3) (1,2,3)"
    s = list(iterable)
    return chain.from_iterable(combinations(s, r) for r in range(maxSize+1))
def powersetAll(iterable):
    "Source: https://docs.python.org/3/library/itertools.html#itertools-recipes"
    "powerset([1,2,3]) --> () (1,) (2,) (3,) (1,2) (1,3) (2,3) (1,2,3)"
    s = list(iterable)
    return chain.from_iterable(combinations(s, r) for r in range(len(s)+1))



def generateRandomGraph(n, p, Ew, Ec):
    """
    Generates random graph using the Erdös-Rényi model.
    params
    n: number of vertices
    p: probability parameter Erdös-Rényi
    Ew: zero truncated poisson weight parameter
    Ec: poisson cost parameter
    """
    graph = erdos_renyi_graph(n,p)
    for edge in graph.edges:
        weight = 0
        cost = 0
        weight = zerotruncatedPoisson(Ew)
        cost = np.random.poisson(Ec)
        setEdgeData(graph, edge, weight, cost)
    return graph
    
def computeCost(g, matching):
    # compute cost of matching
    return sum(getEdgeCost(g, e) for e in matching)
def computeWeight(g, matching):
    # compute weight of matching
    return sum(getEdgeWeight(g, e) for e in matching)
def budgetedMatchingProblemBruteforce(g, B):
    # solve BMP by bruteforce
    maximum = 0
    cost = 0
    matching = None
    for e in powerset(g.edges, len(g.nodes)//2):
        if isMatching(e):
            c = computeCost(g, e)
            m = computeWeight(g, e)
            if c <= B and m > maximum:
                maximum = m
                matching = e
                cost = c
    return cost, maximum, matching

def isSubset(a, b):
    """
    Checks if a subset b
    """
    return a.intersection(b)==a

# %%
# w[i,j,k] = (maximumWeight using first i edges with budget j using vertices in k)  
# w : {0,...,n} x {0,...,B} x P(V) -> Z+
# w[0,j,k] = 0
# w[i,j,{}] = 0
# w[i,j,k] = max(w[i-1,j,k], w[i-1,j-c(i),k\{v : v in e(i)}] + w(i)) if c(i) <= j and {v : v in e(i)} \in k
# w[i,j,k] = w[i-1,j,k] otherwise

def verticesIn(edge):
    return SortedSet([edge[0], edge[1]])

def maximumMatchingDynamic(G, B):
    """
    Solve Budgeted Matching Problem using dynamic programming
    """
    w = [[dict() for _ in range(B + 1)] for _ in range(len(G.edges) + 1)]
    edges = list(G.edges)
    nodes = list(G.nodes)
    for i in range(len(G.edges) + 1):
        for j in range(B + 1):
            for el in powerset(nodes):
                k = SortedSet(el)
                if i == 0: w[i][j][str(k)] = 0
                elif k == SortedSet(set()): w[i][j][str(k)] = 0
                elif getEdgeCost(G,edges[i - 1]) <= j and isSubset(verticesIn(edges[i-1]), k): 
                    w[i][j][str(k)] = max(w[i-1][j][str(k)], w[i-1][j-getEdgeCost(G,edges[i-1])][str(k.difference(verticesIn(edges[i-1])))] + getEdgeWeight(G, edges[i-1]))
                else:
                    w[i][j][str(k)] = w[i-1][j][str(k)]
    return w[len(G.edges)][B][str(SortedSet(nodes))]

def maximumMatchingDynamicAlt(G, B):
    """
    Solve Budgeted Matching Problem using dynamic programming
    filling in w[i,j,k] by iterating through P(V) first
    """
    w = dict()
    edges = list(G.edges)
    nodes = list(G.nodes)
    for el in powerset(nodes):
        k = SortedSet(el)
        w[str(k)] = [[dict() for _ in range(B + 1)] for _ in range(len(G.edges) + 1)]
        for i in range(len(G.edges) + 1):
            for j in range(B + 1):
                if i == 0: w[str(k)][i][j] = 0
                elif k == SortedSet(set()): w[str(k)][i][j] = 0
                elif getEdgeCost(G,edges[i - 1]) <= j and isSubset(verticesIn(edges[i-1]), k):
                    w[str(k)][i][j] = max(w[str(k)][i-1][j], w[str(k.difference(verticesIn(edges[i-1])))][i-1][j-getEdgeCost(G,edges[i-1])] + getEdgeWeight(G, edges[i-1]))
                else:
                    w[str(k)][i][j] = w[str(k)][i-1][j]
    return w[str(SortedSet(nodes))][len(G.edges)][B]


def setToBitstring(inp, size):
    "Convert set to bitstring"
    string = bytearray(size)
    for i in inp:
        string[i] = 1
    return string

def bitsToInt(bitstring):
    "Convert bitstring to integer"
    return int.from_bytes(bitstring, "little")

def edgeIsSubset(edge, bitstring):
    "Given an edge and a bitstring return if edge in bitstring"
    return bitstring[edge[0]] == 1 and bitstring[edge[1]] == 1

def bitStringDifference(a, b):
    "Return the bitstring for the set a setminus b"
    string = bytearray(len(a))
    string[:] = a
    for i in b:
        string[i] = 0
    return string
    

def maximumMatchingDynamicBitstring(G, B):
    """
    Solve budgeted matching problem using Dynamic programming
    by using bitstrings
    """
    w = dict()
    edges = list(G.edges)
    nodes = list(G.nodes)
    size = len(nodes)
    e_size = len(edges)
    for el in powerset(nodes):
        k = setToBitstring(el, size)
        int_k = bitsToInt(k)
        w[int_k] = [[dict() for _ in range(B + 1)] for _ in range(e_size + 1)]
        for i in range(e_size + 1):
            for j in range(B + 1):
                if i == 0: w[int_k][i][j] = 0
                elif int_k == 0: w[int_k][i][j] = 0
                elif getEdgeCost(G,edges[i - 1]) <= j and edgeIsSubset(edges[i-1], k):
                    w[int_k][i][j] = max(w[int_k][i-1][j], w[bitsToInt(bitStringDifference(k, edges[i - 1]))][i-1][j-getEdgeCost(G,edges[i-1])] + getEdgeWeight(G, edges[i-1]))
                else:
                    w[int_k][i][j] = w[int_k][i-1][j]
    return w[bitsToInt(setToBitstring(nodes, size))][e_size][B]

# %%
from gurobipy.gurobipy import Model, quicksum, GRB
def graph_to_gurobi(graph, budget):
    # Turn budgeted matching instance into linear program
    model = Model("Budgeted Matching Constaint")
    x = {}
    edges = list(g.edges)
    nodes = list(g.nodes)
    for e in edges:
        x[e] = model.addVar(vtype=GRB.INTEGER, name=f'edge[{e}]', lb = 0, ub=1)
    model.addConstrs(
        (quicksum(x[e] for e in edges if v in e) <= 1 for v in nodes),
        name='Satisfy Matching'
    )
    model.addConstr(
        quicksum(x[e] * getEdgeCost(graph, e) for e in edges) <= budget,
        name='Satisfy Budget'
    )
    model.setObjective(
        quicksum(x[e] * getEdgeWeight(graph, e) for e in edges),
        sense=GRB.MAXIMIZE
    )
    return model

# %%
'''
Test of budgeted matching dynamic program on dense graphs using bitstrings
Results get saved in dict times_brute_dense and times_gurobi_dense
'''
import time
# Dense Graphs
times_brute_dense = {}
times_gurobi_dense = {}
for n in range(2,11):
    running_time_bruteforce = 0
    running_time_gurobi = 0
    for i in range(10):
        g = generateRandomGraph(n, 0.8, 10, 10)
        gurobi = graph_to_gurobi(g, 3*n)
        start = time.time()
        maximumMatchingDynamicBitstring(g, 3*n)
        end = time.time()
        running_time_bruteforce += end - start
        
        start = time.time()
        gurobi.optimize()
        end = time.time()
        running_time_gurobi += end - start
    times_brute_dense[n] = running_time_bruteforce / 10
    times_gurobi_dense[n] = running_time_gurobi / 10
# Out:
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0xd34ec147
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [7e+00, 7e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective 7.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.000000000000e+00, best bound 7.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0xacf01e33
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [1e+01, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0x9350680c
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [6e+00, 6e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0x7c54dd6a
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+00]
#   Objective range  [9e+00, 9e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0x6c527ac1
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [1e+01, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0xc3d001e5
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [6e+00, 6e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective 6.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.000000000000e+00, best bound 6.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 0 columns and 0 nonzeros
# Model fingerprint: 0x003196a4
# Coefficient statistics:
#   Matrix range     [0e+00, 0e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 3 rows and 0 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds
# Optimal objective -0.000000000e+00
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 0 columns and 0 nonzeros
# Model fingerprint: 0x003196a4
# Coefficient statistics:
#   Matrix range     [0e+00, 0e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 3 rows and 0 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds
# Optimal objective -0.000000000e+00
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0x2845913b
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [7e+00, 7e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0xc5a568ed
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e+01, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective 14.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 14
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.400000000000e+01, best bound 1.400000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0xc11c4c9e
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+00]
#   Objective range  [8e+00, 9e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective 9.0000000
# Presolve removed 4 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.000000000000e+00, best bound 9.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0x052b6780
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [8e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective 13.0000000
# Presolve removed 4 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 13
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.300000000000e+01, best bound 1.300000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0xfd1659c6
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+01, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 4 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0x6e63a0fe
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [5e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 4 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0xbdf77c3a
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [7e+00, 7e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 4 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0xa9708071
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [7e+00, 7e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 4 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0xe34b12ca
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+01, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective 10.0000000
# Presolve removed 4 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 10
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+01, best bound 1.000000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0x9d66e5ad
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+00]
#   Objective range  [8e+00, 8e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective 8.0000000
# Presolve removed 4 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.000000000000e+00, best bound 8.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0x398029ef
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+01, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective 10.0000000
# Presolve removed 4 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 10
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+01, best bound 1.000000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0xfb9437cb
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+01, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective 10.0000000
# Presolve removed 4 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 10
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+01, best bound 1.000000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 6 columns and 18 nonzeros
# Model fingerprint: 0x58d6f993
# Variable types: 0 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [8e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 10.0000000
# Presolve removed 5 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 15 10
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.500000000000e+01, best bound 1.500000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 4 columns and 12 nonzeros
# Model fingerprint: 0xa5e5fc24
# Variable types: 0 continuous, 4 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [7e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 7.0000000
# Presolve removed 5 rows and 4 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 16 7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.600000000000e+01, best bound 1.600000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 4 columns and 12 nonzeros
# Model fingerprint: 0xb79fffb4
# Variable types: 0 continuous, 4 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [7e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 8.0000000
# Presolve removed 5 rows and 4 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 14 8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.400000000000e+01, best bound 1.400000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0x74cd46b6
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [8e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 8.0000000
# Presolve removed 5 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.000000000000e+00, best bound 8.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 5 columns and 15 nonzeros
# Model fingerprint: 0x16e350a5
# Variable types: 0 continuous, 5 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [8e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 12.0000000
# Presolve removed 5 rows and 5 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.200000000000e+01, best bound 1.200000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0x4d716212
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [6e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 6.0000000
# Presolve removed 5 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 12 6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.200000000000e+01, best bound 1.200000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 4 columns and 12 nonzeros
# Model fingerprint: 0x7c1aff88
# Variable types: 0 continuous, 4 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [8e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 8.0000000
# Presolve removed 5 rows and 4 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 10 8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+01, best bound 1.000000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 4 columns and 12 nonzeros
# Model fingerprint: 0x670ad8b9
# Variable types: 0 continuous, 4 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [7e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 7.0000000
# Presolve removed 5 rows and 4 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 12 7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.200000000000e+01, best bound 1.200000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 4 columns and 12 nonzeros
# Model fingerprint: 0x6dbdc9eb
# Variable types: 0 continuous, 4 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [6e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 7.0000000
# Presolve removed 5 rows and 4 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.000000000000e+00, best bound 7.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 5 columns and 15 nonzeros
# Model fingerprint: 0xffe5a8d9
# Variable types: 0 continuous, 5 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 9.0000000
# Presolve removed 5 rows and 5 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 11 9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.100000000000e+01, best bound 1.100000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 8 columns and 24 nonzeros
# Model fingerprint: 0xf9ecd36b
# Variable types: 0 continuous, 8 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [4e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 10.0000000
# Presolve removed 6 rows and 8 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 16 10
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.600000000000e+01, best bound 1.600000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 10 columns and 30 nonzeros
# Model fingerprint: 0x7427c505
# Variable types: 0 continuous, 10 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [7e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 18.0000000
# Presolve removed 2 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 4 rows, 4 columns, 8 nonzeros
# Found heuristic solution: objective 20.0000000
# Variable types: 0 continuous, 4 integer (4 binary)
#
# Root relaxation: objective 2.100000e+01, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      21.0000000   21.00000  0.00%     -    0s
#
# Explored 0 nodes (1 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 21 20 18
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.100000000000e+01, best bound 2.100000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 8 columns and 24 nonzeros
# Model fingerprint: 0xe904bef6
# Variable types: 0 continuous, 8 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [7e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 17.0000000
# Presolve removed 6 rows and 8 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 19 17
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.900000000000e+01, best bound 1.900000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 8 columns and 24 nonzeros
# Model fingerprint: 0xd3e400ee
# Variable types: 0 continuous, 8 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [9e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 21.0000000
# Presolve removed 6 rows and 8 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 21
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.100000000000e+01, best bound 2.100000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 10 columns and 30 nonzeros
# Model fingerprint: 0xb44eb0fa
# Variable types: 0 continuous, 10 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [5e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 17.0000000
# Presolve removed 6 rows and 10 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 17
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.700000000000e+01, best bound 1.700000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 9 columns and 27 nonzeros
# Model fingerprint: 0xfdad4210
# Variable types: 0 continuous, 9 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [6e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 20.0000000
# Presolve removed 6 rows and 9 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 21 20
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.100000000000e+01, best bound 2.100000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 9 columns and 27 nonzeros
# Model fingerprint: 0xf6c0c06b
# Variable types: 0 continuous, 9 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [6e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 20.0000000
# Presolve removed 6 rows and 9 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 20
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+01, best bound 2.000000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 8 columns and 24 nonzeros
# Model fingerprint: 0xef2252a8
# Variable types: 0 continuous, 8 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [7e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 11.0000000
# Presolve removed 6 rows and 8 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 29 11
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.900000000000e+01, best bound 2.900000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 10 columns and 30 nonzeros
# Model fingerprint: 0x06517fa4
# Variable types: 0 continuous, 10 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [5e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 19.0000000
# Presolve removed 6 rows and 10 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 22 19
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.200000000000e+01, best bound 2.200000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 4 columns and 12 nonzeros
# Model fingerprint: 0xf1bfda5e
# Variable types: 0 continuous, 4 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [5e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 6.0000000
# Presolve removed 6 rows and 4 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 12 6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.200000000000e+01, best bound 1.200000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 11 columns and 33 nonzeros
# Model fingerprint: 0x9a20a9cc
# Variable types: 0 continuous, 11 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [7e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 17.0000000
# Presolve removed 2 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 5 rows, 5 columns, 13 nonzeros
# Found heuristic solution: objective 26.0000000
# Variable types: 0 continuous, 5 integer (5 binary)
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 26 17
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.600000000000e+01, best bound 2.600000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 13 columns and 39 nonzeros
# Model fingerprint: 0x7421e4ae
# Variable types: 0 continuous, 13 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [6e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 22.0000000
# Presolve removed 0 rows and 4 columns
# Presolve time: 0.00s
# Presolved: 7 rows, 9 columns, 27 nonzeros
# Variable types: 0 continuous, 9 integer (9 binary)
#
# Root relaxation: objective 3.163636e+01, 5 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   31.63636    0    1   22.00000   31.63636  43.8%     -    0s
# H    0     0                      31.0000000   31.63636  2.05%     -    0s
#      0     0   31.63636    0    1   31.00000   31.63636  2.05%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 31 22
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.100000000000e+01, best bound 3.100000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 13 columns and 39 nonzeros
# Model fingerprint: 0xbbefa1d1
# Variable types: 0 continuous, 13 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [5e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 12.0000000
# Presolve removed 7 rows and 13 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 25 12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.500000000000e+01, best bound 2.500000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 11 columns and 33 nonzeros
# Model fingerprint: 0x1250a8db
# Variable types: 0 continuous, 11 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [5e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 13.0000000
# Presolve removed 3 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 4 rows, 5 columns, 9 nonzeros
# Variable types: 0 continuous, 5 integer (5 binary)
#
# Root relaxation: objective 2.700000e+01, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      27.0000000   27.00000  0.00%     -    0s
#
# Explored 0 nodes (1 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 27 13
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.700000000000e+01, best bound 2.700000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 13 columns and 39 nonzeros
# Model fingerprint: 0xed4ff21b
# Variable types: 0 continuous, 13 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [7e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 27.0000000
# Presolve removed 0 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 7 rows, 11 columns, 34 nonzeros
# Variable types: 0 continuous, 11 integer (11 binary)
#
# Root relaxation: objective 3.825000e+01, 6 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   38.25000    0    6   27.00000   38.25000  41.7%     -    0s
# H    0     0                      33.0000000   38.25000  15.9%     -    0s
#      0     0     cutoff    0        33.00000   33.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Clique: 1
#
# Explored 1 nodes (7 simplex iterations) in 0.02 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 33 27
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.300000000000e+01, best bound 3.300000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 11 columns and 33 nonzeros
# Model fingerprint: 0x30080737
# Variable types: 0 continuous, 11 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [6e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 8.0000000
# Presolve removed 1 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 6 rows, 8 columns, 25 nonzeros
# Found heuristic solution: objective 29.0000000
# Variable types: 0 continuous, 8 integer (8 binary)
#
# Root relaxation: cutoff, 4 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0        29.00000   29.00000  0.00%     -    0s
#
# Explored 0 nodes (4 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 29 8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.900000000000e+01, best bound 2.900000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 11 columns and 33 nonzeros
# Model fingerprint: 0xc3566a90
# Variable types: 0 continuous, 11 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [4e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 16.0000000
# Presolve removed 1 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 6 rows, 9 columns, 29 nonzeros
# Variable types: 0 continuous, 9 integer (9 binary)
#
# Root relaxation: objective 2.200000e+01, 5 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   22.00000    0    3   16.00000   22.00000  37.5%     -    0s
# H    0     0                      21.0000000   22.00000  4.76%     -    0s
#      0     0   22.00000    0    3   21.00000   22.00000  4.76%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 21 16
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.100000000000e+01, best bound 2.100000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 11 columns and 33 nonzeros
# Model fingerprint: 0x3cd1d065
# Variable types: 0 continuous, 11 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [6e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 7.0000000
# Presolve removed 7 rows and 11 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 22 7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.200000000000e+01, best bound 2.200000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 15 columns and 45 nonzeros
# Model fingerprint: 0x423d4646
# Variable types: 0 continuous, 15 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [7e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 26.0000000
# Presolve removed 0 rows and 7 columns
# Presolve time: 0.00s
# Presolved: 7 rows, 8 columns, 25 nonzeros
# Variable types: 0 continuous, 8 integer (8 binary)
#
# Root relaxation: cutoff, 6 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0        26.00000   26.00000  0.00%     -    0s
#
# Explored 0 nodes (6 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 26
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.600000000000e+01, best bound 2.600000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 11 columns and 33 nonzeros
# Model fingerprint: 0xbd2ea447
# Variable types: 0 continuous, 11 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [4e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 13.0000000
# Presolve removed 0 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 7 rows, 6 columns, 18 nonzeros
# Found heuristic solution: objective 26.0000000
# Variable types: 0 continuous, 6 integer (6 binary)
#
# Root relaxation: cutoff, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0        26.00000   26.00000  0.00%     -    0s
#
# Explored 0 nodes (1 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 26 13
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.600000000000e+01, best bound 2.600000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 8 rows, 15 columns and 45 nonzeros
# Model fingerprint: 0x2ad3c148
# Variable types: 0 continuous, 15 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [4e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 14.0000000
# Presolve removed 0 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 8 rows, 13 columns, 40 nonzeros
# Variable types: 0 continuous, 13 integer (13 binary)
#
# Root relaxation: objective 2.900000e+01, 6 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   29.00000    0    1   14.00000   29.00000   107%     -    0s
# H    0     0                      25.0000000   29.00000  16.0%     -    0s
#      0     0   25.00000    0    6   25.00000   25.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 1
#   MIR: 1
#   StrongCG: 1
#   GUB cover: 1
#   Mod-K: 1
#
# Explored 1 nodes (12 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 25 14
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.500000000000e+01, best bound 2.500000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 8 rows, 18 columns and 54 nonzeros
# Model fingerprint: 0x2b4cde04
# Variable types: 0 continuous, 18 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 34.0000000
# Presolve removed 0 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 8 rows, 13 columns, 40 nonzeros
# Variable types: 0 continuous, 13 integer (13 binary)
#
# Root relaxation: objective 3.822222e+01, 5 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      36.0000000   36.00000  0.00%     -    0s
#
# Explored 0 nodes (8 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 36 34
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.600000000000e+01, best bound 3.600000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 8 rows, 20 columns and 60 nonzeros
# Model fingerprint: 0xaf7b9567
# Variable types: 0 continuous, 20 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [6e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 28.0000000
# Presolve removed 0 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 8 rows, 19 columns, 58 nonzeros
# Variable types: 0 continuous, 19 integer (19 binary)
#
# Root relaxation: objective 4.130769e+01, 8 iterations, 0.00 seconds
#
# ...
# Presolved: 10 rows, 24 columns, 72 nonzeros
# Variable types: 0 continuous, 24 integer (24 binary)
#
# Root relaxation: objective 5.116667e+01, 7 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   51.16667    0    1   35.00000   51.16667  46.2%     -    0s
# H    0     0                      50.0000000   51.16667  2.33%     -    0s
#      0     0   51.16667    0    1   50.00000   51.16667  2.33%     -    0s
#
# Explored 1 nodes (7 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 50 35
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.000000000000e+01, best bound 5.000000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 10 rows, 30 columns and 90 nonzeros
# Model fingerprint: 0x22926e89
# Variable types: 0 continuous, 30 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 18.0000000
# Presolve removed 0 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 10 rows, 28 columns, 84 nonzeros
# Variable types: 0 continuous, 28 integer (28 binary)
#
# Root relaxation: objective 4.416667e+01, 11 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   44.16667    0    7   18.00000   44.16667   145%     -    0s
# H    0     0                      42.0000000   44.16667  5.16%     -    0s
#      0     0   44.00000    0    5   42.00000   44.00000  4.76%     -    0s
#
# Cutting planes:
#   Clique: 1
#   GUB cover: 1
#
# Explored 1 nodes (13 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 42 18
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.200000000000e+01, best bound 4.200000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 10 rows, 31 columns and 93 nonzeros
# Model fingerprint: 0x24448e6d
# Variable types: 0 continuous, 31 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [4e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 35.0000000
# Presolve time: 0.00s
# Presolved: 10 rows, 31 columns, 93 nonzeros
# Variable types: 0 continuous, 31 integer (31 binary)
#
# Root relaxation: objective 4.590909e+01, 10 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   45.90909    0    1   35.00000   45.90909  31.2%     -    0s
# H    0     0                      45.0000000   45.90909  2.02%     -    0s
#      0     0   45.90909    0    1   45.00000   45.90909  2.02%     -    0s
#
# Explored 1 nodes (10 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 45 35
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.500000000000e+01, best bound 4.500000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 11 rows, 38 columns and 114 nonzeros
# Model fingerprint: 0x413c53e5
# Variable types: 0 continuous, 38 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [5e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 35.0000000
# Presolve time: 0.00s
# Presolved: 11 rows, 38 columns, 114 nonzeros
# Variable types: 0 continuous, 38 integer (38 binary)
#
# Root relaxation: objective 5.460000e+01, 9 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   54.60000    0    1   35.00000   54.60000  56.0%     -    0s
# H    0     0                      52.0000000   54.60000  5.00%     -    0s
#      0     0   54.60000    0    1   52.00000   54.60000  5.00%     -    0s
#
# Explored 1 nodes (9 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 52 35
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.200000000000e+01, best bound 5.200000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 11 rows, 35 columns and 105 nonzeros
# Model fingerprint: 0x1221397e
# Variable types: 0 continuous, 35 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [5e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 25.0000000
# Presolve time: 0.00s
# Presolved: 11 rows, 35 columns, 105 nonzeros
# Variable types: 0 continuous, 35 integer (35 binary)
#
# Root relaxation: objective 4.952941e+01, 5 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   49.52941    0    3   25.00000   49.52941  98.1%     -    0s
# H    0     0                      47.0000000   49.52941  5.38%     -    0s
#      0     0   49.00000    0    3   47.00000   49.00000  4.26%     -    0s
#
# Cutting planes:
#   Clique: 1
#
# Explored 1 nodes (7 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 47 25
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.700000000000e+01, best bound 4.700000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 11 rows, 31 columns and 93 nonzeros
# Model fingerprint: 0x66c5ffd5
# Variable types: 0 continuous, 31 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [5e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 23.0000000
# Presolve time: 0.00s
# Presolved: 11 rows, 31 columns, 93 nonzeros
# Variable types: 0 continuous, 31 integer (31 binary)
#
# Root relaxation: objective 5.272727e+01, 8 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   52.72727    0    1   23.00000   52.72727   129%     -    0s
# H    0     0                      49.0000000   52.72727  7.61%     -    0s
#
# Cutting planes:
#   Cover: 1
#
# Explored 1 nodes (8 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 49 23
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.900000000000e+01, best bound 4.900000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 11 rows, 35 columns and 105 nonzeros
# Model fingerprint: 0x3346f80a
# Variable types: 0 continuous, 35 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [5e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 19.0000000
# Presolve time: 0.00s
# Presolved: 11 rows, 35 columns, 105 nonzeros
# Variable types: 0 continuous, 35 integer (35 binary)
#
# Root relaxation: objective 5.700000e+01, 5 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      57.0000000   57.00000  0.00%     -    0s
#
# Explored 0 nodes (5 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 57 19
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.700000000000e+01, best bound 5.700000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 11 rows, 37 columns and 111 nonzeros
# Model fingerprint: 0x8c2059b9
# Variable types: 0 continuous, 37 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [4e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 47.0000000
# Presolve time: 0.00s
# Presolved: 11 rows, 37 columns, 111 nonzeros
# Variable types: 0 continuous, 37 integer (37 binary)
#
# Root relaxation: objective 7.500000e+01, 6 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# *    0     0               0      75.0000000   75.00000  0.00%     -    0s
#
# Explored 0 nodes (6 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 75 47
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.500000000000e+01, best bound 7.500000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 11 rows, 35 columns and 105 nonzeros
# Model fingerprint: 0xb9ab21d9
# Variable types: 0 continuous, 35 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [5e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 20.0000000
# Presolve time: 0.00s
# Presolved: 11 rows, 35 columns, 105 nonzeros
# Variable types: 0 continuous, 35 integer (35 binary)
#
# Root relaxation: objective 5.181818e+01, 8 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   51.81818    0    1   20.00000   51.81818   159%     -    0s
# H    0     0                      49.0000000   51.81818  5.75%     -    0s
#      0     0   51.55556    0    7   49.00000   51.55556  5.22%     -    0s
# *    0     0               0      51.0000000   51.00000  0.00%     -    0s
#
# Explored 1 nodes (12 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 51 49 35 20
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.100000000000e+01, best bound 5.100000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 11 rows, 36 columns and 108 nonzeros
# Model fingerprint: 0x70667e8a
# Variable types: 0 continuous, 36 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [6e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 23.0000000
# Presolve time: 0.00s
# Presolved: 11 rows, 36 columns, 108 nonzeros
# Variable types: 0 continuous, 36 integer (36 binary)
#
# Root relaxation: objective 5.818182e+01, 6 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   58.18182    0    1   23.00000   58.18182   153%     -    0s
# H    0     0                      49.0000000   58.18182  18.7%     -    0s
# H    0     0                      57.0000000   58.18182  2.07%     -    0s
# H    0     0                      58.0000000   58.18182  0.31%     -    0s
#
# Explored 1 nodes (6 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 58 57 49 23
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.800000000000e+01, best bound 5.800000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 11 rows, 31 columns and 93 nonzeros
# Model fingerprint: 0x66b5ae5f
# Variable types: 0 continuous, 31 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 32.0000000
# Presolve time: 0.00s
# Presolved: 11 rows, 31 columns, 93 nonzeros
# Variable types: 0 continuous, 31 integer (31 binary)
#
# Root relaxation: objective 5.600000e+01, 5 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      56.0000000   56.00000  0.00%     -    0s
#
# Explored 0 nodes (5 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 56 32
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.600000000000e+01, best bound 5.600000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 11 rows, 33 columns and 99 nonzeros
# Model fingerprint: 0x9d727447
# Variable types: 0 continuous, 33 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 29.0000000
# Presolve time: 0.00s
# Presolved: 11 rows, 33 columns, 99 nonzeros
# Variable types: 0 continuous, 33 integer (33 binary)
#
# Root relaxation: objective 5.600000e+01, 5 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      56.0000000   56.00000  0.00%     -    0s
#
# Explored 0 nodes (5 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 56 29
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.600000000000e+01, best bound 5.600000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 11 rows, 41 columns and 123 nonzeros
# Model fingerprint: 0x365b12e2
# Variable types: 0 continuous, 41 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [4e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 28.0000000
# Presolve time: 0.00s
# Presolved: 11 rows, 41 columns, 123 nonzeros
# Variable types: 0 continuous, 41 integer (41 binary)
#
# Root relaxation: objective 5.128571e+01, 13 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   51.28571    0    3   28.00000   51.28571  83.2%     -    0s
# H    0     0                      49.0000000   51.28571  4.66%     -    0s
#
# Cutting planes:
#   Cover: 1
#
# Explored 1 nodes (13 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 49 28
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.900000000000e+01, best bound 4.900000000000e+01, gap 0.0000%

# %%
'''
Test of budgeted matching dynamic program on sparse graphs using bitstrings
Results get saved in dict times_brute and times_gurobi
'''
import time
# Sparse Graphs
times_brute = {}
times_gurobi = {}
for n in range(2,11):
    running_time_bruteforce = 0
    running_time_gurobi = 0
    for i in range(10):
        g = generateRandomGraph(n, 2 / n, 10, 10)
        gurobi = graph_to_gurobi(g, 3*n)
        start = time.time()
        maximumMatchingDynamicBitstring(g, 3*n)
        end = time.time()
        running_time_bruteforce += end - start
        
        start = time.time()
        gurobi.optimize()
        end = time.time()
        running_time_gurobi += end - start
    times_brute[n] = running_time_bruteforce / 10
    times_gurobi[n] = running_time_gurobi / 10
# Out:
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0x9587d1d3
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [9e+00, 9e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0xded237b6
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+00]
#   Objective range  [1e+01, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0xd6cb45c0
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+01, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0xcb0dce65
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [9e+00, 9e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0xb870eace
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [8e+00, 8e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0x6887bb1e
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [9e+00, 9e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0x5589e8c1
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+00]
#   Objective range  [8e+00, 8e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0xd6cb45c0
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+01, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0x6c527ac1
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [1e+01, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0x0d4a9343
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+01, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0x0dca1351
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+00]
#   Objective range  [1e+01, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective 12.0000000
# Presolve removed 4 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 13 12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.300000000000e+01, best bound 1.300000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0xa36ad179
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+01, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective 12.0000000
# Presolve removed 4 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.200000000000e+01, best bound 1.200000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0xdf8c82df
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [8e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective 8.0000000
# Presolve removed 4 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.000000000000e+00, best bound 8.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0x6d0412e7
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+01, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 4 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0xcee61901
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [7e+00, 8e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 4 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0x8eba7c2e
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [7e+00, 9e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective 9.0000000
# Presolve removed 4 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.000000000000e+00, best bound 9.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0xa1ada68f
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+01, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective 11.0000000
# Presolve removed 4 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 11
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.100000000000e+01, best bound 1.100000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0x62151773
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [5e+00, 6e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 4 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0xc4786856
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [8e+00, 8e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective 8.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.000000000000e+00, best bound 8.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0x7d2b508c
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [6e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective 6.0000000
# Presolve removed 4 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.000000000000e+00, best bound 6.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0x4abb6f48
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [5e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 5.0000000
# Presolve removed 5 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 11 5
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.100000000000e+01, best bound 1.100000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0x6a736266
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [3e+00, 4e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 3.0000000
# Presolve removed 5 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 4 3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.000000000000e+00, best bound 4.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0x79316445
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [6e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 6.0000000
# Presolve removed 5 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 12 6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.200000000000e+01, best bound 1.200000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0x3d624281
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [8e+00, 9e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 8.0000000
# Presolve removed 5 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.000000000000e+00, best bound 8.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0x2f0e947a
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [6e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 14.0000000
# Presolve removed 5 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 14
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.400000000000e+01, best bound 1.400000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 4 columns and 12 nonzeros
# Model fingerprint: 0xddda9fc3
# Variable types: 0 continuous, 4 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [4e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 12.0000000
# Presolve removed 5 rows and 4 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.200000000000e+01, best bound 1.200000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0x43be2d6e
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [9e+00, 9e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 9.0000000
# Presolve removed 5 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.000000000000e+00, best bound 9.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0xef1bb91e
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [1e+01, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 10.0000000
# Presolve removed 5 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 17 10
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.700000000000e+01, best bound 1.700000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0x16f9fdb7
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [7e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 7.0000000
# Presolve removed 5 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.000000000000e+00, best bound 7.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0xd4d3d123
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [2e+01, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 15.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 15
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.500000000000e+01, best bound 1.500000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 4 columns and 12 nonzeros
# Model fingerprint: 0xa6c3cae2
# Variable types: 0 continuous, 4 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [7e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 14.0000000
# Presolve removed 6 rows and 4 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 14
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.400000000000e+01, best bound 1.400000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 8 columns and 24 nonzeros
# Model fingerprint: 0x769c9bf3
# Variable types: 0 continuous, 8 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 12.0000000
# Presolve removed 6 rows and 8 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.200000000000e+01, best bound 1.200000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0xa0b42886
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [9e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 9.0000000
# Presolve removed 6 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 14 9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.400000000000e+01, best bound 1.400000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0xd396dbe6
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [7e+00, 7e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 7.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.000000000000e+00, best bound 7.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 4 columns and 12 nonzeros
# Model fingerprint: 0x106e0b13
# Variable types: 0 continuous, 4 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [7e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 9.0000000
# Presolve removed 6 rows and 4 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 16 9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.600000000000e+01, best bound 1.600000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0xf41b4504
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [5e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 5.0000000
# Presolve removed 6 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 7 5
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.000000000000e+00, best bound 7.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 5 columns and 15 nonzeros
# Model fingerprint: 0xfd8cdf5c
# Variable types: 0 continuous, 5 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [9e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 9.0000000
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 12 9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.200000000000e+01, best bound 1.200000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0xd317f00d
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [7e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 10.0000000
# Presolve removed 6 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 10
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+01, best bound 1.000000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0x52c0cafe
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [8e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 8.0000000
# Presolve removed 6 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 13 8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.300000000000e+01, best bound 1.300000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 6 columns and 18 nonzeros
# Model fingerprint: 0x4cac511a
# Variable types: 0 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [7e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 22.0000000
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 22
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.200000000000e+01, best bound 2.200000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 4 columns and 12 nonzeros
# Model fingerprint: 0x3a99a314
# Variable types: 0 continuous, 4 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [7e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 15.0000000
# Presolve removed 7 rows and 4 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 22 15
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.200000000000e+01, best bound 2.200000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 4 columns and 12 nonzeros
# Model fingerprint: 0xd4ac5da4
# Variable types: 0 continuous, 4 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [7e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 18.0000000
# Presolve removed 7 rows and 4 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 18
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.800000000000e+01, best bound 1.800000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0xf7b16871
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [9e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 11.0000000
# Presolve removed 7 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 11
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.100000000000e+01, best bound 1.100000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 7 columns and 21 nonzeros
# Model fingerprint: 0x30e9ce18
# Variable types: 0 continuous, 7 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [4e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 8.0000000
# Presolve removed 7 rows and 7 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 18 8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.800000000000e+01, best bound 1.800000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 6 columns and 18 nonzeros
# Model fingerprint: 0x6f96cd32
# Variable types: 0 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [6e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 13.0000000
# Presolve removed 7 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 14 13
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.400000000000e+01, best bound 1.400000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 6 columns and 18 nonzeros
# Model fingerprint: 0xe56b36e4
# Variable types: 0 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [6e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 15.0000000
# Presolve removed 7 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 15
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.500000000000e+01, best bound 1.500000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 4 columns and 12 nonzeros
# Model fingerprint: 0xb4a5fff7
# Variable types: 0 continuous, 4 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [5e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 14.0000000
# Presolve removed 7 rows and 4 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 14
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.400000000000e+01, best bound 1.400000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0xdf5a9da5
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+01, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 23.0000000
# Presolve removed 7 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 23
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.300000000000e+01, best bound 2.300000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 5 columns and 15 nonzeros
# Model fingerprint: 0x3e43d085
# Variable types: 0 continuous, 5 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [7e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 27.0000000
# Presolve removed 7 rows and 5 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 27
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.700000000000e+01, best bound 2.700000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 7 columns and 21 nonzeros
# Model fingerprint: 0x614d7b85
# Variable types: 0 continuous, 7 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [6e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 20.0000000
# Presolve removed 7 rows and 7 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 26 20
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.600000000000e+01, best bound 2.600000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 8 rows, 6 columns and 18 nonzeros
# Model fingerprint: 0x3b4a83b4
# Variable types: 0 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [6e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 22.0000000
# Presolve removed 8 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 35 22
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.500000000000e+01, best bound 3.500000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 8 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0xccf1f5b3
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [6e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 25.0000000
# Presolve removed 8 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 25
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.500000000000e+01, best bound 2.500000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 8 rows, 5 columns and 15 nonzeros
# Model fingerprint: 0x221cd84f
# Variable types: 0 continuous, 5 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [7e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 20.0000000
# Presolve removed 8 rows and 5 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 23 20
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.300000000000e+01, best bound 2.300000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 8 rows, 7 columns and 21 nonzeros
# Model fingerprint: 0xfa61fa67
# Variable types: 0 continuous, 7 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [6e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 21.0000000
# Presolve removed 8 rows and 7 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 27 21
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.700000000000e+01, best bound 2.700000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 8 rows, 6 columns and 18 nonzeros
# Model fingerprint: 0x714f04ed
# Variable types: 0 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [5e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 17.0000000
# Presolve removed 8 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 17
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.700000000000e+01, best bound 1.700000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 8 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0xc90c6e11
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [9e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 19.0000000
# Presolve removed 8 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 19
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.900000000000e+01, best bound 1.900000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 8 rows, 7 columns and 21 nonzeros
# Model fingerprint: 0x6a9e6db0
# Variable types: 0 continuous, 7 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [5e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 22.0000000
# Presolve removed 8 rows and 7 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 23 22
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.300000000000e+01, best bound 2.300000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 8 rows, 5 columns and 15 nonzeros
# Model fingerprint: 0x115b09e9
# Variable types: 0 continuous, 5 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [7e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 24.0000000
# Presolve removed 8 rows and 5 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 27 24
#
# Optimal solution found (tolerance 1.00e-04)
# ...
# Best objective 2.000000000000e+01, best bound 2.000000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 10 rows, 8 columns and 24 nonzeros
# Model fingerprint: 0x061239af
# Variable types: 0 continuous, 8 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [9e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 36.0000000
# Presolve removed 4 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 6 rows, 7 columns, 18 nonzeros
# Variable types: 0 continuous, 7 integer (7 binary)
#
# Root relaxation: objective 4.400000e+01, 2 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   43.50000    0    1   36.00000   43.50000  20.8%     -    0s
# H    0     0                      37.0000000   43.50000  17.6%     -    0s
#      0     0     cutoff    0        37.00000   37.00000  0.00%     -    0s
#
# Cutting planes:
#   Cover: 1
#
# Explored 1 nodes (5 simplex iterations) in 0.02 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 37 36
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.700000000000e+01, best bound 3.700000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 10 rows, 7 columns and 21 nonzeros
# Model fingerprint: 0xe006283a
# Variable types: 0 continuous, 7 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [8e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 32.0000000
# Presolve removed 5 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 5 rows, 6 columns, 14 nonzeros
# Variable types: 0 continuous, 6 integer (6 binary)
#
# Root relaxation: objective 3.533333e+01, 3 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      34.0000000   34.00000  0.00%     -    0s
#
# Explored 0 nodes (5 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 34 32
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.400000000000e+01, best bound 3.400000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 10 rows, 8 columns and 24 nonzeros
# Model fingerprint: 0x2b80133b
# Variable types: 0 continuous, 8 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [3e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 19.0000000
# Presolve removed 10 rows and 8 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 26 19
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.600000000000e+01, best bound 2.600000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 10 rows, 5 columns and 15 nonzeros
# Model fingerprint: 0x9c9dea55
# Variable types: 0 continuous, 5 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [5e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 13.0000000
# Presolve removed 10 rows and 5 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 23 13
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.300000000000e+01, best bound 2.300000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 11 rows, 9 columns and 27 nonzeros
# Model fingerprint: 0x6176de66
# Variable types: 0 continuous, 9 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [6e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 25.0000000
# Presolve removed 5 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 6 rows, 6 columns, 15 nonzeros
# Found heuristic solution: objective 30.0000000
# Variable types: 0 continuous, 6 integer (6 binary)
#
# Root relaxation: objective 3.550000e+01, 3 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      32.0000000   32.00000  0.00%     -    0s
#
# Explored 0 nodes (4 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 32 30 25
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.200000000000e+01, best bound 3.200000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 11 rows, 20 columns and 60 nonzeros
# Model fingerprint: 0x932680d8
# Variable types: 0 continuous, 20 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [6e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 17.0000000
# Presolve removed 0 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 11 rows, 18 columns, 54 nonzeros
# Found heuristic solution: objective 40.0000000
# Variable types: 0 continuous, 18 integer (18 binary)
#
# Root relaxation: objective 4.857143e+01, 15 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   48.57143    0    3   40.00000   48.57143  21.4%     -    0s
# H    0     0                      47.0000000   48.57143  3.34%     -    0s
#      0     0   48.57143    0    3   47.00000   48.57143  3.34%     -    0s
#
# Explored 1 nodes (15 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 47 40 17
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.700000000000e+01, best bound 4.700000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 11 rows, 7 columns and 21 nonzeros
# Model fingerprint: 0xf369ec44
# Variable types: 0 continuous, 7 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [5e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 29.0000000
# Presolve removed 11 rows and 7 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 29
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.900000000000e+01, best bound 2.900000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 11 rows, 10 columns and 30 nonzeros
# Model fingerprint: 0xd3f89d5d
# Variable types: 0 continuous, 10 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [5e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 28.0000000
# Presolve removed 11 rows and 10 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 33 28
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.300000000000e+01, best bound 3.300000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 11 rows, 11 columns and 33 nonzeros
# Model fingerprint: 0x352396cd
# Variable types: 0 continuous, 11 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [5e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 29.0000000
# Presolve removed 5 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 6 rows, 8 columns, 21 nonzeros
# Found heuristic solution: objective 43.0000000
# Variable types: 0 continuous, 8 integer (8 binary)
#
# Root relaxation: cutoff, 2 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0        43.00000   43.00000  0.00%     -    0s
#
# Explored 0 nodes (2 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 43 29
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.300000000000e+01, best bound 4.300000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 11 rows, 9 columns and 27 nonzeros
# Model fingerprint: 0x63188b76
# Variable types: 0 continuous, 9 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [5e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 45.0000000
# Presolve removed 5 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 6 rows, 7 columns, 18 nonzeros
# Variable types: 0 continuous, 7 integer (7 binary)
#
# Root relaxation: cutoff, 2 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0        45.00000   45.00000  0.00%     -    0s
#
# Explored 0 nodes (2 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 45
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.500000000000e+01, best bound 4.500000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 11 rows, 7 columns and 21 nonzeros
# Model fingerprint: 0x6d4a5de8
# Variable types: 0 continuous, 7 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [6e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 15.0000000
# Presolve removed 6 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 5 rows, 5 columns, 12 nonzeros
# Found heuristic solution: objective 24.0000000
# Variable types: 0 continuous, 5 integer (5 binary)
#
# Root relaxation: objective 2.600000e+01, 3 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 infeasible    0        24.00000   24.00000  0.00%     -    0s
#
# Explored 0 nodes (3 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 24 15
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.400000000000e+01, best bound 2.400000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 11 rows, 8 columns and 24 nonzeros
# Model fingerprint: 0xcb32f5f0
# Variable types: 0 continuous, 8 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [4e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 19.0000000
# Presolve removed 8 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 5 columns, 9 nonzeros
# Variable types: 0 continuous, 5 integer (5 binary)
#
# Root relaxation: objective 3.200000e+01, 2 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      32.0000000   32.00000  0.00%     -    0s
#
# Explored 0 nodes (2 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 32 19
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.200000000000e+01, best bound 3.200000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 11 rows, 12 columns and 36 nonzeros
# Model fingerprint: 0x78884786
# Variable types: 0 continuous, 12 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [5e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 27.0000000
# Presolve removed 4 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 7 rows, 12 columns, 33 nonzeros
# Variable types: 0 continuous, 12 integer (12 binary)
#
# Root relaxation: objective 3.850000e+01, 5 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   38.50000    0    6   27.00000   38.50000  42.6%     -    0s
# H    0     0                      32.0000000   38.50000  20.3%     -    0s
# H    0     0                      36.0000000   38.50000  6.94%     -    0s
# H    0     0                      38.0000000   38.50000  1.32%     -    0s
#      0     0   38.50000    0    6   38.00000   38.50000  1.32%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 38 36 32 27
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.800000000000e+01, best bound 3.800000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 11 rows, 9 columns and 27 nonzeros
# Model fingerprint: 0x13091504
# Variable types: 0 continuous, 9 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [6e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 39.0000000
# Presolve removed 3 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 8 rows, 9 columns, 25 nonzeros
# Variable types: 0 continuous, 9 integer (9 binary)
#
# Root relaxation: cutoff, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0        39.00000   39.00000  0.00%     -    0s
#
# Explored 0 nodes (1 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 39
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.900000000000e+01, best bound 3.900000000000e+01, gap 0.0000%

# %%
# Plot results
# Source: https://stackoverflow.com/a/37266356/18307616
plt.figure(figsize=(15,9))
lists = sorted(times_brute_dense.items()) # sorted by key, return a list of tuples

x, y = zip(*lists) # unpack a list of pairs into two tuples

plt.plot(x, y)

lists = sorted(times_gurobi_dense.items())

x, y = zip(*lists) # unpack a list of pairs into two tuples

plt.plot(x, y)

lists = sorted(times_brute.items()) # sorted by key, return a list of tuples

x, y = zip(*lists) # unpack a list of pairs into two tuples

plt.plot(x, y)

lists = sorted(times_gurobi.items())

x, y = zip(*lists) # unpack a list of pairs into two tuples

plt.plot(x, y, 'x')

plt.legend(['Dynamic Dense', 'Gurobi Dense', 'Dynamic Sparse', 'Gurobi Sparse'], prop={'size':20})
plt.title("Running time of Dynamic Programming Algorithm, B=3n", size=28, weight='bold')
plt.xlabel("Number of vertices", size=20)
plt.ylabel("Running time (seconds)", size=20)
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.show()
