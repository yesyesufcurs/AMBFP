# %%
# import libraries needed
import networkx as nx
import random
import numpy as np
import math
from itertools import chain, combinations
from networkx.generators.random_graphs import erdos_renyi_graph
import matplotlib.pylab as plt

# %%
# Create new edge and set edge weight and cost
def setEdgeData(G, edge, weight, cost):
    G.add_edge(edge[0], edge[1])
    G[edge[0]][edge[1]]['weight'] = weight
    G[edge[0]][edge[1]]['cost'] = cost

def getEdgeCost(G, edge):
    return G[edge[0]][edge[1]]['cost']

def getEdgeWeight(G, edge):
    return G[edge[0]][edge[1]]['weight']

def zerotruncatedPoisson(p):
    #source: https://web.archive.org/web/20180826164029/http://giocc.com/zero_truncated_poisson_sampling_algorithm.html
    k = 1
    t = math.e**(-p) / (1 - math.e**(-p)) * p
    s = t
    u = random.random()
    while s < u:
        k += 1
        t *= p / k
        s += t
    return k

def isMatching(edges):
    # Check if set of edges is matching
    seen = []
    for e in edges:
        if e[0] in seen:
            return False
        seen.append(e[0])
        if e[1] in seen:
            return False
        seen.append(e[1])
    return True

def powerset(iterable, maxSize):
    "Source: https://docs.python.org/3/library/itertools.html#itertools-recipes"
    "powerset([1,2,3]) --> () (1,) (2,) (3,) (1,2) (1,3) (2,3) (1,2,3)"
    s = list(iterable)
    return chain.from_iterable(combinations(s, r) for r in range(maxSize+1))
def powersetAll(iterable):
    "Source: https://docs.python.org/3/library/itertools.html#itertools-recipes"
    "powerset([1,2,3]) --> () (1,) (2,) (3,) (1,2) (1,3) (2,3) (1,2,3)"
    s = list(iterable)
    return chain.from_iterable(combinations(s, r) for r in range(len(s)+1))



def generateRandomGraph(n, p, Ew, Ec):
    """
    Generates random graph using the Erdös-Rényi model.
    params
    n: number of vertices
    p: probability parameter Erdös-Rényi
    Ew: zero truncated poisson weight parameter
    Ec: poisson cost parameter
    """
    graph = erdos_renyi_graph(n,p)
    for edge in graph.edges:
        weight = 0
        cost = 0
        weight = zerotruncatedPoisson(Ew)
        cost = np.random.poisson(Ec)
        setEdgeData(graph, edge, weight, cost)
    return graph

# %%
def computeCost(g, matching):
    # compute cost of matching
    return sum(getEdgeCost(g, e) for e in matching)
def computeWeight(g, matching):
    # compute weight of matching
    return sum(getEdgeWeight(g, e) for e in matching)
def budgetedMatchingProblemBruteforce(g, B):
    # solve BMP by bruteforce
    maximum = 0
    cost = 0
    matching = None
    for e in powerset(g.edges, len(g.nodes)//2):
        if isMatching(e):
            c = computeCost(g, e)
            m = computeWeight(g, e)
            if c <= B and m > maximum:
                maximum = m
                matching = e
                cost = c
    return cost, maximum, matching

# %%
from gurobipy.gurobipy import Model, quicksum, GRB
def graph_to_gurobi(graph, budget):
    # Turn budgeted matching instance into linear program
    model = Model("Budgeted Matching Problem")
    x = {}
    edges = list(graph.edges)
    nodes = list(graph.nodes)
    for e in edges:
        x[e] = model.addVar(vtype=GRB.INTEGER, name=f'edge[{e}]', lb = 0, ub=1)
    model.addConstrs(
        (quicksum(x[e] for e in edges if v in e) <= 1 for v in nodes),
        name='Satisfy Matching'
    )
    model.addConstr(
        quicksum(x[e] * getEdgeCost(graph, e) for e in edges) <= budget,
        name='Satisfy Budget'
    )
    model.setObjective(
        quicksum(x[e] * getEdgeWeight(graph, e) for e in edges),
        sense=GRB.MAXIMIZE
    )
    return model

# %%
'''
Test of budgeted matching bruteforce on dense graphs
Results get saved in dict times_brute_dense and times_gurobi_dense
'''
import time
times_brute_dense = {}
times_gurobi_dense = {}
for n in range(2,13):
    running_time_bruteforce = 0
    running_time_gurobi = 0
    for i in range(10):
        g = generateRandomGraph(n, 0.8, 10, 10)
        gurobi = graph_to_gurobi(g, 3*n)
        start = time.time()
        budgetedMatchingProblemBruteforce(g, 3*n)
        end = time.time()
        running_time_bruteforce += end - start
        
        start = time.time()
        gurobi.optimize()
        end = time.time()
        running_time_gurobi += end - start
    times_brute_dense[n] = running_time_bruteforce / 10
    times_gurobi_dense[n] = running_time_gurobi / 10
# Out:
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0x9350680c
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [6e+00, 6e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0x51bc1007
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+01, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 0 columns and 0 nonzeros
# Model fingerprint: 0x003196a4
# Coefficient statistics:
#   Matrix range     [0e+00, 0e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 3 rows and 0 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds
# Optimal objective -0.000000000e+00
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0xe00324d5
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+01, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0x45b3201c
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+00]
#   Objective range  [8e+00, 8e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0x14e5308e
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+01, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0x3b4f89f7
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+00]
#   Objective range  [2e+01, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0x94794170
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [7e+00, 7e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0x62b4ff7e
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [6e+00, 6e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0x196b7266
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+01, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0x66c879f7
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [9e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective 15.0000000
# Presolve removed 4 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 15
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.500000000000e+01, best bound 1.500000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0xb6fc8b3c
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [9e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective 9.0000000
# Presolve removed 4 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.000000000000e+00, best bound 9.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0x2592bd51
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+01, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective 11.0000000
# Presolve removed 4 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 11
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.100000000000e+01, best bound 1.100000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0xee8fe302
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [4e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective 4.0000000
# Presolve removed 4 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 11 4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.100000000000e+01, best bound 1.100000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0x810ff07f
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [9e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective 11.0000000
# Presolve removed 4 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 11
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.100000000000e+01, best bound 1.100000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0xf63fc253
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [2e+01, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 4 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0xda17f7f3
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+01, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective 11.0000000
# Presolve removed 4 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 11
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.100000000000e+01, best bound 1.100000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0x25209533
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+01, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective 10.0000000
# Presolve removed 4 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 10
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+01, best bound 1.000000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0x9f9e5525
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+01, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective 12.0000000
# Presolve removed 4 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.200000000000e+01, best bound 1.200000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0x316d33fb
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [8e+00, 9e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective 9.0000000
# Presolve removed 4 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.000000000000e+00, best bound 9.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 5 columns and 15 nonzeros
# Model fingerprint: 0xd4457b4f
# Variable types: 0 continuous, 5 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [8e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 11.0000000
# Presolve removed 5 rows and 5 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 20 11
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+01, best bound 2.000000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 5 columns and 15 nonzeros
# Model fingerprint: 0xac1044c1
# Variable types: 0 continuous, 5 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [7e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 8.0000000
# Presolve removed 5 rows and 5 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 14 8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.400000000000e+01, best bound 1.400000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 6 columns and 18 nonzeros
# Model fingerprint: 0xf7c5b52b
# Variable types: 0 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [8e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 12.0000000
# Presolve removed 5 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 15 12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.500000000000e+01, best bound 1.500000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 5 columns and 15 nonzeros
# Model fingerprint: 0xaeeb1d6e
# Variable types: 0 continuous, 5 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [7e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 7.0000000
# Presolve removed 5 rows and 5 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 15 7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.500000000000e+01, best bound 1.500000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 6 columns and 18 nonzeros
# Model fingerprint: 0x7accd144
# Variable types: 0 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [7e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 12.0000000
# Presolve removed 5 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.200000000000e+01, best bound 1.200000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 6 columns and 18 nonzeros
# Model fingerprint: 0xaab65f70
# Variable types: 0 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [5e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 7.0000000
# Presolve removed 5 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 11 7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.100000000000e+01, best bound 1.100000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 4 columns and 12 nonzeros
# Model fingerprint: 0xd8e54553
# Variable types: 0 continuous, 4 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [8e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 9.0000000
# Presolve removed 5 rows and 4 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 11 9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.100000000000e+01, best bound 1.100000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 5 columns and 15 nonzeros
# Model fingerprint: 0x4815bd80
# Variable types: 0 continuous, 5 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [7e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 7.0000000
# Presolve removed 5 rows and 5 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 12 7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.200000000000e+01, best bound 1.200000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 6 columns and 18 nonzeros
# Model fingerprint: 0x5daacd22
# Variable types: 0 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [6e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 7.0000000
# Presolve removed 5 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 11 7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.100000000000e+01, best bound 1.100000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 6 columns and 18 nonzeros
# Model fingerprint: 0x71c55245
# Variable types: 0 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [8e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 11.0000000
# Presolve removed 5 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 15 11
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.500000000000e+01, best bound 1.500000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 7 columns and 21 nonzeros
# Model fingerprint: 0xd7c25890
# Variable types: 0 continuous, 7 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [6e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 10.0000000
# Presolve removed 6 rows and 7 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 26 10
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.600000000000e+01, best bound 2.600000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 5 columns and 15 nonzeros
# Model fingerprint: 0xb4aa7406
# Variable types: 0 continuous, 5 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [8e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 12.0000000
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.200000000000e+01, best bound 1.200000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 6 columns and 18 nonzeros
# Model fingerprint: 0xd4bbbebf
# Variable types: 0 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [7e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 9.0000000
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 11 9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.100000000000e+01, best bound 1.100000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 10 columns and 30 nonzeros
# Model fingerprint: 0x3e0c0ffa
# Variable types: 0 continuous, 10 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [6e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 13.0000000
# Presolve removed 6 rows and 10 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 24 13
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.400000000000e+01, best bound 2.400000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 7 columns and 21 nonzeros
# Model fingerprint: 0x5405662f
# Variable types: 0 continuous, 7 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [5e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 11.0000000
# Presolve removed 6 rows and 7 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 14 11
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.400000000000e+01, best bound 1.400000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 8 columns and 24 nonzeros
# Model fingerprint: 0x00048eec
# Variable types: 0 continuous, 8 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [4e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 7.0000000
# Presolve removed 6 rows and 8 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 22 7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.200000000000e+01, best bound 2.200000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 8 columns and 24 nonzeros
# Model fingerprint: 0x7292b5c0
# Variable types: 0 continuous, 8 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [8e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 8.0000000
# Presolve removed 6 rows and 8 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 20 8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+01, best bound 2.000000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 10 columns and 30 nonzeros
# Model fingerprint: 0x9f8851a5
# Variable types: 0 continuous, 10 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [4e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 14.0000000
# Presolve removed 6 rows and 10 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 15 14
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.500000000000e+01, best bound 1.500000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 6 columns and 18 nonzeros
# Model fingerprint: 0x2e35cec4
# Variable types: 0 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [6e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 6.0000000
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 11 6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.100000000000e+01, best bound 1.100000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 7 columns and 21 nonzeros
# Model fingerprint: 0x59b8b2ed
# Variable types: 0 continuous, 7 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [6e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 10.0000000
# Presolve removed 6 rows and 7 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 15 10
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.500000000000e+01, best bound 1.500000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 10 columns and 30 nonzeros
# Model fingerprint: 0xe785fd03
# Variable types: 0 continuous, 10 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [6e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 21.0000000
# Presolve removed 0 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 7 rows, 8 columns, 25 nonzeros
# Variable types: 0 continuous, 8 integer (8 binary)
#
# Root relaxation: objective 2.600000e+01, 3 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   26.00000    0    1   21.00000   26.00000  23.8%     -    0s
# H    0     0                      23.0000000   26.00000  13.0%     -    0s
#      0     0     cutoff    0        23.00000   23.00000  0.00%     -    0s
#
# Cutting planes:
#   Cover: 1
#   GUB cover: 1
#
# Explored 1 nodes (3 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 23 21
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.300000000000e+01, best bound 2.300000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 8 columns and 24 nonzeros
# Model fingerprint: 0x39daa1d1
# Variable types: 0 continuous, 8 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [4e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 11.0000000
# Presolve removed 7 rows and 8 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 23 11
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.300000000000e+01, best bound 2.300000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 11 columns and 33 nonzeros
# Model fingerprint: 0xa8e6d3eb
# Variable types: 0 continuous, 11 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [6e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 11.0000000
# Presolve removed 7 rows and 11 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 22 11
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.200000000000e+01, best bound 2.200000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 12 columns and 36 nonzeros
# Model fingerprint: 0xd7b702ca
# Variable types: 0 continuous, 12 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [5e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 15.0000000
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 6 rows, 6 columns, 18 nonzeros
# Variable types: 0 continuous, 6 integer (6 binary)
#
# Root relaxation: objective 2.700000e+01, 2 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      27.0000000   27.00000  0.00%     -    0s
#
# Explored 0 nodes (2 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 27 15
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.700000000000e+01, best bound 2.700000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 13 columns and 39 nonzeros
# Model fingerprint: 0xe5891033
# Variable types: 0 continuous, 13 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [4e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 29.0000000
# Presolve removed 4 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 4 columns, 8 nonzeros
# Variable types: 0 continuous, 4 integer (4 binary)
#
# Root relaxation: cutoff, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0        29.00000   29.00000  0.00%     -    0s
#
# Explored 0 nodes (1 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 29
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.900000000000e+01, best bound 2.900000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 12 columns and 36 nonzeros
# Model fingerprint: 0xa50ae17c
# Variable types: 0 continuous, 12 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [9e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 19.0000000
# Presolve removed 0 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 7 rows, 9 columns, 27 nonzeros
# Variable types: 0 continuous, 9 integer (9 binary)
#
# Root relaxation: objective 2.962500e+01, 7 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   29.62500    0    4   19.00000   29.62500  55.9%     -    0s
# H    0     0                      25.0000000   29.62500  18.5%     -    0s
#      0     0   27.33333    0    3   25.00000   27.33333  9.33%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   GUB cover: 1
#
# Explored 1 nodes (11 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 25 19
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.500000000000e+01, best bound 2.500000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 14 columns and 42 nonzeros
# Model fingerprint: 0xe59b9af9
# Variable types: 0 continuous, 14 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [2e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 16.0000000
# Presolve removed 0 rows and 4 columns
# Presolve time: 0.00s
# Presolved: 7 rows, 10 columns, 31 nonzeros
# Found heuristic solution: objective 29.0000000
# Variable types: 0 continuous, 10 integer (10 binary)
#
# Root relaxation: objective 3.175000e+01, 4 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 infeasible    0        29.00000   29.00000  0.00%     -    0s
#
# Explored 0 nodes (4 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 29 16
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.900000000000e+01, best bound 2.900000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 10 columns and 30 nonzeros
# Model fingerprint: 0xb9a76650
# Variable types: 0 continuous, 10 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [5e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 21.0000000
# Presolve removed 7 rows and 10 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 26 21
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.600000000000e+01, best bound 2.600000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 11 columns and 33 nonzeros
# Model fingerprint: 0xfa8d08f6
# Variable types: 0 continuous, 11 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 14.0000000
# Presolve removed 7 rows and 11 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 14
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.400000000000e+01, best bound 1.400000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 11 columns and 33 nonzeros
# Model fingerprint: 0xda4aee54
# Variable types: 0 continuous, 11 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 19.0000000
# Presolve removed 3 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 4 rows, 5 columns, 12 nonzeros
# Found heuristic solution: objective 19.0000000
# Variable types: 0 continuous, 5 integer (5 binary)
#
# Root relaxation: objective 2.200000e+01, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      22.0000000   22.00000  0.00%     -    0s
#
# Explored 0 nodes (1 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 22 19 19
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.200000000000e+01, best bound 2.200000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 8 rows, 12 columns and 36 nonzeros
# Model fingerprint: 0x4f43f2db
# Variable types: 0 continuous, 12 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [7e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 18.0000000
# Presolve removed 3 rows and 7 columns
# Presolve time: 0.00s
# Presolved: 5 rows, 5 columns, 13 nonzeros
# Variable types: 0 continuous, 5 integer (5 binary)
#
# Root relaxation: objective 2.500000e+01, 2 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      25.0000000   25.00000  0.00%     -    0s
#
# Explored 0 nodes (2 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 25 18
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.500000000000e+01, best bound 2.500000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 8 rows, 16 columns and 48 nonzeros
# Model fingerprint: 0x09a0d57a
# Variable types: 0 continuous, 16 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [6e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 29.0000000
# Presolve time: 0.00s
# Presolved: 8 rows, 16 columns, 49 nonzeros
# Variable types: 0 continuous, 16 integer (16 binary)
#
# Root relaxation: objective 3.677778e+01, 6 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      34.0000000   34.00000  0.00%     -    0s
#
# Explored 0 nodes (11 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 34 29
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.400000000000e+01, best bound 3.400000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 8 rows, 19 columns and 57 nonzeros
# Model fingerprint: 0x760c1764
# Variable types: 0 continuous, 19 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [4e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 21.0000000
# Presolve removed 0 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 8 rows, 14 columns, 43 nonzeros
# Variable types: 0 continuous, 14 integer (14 binary)
#
# Root relaxation: objective 3.180000e+01, 5 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   31.80000    0    1   21.00000   31.80000  51.4%     -    0s
# H    0     0                      31.0000000   31.80000  2.58%     -    0s
#      0     0   31.80000    0    1   31.00000   31.80000  2.58%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 31 21
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.100000000000e+01, best bound 3.100000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# ...
# Model fingerprint: 0x726530cd
# Variable types: 0 continuous, 46 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 28.0000000
# Presolve time: 0.00s
# Presolved: 12 rows, 46 columns, 138 nonzeros
# Variable types: 0 continuous, 46 integer (46 binary)
#
# Root relaxation: objective 7.000000e+01, 9 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      70.0000000   70.00000  0.00%     -    0s
#
# Explored 0 nodes (9 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 70 28
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.000000000000e+01, best bound 7.000000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 12 rows, 43 columns and 129 nonzeros
# Model fingerprint: 0x47035afc
# Variable types: 0 continuous, 43 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [4e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 32.0000000
# Presolve time: 0.00s
# Presolved: 12 rows, 43 columns, 129 nonzeros
# Variable types: 0 continuous, 43 integer (43 binary)
#
# Root relaxation: objective 5.128571e+01, 15 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   51.28571    0    5   32.00000   51.28571  60.3%     -    0s
# H    0     0                      49.0000000   51.28571  4.66%     -    0s
#      0     0     cutoff    0        49.00000   49.00000  0.00%     -    0s
#
# Cutting planes:
#   StrongCG: 1
#   Zero half: 1
#
# Explored 1 nodes (16 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 49 32
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.900000000000e+01, best bound 4.900000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 13 rows, 60 columns and 180 nonzeros
# Model fingerprint: 0x69a0684b
# Variable types: 0 continuous, 60 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [4e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+01]
# Found heuristic solution: objective 30.0000000
# Presolve time: 0.00s
# Presolved: 13 rows, 60 columns, 180 nonzeros
# Variable types: 0 continuous, 60 integer (60 binary)
#
# Root relaxation: objective 6.823077e+01, 4 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   68.23077    0    4   30.00000   68.23077   127%     -    0s
# H    0     0                      67.0000000   68.23077  1.84%     -    0s
#      0     0   68.23077    0    4   67.00000   68.23077  1.84%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 67 30
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.700000000000e+01, best bound 6.700000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 13 rows, 51 columns and 153 nonzeros
# Model fingerprint: 0xe5ad5a5d
# Variable types: 0 continuous, 51 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [4e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+01]
# Found heuristic solution: objective 41.0000000
# Presolve time: 0.00s
# Presolved: 13 rows, 51 columns, 153 nonzeros
# Variable types: 0 continuous, 51 integer (51 binary)
#
# Root relaxation: objective 7.677500e+01, 14 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   76.77500    0    8   41.00000   76.77500  87.3%     -    0s
# H    0     0                      72.0000000   76.77500  6.63%     -    0s
# H    0     0                      76.0000000   76.77500  1.02%     -    0s
#      0     0   76.77500    0    8   76.00000   76.77500  1.02%     -    0s
#
# Explored 1 nodes (14 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 76 72 41
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.600000000000e+01, best bound 7.600000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 13 rows, 50 columns and 150 nonzeros
# Model fingerprint: 0xbe44181a
# Variable types: 0 continuous, 50 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [2e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+01]
# Found heuristic solution: objective 42.0000000
# Presolve time: 0.00s
# Presolved: 13 rows, 50 columns, 150 nonzeros
# Variable types: 0 continuous, 50 integer (50 binary)
#
# Root relaxation: objective 6.491667e+01, 11 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   64.91667    0    1   42.00000   64.91667  54.6%     -    0s
# H    0     0                      61.0000000   64.91667  6.42%     -    0s
# H    0     0                      62.0000000   64.91667  4.70%     -    0s
# H    0     0                      64.0000000   64.91667  1.43%     -    0s
#      0     0   64.91667    0    1   64.00000   64.91667  1.43%     -    0s
#
# Explored 1 nodes (11 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 64 62 61 42
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.400000000000e+01, best bound 6.400000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 13 rows, 53 columns and 159 nonzeros
# Model fingerprint: 0x3b5ce8b4
# Variable types: 0 continuous, 53 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [4e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+01]
# Found heuristic solution: objective 29.0000000
# Presolve time: 0.00s
# Presolved: 13 rows, 53 columns, 159 nonzeros
# Variable types: 0 continuous, 53 integer (53 binary)
#
# Root relaxation: objective 6.763636e+01, 10 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   67.63636    0    6   29.00000   67.63636   133%     -    0s
# H    0     0                      64.0000000   67.63636  5.68%     -    0s
# H    0     0                      67.0000000   67.63636  0.95%     -    0s
#      0     0   67.63636    0    6   67.00000   67.63636  0.95%     -    0s
#
# Explored 1 nodes (10 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 67 64 29
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.700000000000e+01, best bound 6.700000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 13 rows, 55 columns and 165 nonzeros
# Model fingerprint: 0x8a2fd56f
# Variable types: 0 continuous, 55 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [5e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+01]
# Found heuristic solution: objective 51.0000000
# Presolve time: 0.00s
# Presolved: 13 rows, 55 columns, 165 nonzeros
# Variable types: 0 continuous, 55 integer (55 binary)
#
# Root relaxation: objective 7.633333e+01, 8 iterations, 0.00 seconds
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   76.33333    0    1   51.00000   76.33333  49.7%     -    0s
# H    0     0                      71.0000000   76.33333  7.51%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 1
#   MIR: 1
#   StrongCG: 1
#   GUB cover: 1
#
# Explored 1 nodes (8 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 71 51
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.100000000000e+01, best bound 7.100000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 13 rows, 58 columns and 174 nonzeros
# Model fingerprint: 0x538dfc9f
# Variable types: 0 continuous, 58 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+01]
# Found heuristic solution: objective 61.0000000
# Presolve time: 0.00s
# Presolved: 13 rows, 58 columns, 174 nonzeros
# Variable types: 0 continuous, 58 integer (58 binary)
#
# Root relaxation: objective 8.175000e+01, 12 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   81.75000    0    4   61.00000   81.75000  34.0%     -    0s
# H    0     0                      74.0000000   81.75000  10.5%     -    0s
# H    0     0                      81.0000000   81.75000  0.93%     -    0s
#      0     0   81.75000    0    4   81.00000   81.75000  0.93%     -    0s
#
# Explored 1 nodes (12 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 81 74 61
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.100000000000e+01, best bound 8.100000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 13 rows, 53 columns and 159 nonzeros
# Model fingerprint: 0xcedfa5ca
# Variable types: 0 continuous, 53 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [4e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+01]
# Found heuristic solution: objective 31.0000000
# Presolve time: 0.00s
# Presolved: 13 rows, 53 columns, 159 nonzeros
# Variable types: 0 continuous, 53 integer (53 binary)
#
# Root relaxation: objective 6.325000e+01, 15 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   63.25000    0    4   31.00000   63.25000   104%     -    0s
# H    0     0                      59.0000000   63.25000  7.20%     -    0s
# H    0     0                      62.0000000   63.25000  2.02%     -    0s
#
# Cutting planes:
#   Gomory: 1
#
# Explored 1 nodes (15 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 62 59 31
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.200000000000e+01, best bound 6.200000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 13 rows, 55 columns and 165 nonzeros
# Model fingerprint: 0xacf30324
# Variable types: 0 continuous, 55 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [5e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+01]
# Found heuristic solution: objective 38.0000000
# Presolve time: 0.00s
# Presolved: 13 rows, 55 columns, 165 nonzeros
# Variable types: 0 continuous, 55 integer (55 binary)
#
# Root relaxation: objective 6.780000e+01, 11 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   67.80000    0    1   38.00000   67.80000  78.4%     -    0s
# H    0     0                      63.0000000   67.80000  7.62%     -    0s
# H    0     0                      65.0000000   67.80000  4.31%     -    0s
#      0     0   67.16667    0    8   65.00000   67.16667  3.33%     -    0s
#
# Cutting planes:
#   Cover: 1
#
# Explored 1 nodes (14 simplex iterations) in 0.02 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 65 63 38
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.500000000000e+01, best bound 6.500000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 13 rows, 51 columns and 153 nonzeros
# Model fingerprint: 0xd48d8346
# Variable types: 0 continuous, 51 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [5e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+01]
# Found heuristic solution: objective 29.0000000
# Presolve time: 0.00s
# Presolved: 13 rows, 51 columns, 153 nonzeros
# Variable types: 0 continuous, 51 integer (51 binary)
#
# Root relaxation: objective 6.392000e+01, 12 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   63.92000    0    7   29.00000   63.92000   120%     -    0s
# H    0     0                      63.0000000   63.92000  1.46%     -    0s
#      0     0   63.92000    0    7   63.00000   63.92000  1.46%     -    0s
#
# Explored 1 nodes (12 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 63 29
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.300000000000e+01, best bound 6.300000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 13 rows, 47 columns and 141 nonzeros
# Model fingerprint: 0xf555fdd7
# Variable types: 0 continuous, 47 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [5e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+01]
# Found heuristic solution: objective 45.0000000
# Presolve time: 0.00s
# Presolved: 13 rows, 47 columns, 141 nonzeros
# Variable types: 0 continuous, 47 integer (47 binary)
#
# Root relaxation: objective 6.337500e+01, 16 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   63.37500    0    6   45.00000   63.37500  40.8%     -    0s
# H    0     0                      58.0000000   63.37500  9.27%     -    0s
# H    0     0                      61.0000000   63.37500  3.89%     -    0s
# H    0     0                      62.0000000   63.37500  2.22%     -    0s
#
# Cutting planes:
#   Zero half: 1
#
# Explored 1 nodes (16 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 62 61 58 45
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.200000000000e+01, best bound 6.200000000000e+01, gap 0.0000%

# %%
# Plot results
# Source: https://stackoverflow.com/a/37266356/18307616
plt.figure(figsize=(15,9))
lists = sorted(times_brute_dense.items()) # sorted by key, return a list of tuples

x, y = zip(*lists) # unpack a list of pairs into two tuples

plt.plot(x, y)

lists = sorted(times_gurobi_dense.items()) # sorted by key, return a list of tuples

x, y = zip(*lists) # unpack a list of pairs into two tuples

plt.plot(x, y)

plt.legend(['Brute Force', 'Gurobi'], prop={'size':20})
plt.title("Running time of Brute Force Algorithm on dense graphs", size=28, weight='bold')
plt.xlabel("Number of vertices", size=20)
plt.ylabel("Running time (seconds)", size=20)
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.show()

# %%
'''
Test of budgeted matching bruteforce on sparse graphs
Results get saved in dict times_brute and times_gurobi
'''
import time
# Sparse Graphs
times_brute = {}
times_gurobi = {}
for n in range(2,22):
    running_time_bruteforce = 0
    running_time_gurobi = 0
    for i in range(10):
        g = generateRandomGraph(n, 2 / n, 10, 10)
        gurobi = graph_to_gurobi(g, 10*n)
        start = time.time()
        budgetedMatchingProblemBruteforce(g, 10*n)
        end = time.time()
        running_time_bruteforce += end - start
        
        start = time.time()
        gurobi.optimize()
        end = time.time()
        running_time_gurobi += end - start
    times_brute[n] = running_time_bruteforce / 10
    times_gurobi[n] = running_time_gurobi / 10
# Out:
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0xc94c2eed
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+01, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 12.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.200000000000e+01, best bound 1.200000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0x37828aae
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [9e+00, 9e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 9.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.000000000000e+00, best bound 9.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0x0702f0f4
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [9e+00, 9e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 9.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.000000000000e+00, best bound 9.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0x00a6eae8
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [6e+00, 6e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 6.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.000000000000e+00, best bound 6.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0x63ab403b
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [5e+00, 5e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 5.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 5
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.000000000000e+00, best bound 5.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0x0ef06988
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [2e+01, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 15.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 15
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.500000000000e+01, best bound 1.500000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0x53d28b38
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [5e+00, 5e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 5.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 5
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.000000000000e+00, best bound 5.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0x9abe1355
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+00]
#   Objective range  [1e+01, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 11.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 11
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.100000000000e+01, best bound 1.100000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0x431507aa
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [7e+00, 7e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 7.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.000000000000e+00, best bound 7.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0x86a7d134
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+00]
#   Objective range  [1e+01, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 10.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 10
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+01, best bound 1.000000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0xba4ec2dc
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [9e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 9.0000000
# Presolve removed 4 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 11 9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.100000000000e+01, best bound 1.100000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0x231850fe
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [5e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 5.0000000
# Presolve removed 4 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 11 5
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.100000000000e+01, best bound 1.100000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0xcec91293
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [7e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 7.0000000
# Presolve removed 4 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 14 7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.400000000000e+01, best bound 1.400000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0x046859d6
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [7e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 7.0000000
# Presolve removed 4 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 10 7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+01, best bound 1.000000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0x613aae39
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [7e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 7.0000000
# Presolve removed 4 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 10 7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+01, best bound 1.000000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0x85ab92c4
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [7e+00, 7e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 7.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.000000000000e+00, best bound 7.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0xba11135c
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+00]
#   Objective range  [7e+00, 7e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 7.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.000000000000e+00, best bound 7.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0xdbb9c3a8
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [8e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 8.0000000
# Presolve removed 4 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 14 8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.400000000000e+01, best bound 1.400000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0x5ce4c795
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [4e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 4.0000000
# Presolve removed 4 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 10 4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+01, best bound 1.000000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0x31bdd8c0
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [8e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 12.0000000
# Presolve removed 4 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 16 12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.600000000000e+01, best bound 1.600000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0x6902b5cb
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [7e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+01]
# Found heuristic solution: objective 13.0000000
# Presolve removed 5 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 13
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.300000000000e+01, best bound 1.300000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0x96ac6cdd
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [6e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+01]
# Found heuristic solution: objective 6.0000000
# Presolve removed 5 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 14 6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.400000000000e+01, best bound 1.400000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0x1bf372f1
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [5e+00, 9e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+01]
# Found heuristic solution: objective 18.0000000
# Presolve removed 5 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 18
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.800000000000e+01, best bound 1.800000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0x6dc81b57
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [8e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+01]
# Found heuristic solution: objective 18.0000000
# Presolve removed 5 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 18
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.800000000000e+01, best bound 1.800000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0x38929cd6
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [8e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+01]
# Found heuristic solution: objective 17.0000000
# Presolve removed 5 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 17
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.700000000000e+01, best bound 1.700000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0xee0f4ab1
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [4e+00, 8e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+01]
# Found heuristic solution: objective 12.0000000
# Presolve removed 5 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.200000000000e+01, best bound 1.200000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0x1bf5d0ca
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [8e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+01]
# Found heuristic solution: objective 25.0000000
# Presolve removed 5 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 25
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.500000000000e+01, best bound 2.500000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0x8167c942
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [9e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+01]
# Found heuristic solution: objective 22.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 22
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.200000000000e+01, best bound 2.200000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0x06ba2cbf
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+00]
#   Objective range  [7e+00, 7e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+01]
# Found heuristic solution: objective 7.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.000000000000e+00, best bound 7.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 5 columns and 15 nonzeros
# Model fingerprint: 0x158f3b0e
# Variable types: 0 continuous, 5 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+01, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+01]
# Found heuristic solution: objective 22.0000000
# Presolve removed 1 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 4 rows, 4 columns, 8 nonzeros
# Variable types: 0 continuous, 4 integer (4 binary)
#
# Root relaxation: objective 3.000000e+01, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      30.0000000   30.00000  0.00%     -    0s
#
# Explored 0 nodes (1 simplex iterations) in 0.02 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 30 22
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.000000000000e+01, best bound 3.000000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0x9816edcf
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [9e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
# Found heuristic solution: objective 9.0000000
# Presolve removed 6 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 12 9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.200000000000e+01, best bound 1.200000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 5 columns and 15 nonzeros
# Model fingerprint: 0x30c39694
# Variable types: 0 continuous, 5 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [7e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
# Found heuristic solution: objective 22.0000000
# Presolve removed 2 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 4 rows, 4 columns, 8 nonzeros
# Variable types: 0 continuous, 4 integer (4 binary)
#
# Root relaxation: objective 2.600000e+01, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      26.0000000   26.00000  0.00%     -    0s
#
# Explored 0 nodes (1 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 26 22
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.600000000000e+01, best bound 2.600000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 9 columns and 27 nonzeros
# Model fingerprint: 0x7684200e
# Variable types: 0 continuous, 9 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
# Found heuristic solution: objective 26.0000000
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 5 rows, 9 columns, 18 nonzeros
# Variable types: 0 continuous, 9 integer (9 binary)
#
# Root relaxation: objective 3.400000e+01, 5 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   34.00000    0    5   26.00000   34.00000  30.8%     -    0s
# H    0     0                      30.0000000   34.00000  13.3%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 30 26
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.000000000000e+01, best bound 3.000000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0x47837edc
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [5e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
# Found heuristic solution: objective 5.0000000
# Presolve removed 6 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 16 5
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.600000000000e+01, best bound 1.600000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 8 columns and 24 nonzeros
# Model fingerprint: 0xf0d167e2
# Variable types: 0 continuous, 8 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [5e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
# Found heuristic solution: objective 12.0000000
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 5 rows, 8 columns, 16 nonzeros
# Variable types: 0 continuous, 8 integer (8 binary)
#
# Root relaxation: objective 2.800000e+01, 3 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   28.00000    0    3   12.00000   28.00000   133%     -    0s
# H    0     0                      24.0000000   28.00000  16.7%     -    0s
#
# Cutting planes:
#   Clique: 1
#
# Explored 1 nodes (3 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 24 12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.400000000000e+01, best bound 2.400000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 4 columns and 12 nonzeros
# Model fingerprint: 0x3a08f26c
# Variable types: 0 continuous, 4 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [6e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
# Found heuristic solution: objective 22.0000000
# Presolve removed 6 rows and 4 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 23 22
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.300000000000e+01, best bound 2.300000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 4 columns and 12 nonzeros
# Model fingerprint: 0x9b010547
# Variable types: 0 continuous, 4 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [7e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
# Found heuristic solution: objective 22.0000000
# Presolve removed 6 rows and 4 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 22
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.200000000000e+01, best bound 2.200000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 5 columns and 15 nonzeros
# Model fingerprint: 0xb9da9e95
# Variable types: 0 continuous, 5 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [7e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
# Found heuristic solution: objective 23.0000000
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 23
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.300000000000e+01, best bound 2.300000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0x681188ab
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [6e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
# Found heuristic solution: objective 20.0000000
# Presolve removed 6 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 20
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+01, best bound 2.000000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0x7ea559d1
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [8e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
# Found heuristic solution: objective 11.0000000
# Presolve removed 6 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 11
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.100000000000e+01, best bound 1.100000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 6 columns and 18 nonzeros
# Model fingerprint: 0xbc17a1eb
# Variable types: 0 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [7e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Found heuristic solution: objective 31.0000000
# Presolve removed 7 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 31
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.100000000000e+01, best bound 3.100000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0x18b57edd
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [8e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Found heuristic solution: objective 28.0000000
# Presolve removed 7 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 28
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.800000000000e+01, best bound 2.800000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 4 columns and 12 nonzeros
# Model fingerprint: 0xb013e41a
# Variable types: 0 continuous, 4 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [8e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Found heuristic solution: objective 24.0000000
# Presolve removed 7 rows and 4 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 24
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.400000000000e+01, best bound 2.400000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 6 columns and 18 nonzeros
# Model fingerprint: 0x9f7ce23f
# Variable types: 0 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [6e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Found heuristic solution: objective 18.0000000
# Presolve removed 3 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 4 rows, 6 columns, 12 nonzeros
# Variable types: 0 continuous, 6 integer (6 binary)
#
# Root relaxation: objective 3.100000e+01, 2 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      31.0000000   31.00000  0.00%     -    0s
#
# Explored 0 nodes (2 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 31 18
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.100000000000e+01, best bound 3.100000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0x50084e77
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [4e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Found heuristic solution: objective 16.0000000
# Presolve removed 7 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 16
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.600000000000e+01, best bound 1.600000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 5 columns and 15 nonzeros
# Model fingerprint: 0x705c2ca8
# Variable types: 0 continuous, 5 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [8e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Found heuristic solution: objective 30.0000000
# Presolve removed 7 rows and 5 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 30
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.000000000000e+01, best bound 3.000000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 6 columns and 18 nonzeros
# Model fingerprint: 0x9d197c9c
# Variable types: 0 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [5e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Found heuristic solution: objective 13.0000000
# Presolve removed 2 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 5 rows, 5 columns, 10 nonzeros
# Variable types: 0 continuous, 5 integer (5 binary)
#
# Root relaxation: objective 2.050000e+01, 3 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   20.50000    0    5   13.00000   20.50000  57.7%     -    0s
# H    0     0                      20.0000000   20.50000  2.50%     -    0s
#      0     0   20.50000    0    5   20.00000   20.50000  2.50%     -    0s
#
# Explored 1 nodes (3 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 20 13
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+01, best bound 2.000000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 5 columns and 15 nonzeros
# Model fingerprint: 0xa9b71e43
# Variable types: 0 continuous, 5 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [7e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Found heuristic solution: objective 14.0000000
# Presolve removed 7 rows and 5 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 18 14
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.800000000000e+01, best bound 1.800000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 8 columns and 24 nonzeros
# Model fingerprint: 0x506e5bf8
# Variable types: 0 continuous, 8 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [4e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Found heuristic solution: objective 21.0000000
# Presolve removed 7 rows and 8 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 32 21
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.200000000000e+01, best bound 3.200000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 7 columns and 21 nonzeros
# Model fingerprint: 0x23f9d081
# Variable types: 0 continuous, 7 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [8e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Found heuristic solution: objective 22.0000000
# Presolve removed 3 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 4 rows, 4 columns, 8 nonzeros
# Found heuristic solution: objective 46.0000000
# Variable types: 0 continuous, 4 integer (4 binary)
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 46 22
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.600000000000e+01, best bound 4.600000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 8 rows, 8 columns and 24 nonzeros
# Model fingerprint: 0xbb62687b
# Variable types: 0 continuous, 8 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [7e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+01]
# Found heuristic solution: objective 28.0000000
# Presolve removed 8 rows and 8 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 31 28
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.100000000000e+01, best bound 3.100000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 8 rows, 4 columns and 12 nonzeros
# Model fingerprint: 0x12c5f0e7
# Variable types: 0 continuous, 4 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+01, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+01]
# Found heuristic solution: objective 36.0000000
# Presolve removed 8 rows and 4 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 36
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.600000000000e+01, best bound 3.600000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 8 rows, 9 columns and 27 nonzeros
# Model fingerprint: 0x115c6b07
# Variable types: 0 continuous, 9 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [5e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+01]
# Found heuristic solution: objective 30.0000000
# Presolve removed 1 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 7 rows, 8 columns, 17 nonzeros
# Variable types: 0 continuous, 8 integer (8 binary)
#
# Root relaxation: objective 3.300000e+01, 4 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      33.0000000   33.00000  0.00%     -    0s
#
# Explored 0 nodes (4 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 33 30
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.300000000000e+01, best bound 3.300000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 8 rows, 5 columns and 15 nonzeros
# Model fingerprint: 0x67378829
# Variable types: 0 continuous, 5 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [6e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+01]
# Found heuristic solution: objective 14.0000000
# Presolve removed 8 rows and 5 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 26 14
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.600000000000e+01, best bound 2.600000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 8 rows, 6 columns and 18 nonzeros
# Model fingerprint: 0x05fff3aa
# Variable types: 0 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [6e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+01]
# Found heuristic solution: objective 18.0000000
# Presolve removed 8 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 19 18
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.900000000000e+01, best bound 1.900000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 8 rows, 6 columns and 18 nonzeros
# Model fingerprint: 0x2ee42761
# Variable types: 0 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [5e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+01]
# Found heuristic solution: objective 27.0000000
# Presolve removed 8 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 27
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.700000000000e+01, best bound 2.700000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# ...
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 74 62
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.400000000000e+01, best bound 7.400000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 21 rows, 20 columns and 60 nonzeros
# Model fingerprint: 0x545ac51c
# Variable types: 0 continuous, 20 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 68.0000000
# Presolve removed 21 rows and 20 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 85 68
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.500000000000e+01, best bound 8.500000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 21 rows, 17 columns and 51 nonzeros
# Model fingerprint: 0x0a0c0696
# Variable types: 0 continuous, 17 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [5e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 70.0000000
# Presolve removed 21 rows and 17 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 84 70
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.400000000000e+01, best bound 8.400000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 21 rows, 19 columns and 57 nonzeros
# Model fingerprint: 0x10be4b12
# Variable types: 0 continuous, 19 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [5e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 74.0000000
# Presolve removed 14 rows and 11 columns
# Presolve time: 0.00s
# Presolved: 7 rows, 8 columns, 16 nonzeros
# Found heuristic solution: objective 80.0000000
# Variable types: 0 continuous, 8 integer (8 binary)
#
# Root relaxation: objective 8.400000e+01, 3 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      82.0000000   82.00000  0.00%     -    0s
#
# Explored 0 nodes (4 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 82 80 74
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.200000000000e+01, best bound 8.200000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 21 rows, 17 columns and 51 nonzeros
# Model fingerprint: 0x8b1816e2
# Variable types: 0 continuous, 17 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [6e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 47.0000000
# Presolve removed 21 rows and 17 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 80 47
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.000000000000e+01, best bound 8.000000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 21 rows, 18 columns and 54 nonzeros
# Model fingerprint: 0xda1e0051
# Variable types: 0 continuous, 18 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [4e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 76.0000000
# Presolve removed 21 rows and 18 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 96 76
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.600000000000e+01, best bound 9.600000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 21 rows, 15 columns and 45 nonzeros
# Model fingerprint: 0x5cf1e15a
# Variable types: 0 continuous, 15 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [8e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 87.0000000
# Presolve removed 12 rows and 6 columns
# Presolve time: 0.00s
# Presolved: 9 rows, 9 columns, 18 nonzeros
# Variable types: 0 continuous, 9 integer (9 binary)
#
# Root relaxation: cutoff, 3 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0        87.00000   87.00000  0.00%     -    0s
#
# Explored 0 nodes (3 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 87
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.700000000000e+01, best bound 8.700000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 21 rows, 16 columns and 48 nonzeros
# Model fingerprint: 0xd7679a49
# Variable types: 0 continuous, 16 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [5e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 59.0000000
# Presolve removed 21 rows and 16 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 68 59
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.800000000000e+01, best bound 6.800000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 22 rows, 13 columns and 39 nonzeros
# Model fingerprint: 0xbf945760
# Variable types: 0 continuous, 13 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [6e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 52.0000000
# Presolve removed 22 rows and 13 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 58 52
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.800000000000e+01, best bound 5.800000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 22 rows, 22 columns and 66 nonzeros
# Model fingerprint: 0x30e48b18
# Variable types: 0 continuous, 22 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [6e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 78.0000000
# Presolve removed 11 rows and 7 columns
# Presolve time: 0.00s
# Presolved: 11 rows, 15 columns, 30 nonzeros
# Found heuristic solution: objective 85.0000000
# Variable types: 0 continuous, 15 integer (15 binary)
#
# Root relaxation: objective 9.000000e+01, 7 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      90.0000000   90.00000  0.00%     -    0s
#
# Explored 0 nodes (7 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 90 85 78
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.000000000000e+01, best bound 9.000000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 22 rows, 20 columns and 60 nonzeros
# Model fingerprint: 0xb65056a1
# Variable types: 0 continuous, 20 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [5e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 78.0000000
# Presolve removed 22 rows and 20 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 96 78
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.600000000000e+01, best bound 9.600000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 22 rows, 15 columns and 45 nonzeros
# Model fingerprint: 0xfde9d7b5
# Variable types: 0 continuous, 15 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [5e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 68.0000000
# Presolve removed 16 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 6 rows, 6 columns, 12 nonzeros
# Found heuristic solution: objective 85.0000000
# Variable types: 0 continuous, 6 integer (6 binary)
#
# Root relaxation: cutoff, 2 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0        85.00000   85.00000  0.00%     -    0s
#
# Explored 0 nodes (2 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 85 68
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.500000000000e+01, best bound 8.500000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 22 rows, 19 columns and 57 nonzeros
# Model fingerprint: 0x99ee40e8
# Variable types: 0 continuous, 19 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [4e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 79.0000000
# Presolve removed 22 rows and 19 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 87 79
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.700000000000e+01, best bound 8.700000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 22 rows, 27 columns and 81 nonzeros
# Model fingerprint: 0xcbea5518
# Variable types: 0 continuous, 27 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [6e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 92.0000000
# Presolve removed 22 rows and 27 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 105 92
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.050000000000e+02, best bound 1.050000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 22 rows, 18 columns and 54 nonzeros
# Model fingerprint: 0xc68f4fb5
# Variable types: 0 continuous, 18 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [6e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 86.0000000
# Presolve removed 22 rows and 18 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 87 86
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.700000000000e+01, best bound 8.700000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 22 rows, 19 columns and 57 nonzeros
# Model fingerprint: 0x0e290cd0
# Variable types: 0 continuous, 19 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [5e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 55.0000000
# Presolve removed 22 rows and 19 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 75 55
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.500000000000e+01, best bound 7.500000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 22 rows, 16 columns and 48 nonzeros
# Model fingerprint: 0xc15374af
# Variable types: 0 continuous, 16 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 66.0000000
# Presolve removed 22 rows and 16 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 84 66
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.400000000000e+01, best bound 8.400000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 22 rows, 18 columns and 54 nonzeros
# Model fingerprint: 0x10dc9b98
# Variable types: 0 continuous, 18 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [4e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 66.0000000
# Presolve removed 22 rows and 18 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 88 66
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.800000000000e+01, best bound 8.800000000000e+01, gap 0.0000%

# %%
# Plot results
# Source: https://stackoverflow.com/a/37266356/18307616
plt.figure(figsize=(15,9))

lists = sorted(times_brute.items()) # sorted by key, return a list of tuples

x, y = zip(*lists) # unpack a list of pairs into two tuples

plt.plot(x, y)

lists = sorted(times_gurobi.items()) # sorted by key, return a list of tuples

x, y = zip(*lists) # unpack a list of pairs into two tuples

plt.plot(x, y)

plt.legend(['Brute Force', 'Gurobi'], prop={'size':20})
plt.title("Running time of Brute Force Algorithm on sparse graphs", size=28, weight='bold')
plt.xlabel("Number of vertices", size=20)
plt.ylabel("Running time (seconds)", size=20)
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.show()
