# %%
# import libraries needed
import networkx as nx
from sortedcontainers import SortedList, SortedSet, SortedDict
import random
import numpy as np
import math
from itertools import chain, combinations
from networkx.generators.random_graphs import erdos_renyi_graph, fast_gnp_random_graph
from networkx.algorithms.matching import max_weight_matching
from subprocess import check_output
from gurobipy.gurobipy import Model, quicksum, GRB
import matplotlib.pylab as plt

# %%
# Create new edge and set edge weight and cost
def setEdgeData(G, edge, weight, cost):
    G.add_edge(edge[0], edge[1])
    G[edge[0]][edge[1]]['weight'] = weight
    G[edge[0]][edge[1]]['cost'] = cost

def getEdgeCost(G, edge):
    return G[edge[0]][edge[1]]['cost']

def getEdgeWeight(G, edge):
    return G[edge[0]][edge[1]]['weight']

def zerotruncatedPoisson(p):
    #source: https://web.archive.org/web/20180826164029/http://giocc.com/zero_truncated_poisson_sampling_algorithm.html
    k = 1
    t = math.e**(-p) / (1 - math.e**(-p)) * p
    s = t
    u = random.random()
    while s < u:
        k += 1
        t *= p / k
        s += t
    return k

def isMatching(edges):
    # Check if set of edges is matching
    seen = []
    for e in edges:
        if e[0] in seen:
            return False
        seen.append(e[0])
        if e[1] in seen:
            return False
        seen.append(e[1])
    return True

def powerset(iterable, maxSize):
    "Source: https://docs.python.org/3/library/itertools.html#itertools-recipes"
    "powerset([1,2,3]) --> () (1,) (2,) (3,) (1,2) (1,3) (2,3) (1,2,3)"
    s = list(iterable)
    return chain.from_iterable(combinations(s, r) for r in range(maxSize+1))
def powersetAll(iterable):
    "Source: https://docs.python.org/3/library/itertools.html#itertools-recipes"
    "powerset([1,2,3]) --> () (1,) (2,) (3,) (1,2) (1,3) (2,3) (1,2,3)"
    s = list(iterable)
    return chain.from_iterable(combinations(s, r) for r in range(len(s)+1))



def generateRandomGraph(n, p, Ew, Ec):
    """
    Generates random graph using the Erdös-Rényi model.
    params
    n: number of vertices
    p: probability parameter Erdös-Rényi
    Ew: zero truncated poisson weight parameter
    Ec: poisson cost parameter
    """
    graph = erdos_renyi_graph(n,p)
    for edge in graph.edges:
        weight = 0
        cost = 0
        weight = zerotruncatedPoisson(Ew)
        cost = np.random.poisson(Ec)
        setEdgeData(graph, edge, weight, cost)
    return graph
    

def computeCost(g, matching):
    # compute cost of matching
    return sum(getEdgeCost(g, e) for e in matching)
def computeWeight(g, matching):
    # compute weight of matching
    return sum(getEdgeWeight(g, e) for e in matching)
def budgetedMatchingProblemBruteforce(g, B):
    # solve BMP by bruteforce
    maximum = 0
    cost = 0
    matching = None
    for e in powerset(g.edges, len(g.nodes)//2):
        if isMatching(e):
            c = computeCost(g, e)
            m = computeWeight(g, e)
            if c <= B and m > maximum:
                maximum = m
                matching = e
                cost = c
    return cost, maximum, matching

def generateRandomRestricted(n, p, Ec):
    """
    Generates random graph using the Erdös-Rényi model.
    The weights of all edges are 1
    The costs are following a poisson parameter
    Here the 'weight' variable of each edge denotes the edge cost not edge weight
    params
    n: number of vertices
    p: probability parameter Erdös-Rényi
    Ec: poisson cost parameter
    """
    graph = fast_gnp_random_graph(n,p)
    for edge in graph.edges:
        graph[edge[0]][edge[1]]['weight'] = np.random.poisson(Ec) # Edge cost!
    return graph

def restrictedToGeneral(G):
    """
    Transform graph instance with weights 1
    to general instance of budgeted matching problem
    """
    graph = nx.Graph()
    for e in G.edges():
        setEdgeData(graph, e, 1, G[e[0]][e[1]]['weight'])
    return graph

# %%
### Using Min Weight Max Cardinality Matching

G = generateRandomRestricted(40,0.8,5)

# %%
nx.draw(G)

# %%
def transform_graph(G, weight="weight"):
    """
    Transforms min weight to max weight problem
    """
    if len(G.edges) == 0:
        return max_weight_matching(G, maxcardinality, weight)
    G_edges = G.edges(data=weight, default=1)
    min_weight = min([w for _, _, w in G_edges])
    InvG = nx.Graph()
    edges = ((u, v, 1 / (1 + w - min_weight)) for u, v, w in G_edges)
    InvG.add_weighted_edges_from(edges, weight=weight)
    return InvG

def transform_graph_min_size_k(G, k, weight="weight"):
    """
    Transforms max weight matching to max weight matching on k vertices
    """
    transG = nx.Graph()
    G_edges = G.edges(data=weight, default=1)
    edges = ((u, v, w) for u, v, w in G_edges)
    transG.add_weighted_edges_from(edges, weight=weight)
    old_nodes = list(G.nodes).copy()
    for i in range(len(G.nodes), 2*len(G.nodes)-2*k):
        for j in old_nodes:
            transG.add_edge(j, i, weight=0)
    return transG

def graphToAdjacency(G):
    """
    Transform graph to adjacency list
    """
    lines = []
    lines.append(str(len(G.nodes)))
    lines.append(str(len(G.edges)))
    for e in G.edges:
        e0 = e[0]
        e1 = e[1]
        lines.append(f"{e0} {e1} {G[e0][e1]['weight']}")
    return lines

def min_cost_matching(G):
    """
    Returns minimum cost perfect matching, if exists else false
    """
    adjacency = graphToAdjacency(G)
    f = open("input.txt", "w")
    for line in adjacency:
        f.write(line)
        f.write("\n")
    f.close()
    try:
        raw_data = check_output('MinimumCostMatching\example -f input.txt --minweight', shell=True).decode('utf-8').split(":")[-1].split("\r\n")
    except:
        return False
    return set(tuple(int(e) for e in x.split(" ")) for x in raw_data if x!="")

def min_cost_matching_size_k(G, k):
    """
    Compute minimum cost matching of size k
    """
    graph = transform_graph_min_size_k(G, k)
    matching = min_cost_matching(graph)
    if matching == False: return False
    nodesG = len(G.nodes)
    return set(x for x in matching if (x[0] < nodesG and x[1] < nodesG))
    
def budgetedMatchingPolynomial(G, B):
    """
    BudgetedMatching on graph G with weights restricted to 1
    and buget B in polynomial time
    """
    matching = min_cost_matching(G)
    maximumWeight = len(G.nodes)//2
    cost = sum(G[e[0]][e[1]]["weight"] for e in matching) if matching != False else B
    
    while (cost > B or not(matching)) and maximumWeight > 0:
        maximumWeight -= 1
        matching = min_cost_matching_size_k(G, maximumWeight)
        if (matching != False): cost = sum(G[e[0]][e[1]]["weight"] for e in matching)
    return (cost, maximumWeight, matching)

# %%
def computeCost(g, matching):
    # Compute cost of matching
    return sum(getEdgeCost(g, e) for e in matching)
def computeWeight(g, matching):
    # Compute weight of matching
    return sum(getEdgeWeight(g, e) for e in matching)
def budgetedMatchingProblemBruteforce(g, B):
    # solve BMP by bruteforce
    maximum = 0
    cost = 0
    matching = None
    for e in powerset(g.edges):
        if len(e) <= len(g.nodes) and isMatching(e):
            c = computeCost(g, e)
            m = computeWeight(g, e)
            if c <= B and m > maximum:
                maximum = m
                matching = e
                cost = c
    return cost, maximum, matching

# %%
from gurobipy.gurobipy import Model, quicksum, GRB
# ============================================ GUROBI ====================================================
def restricted_graph_to_gurobi(graph, budget):
    # Transform graph with weights = 1 to gurobi instance
    model = Model("Budgeted Matching Restricted")
    x = {}
    edges = list(graph.edges)
    nodes = list(graph.nodes)
    for e in edges:
        x[e] = model.addVar(vtype=GRB.INTEGER, name=f'edge[{e}]', lb = 0, ub=1)
    model.addConstrs(
        (quicksum(x[e] for e in edges if v in e) <= 1 for v in nodes),
        name='Satisfy Matching'
    )
    model.addConstr(
        quicksum(x[e] * getEdgeWeight(graph, e) for e in edges) <= budget,
        name='Satisfy Budget'
    )
    model.setObjective(
        quicksum(x[e] for e in edges),
        sense=GRB.MAXIMIZE
    )
    return model

# %%
def check_model(graph, budget):
    # Check that budgeted matching done in polynomial time the same value gives as
    # Gurobi linear program
    m = restricted_graph_to_gurobi(graph, budget)
    m.optimize()
    num1 = budgetedMatchingPolynomial(graph, budget)[1]
    num2 = int(m.objVal)
    return num1 == num2

# %%
'''
Test of budgeted matching polynomial program on dense graphs
Results get saved in dict times_brute_dense and times_gurobi_dense
'''
# Dense Graphs
times_brute_dense = {}
times_gurobi_dense = {}
for n in range(2,51):
    print("iterationnumber", n)
    running_time_bruteforce = 0
    running_time_gurobi = 0
    for i in range(10):
        g = generateRandomRestricted(n, 0.8, 10)
        gurobi = restricted_graph_to_gurobi(g, 3*n)
        start = time.time()
        budgetedMatchingPolynomial(g, 3*n)
        end = time.time()
        running_time_bruteforce += end - start
        
        start = time.time()
        gurobi.optimize()
        end = time.time()
        running_time_gurobi += end - start
    times_brute_dense[n] = running_time_bruteforce / 10
    times_gurobi_dense[n] = running_time_gurobi / 10
# Out:
# iterationnumber 2
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 0 columns and 0 nonzeros
# Model fingerprint: 0x003196a4
# Coefficient statistics:
#   Matrix range     [0e+00, 0e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 3 rows and 0 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds
# Optimal objective -0.000000000e+00
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0xce4abc4d
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 0 columns and 0 nonzeros
# Model fingerprint: 0x003196a4
# Coefficient statistics:
#   Matrix range     [0e+00, 0e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 3 rows and 0 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds
# Optimal objective -0.000000000e+00
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0xb553d7e4
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0xb553d7e4
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0xa57b1f3f
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0x6586ca0d
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 0 columns and 0 nonzeros
# Model fingerprint: 0x003196a4
# Coefficient statistics:
#   Matrix range     [0e+00, 0e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 3 rows and 0 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds
# Optimal objective -0.000000000e+00
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0x8eb85f1a
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0xb553d7e4
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# iterationnumber 3
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0xa10d927f
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective 1.0000000
# Presolve removed 4 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0xdc61716e
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective 1.0000000
# Presolve removed 4 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0x9ea9122c
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective 1.0000000
# Presolve removed 4 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0xe8ede374
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 4 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0x2bd5cc91
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 4 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0xf843fc76
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective 1.0000000
# Presolve removed 4 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0x0a6b9352
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective 1.0000000
# Presolve removed 4 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0x9add926b
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 4 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0xca441012
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 4 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0xfcff7f81
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective 1.0000000
# Presolve removed 4 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# iterationnumber 4
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 4 columns and 12 nonzeros
# Model fingerprint: 0xfad1aa4d
# Variable types: 0 continuous, 4 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 5 rows and 4 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 4 columns and 12 nonzeros
# Model fingerprint: 0x4bf154da
# Variable types: 0 continuous, 4 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 5 rows and 4 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 5 columns and 15 nonzeros
# Model fingerprint: 0x960ea93f
# Variable types: 0 continuous, 5 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 5 rows and 5 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0x124a66f5
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 5 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 5 columns and 15 nonzeros
# Model fingerprint: 0x41c04dcf
# Variable types: 0 continuous, 5 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 5 rows and 5 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 5 columns and 15 nonzeros
# Model fingerprint: 0x65ab3188
# Variable types: 0 continuous, 5 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 5 rows and 5 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 5 columns and 15 nonzeros
# Model fingerprint: 0x808f480a
# Variable types: 0 continuous, 5 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 2.0000000
# Presolve removed 5 rows and 5 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 4 columns and 12 nonzeros
# Model fingerprint: 0x60c64243
# Variable types: 0 continuous, 4 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 5 rows and 4 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 5 columns and 15 nonzeros
# Model fingerprint: 0x97659afa
# Variable types: 0 continuous, 5 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 5 rows and 5 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 5 columns and 15 nonzeros
# Model fingerprint: 0x7ff702f2
# Variable types: 0 continuous, 5 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 5 rows and 5 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# iterationnumber 5
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 8 columns and 24 nonzeros
# Model fingerprint: 0x35843047
# Variable types: 0 continuous, 8 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 6 rows and 8 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 9 columns and 27 nonzeros
# Model fingerprint: 0x2a25593c
# Variable types: 0 continuous, 9 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 2.0000000
# Presolve removed 6 rows and 9 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 5 columns and 15 nonzeros
# Model fingerprint: 0x6e09cf85
# Variable types: 0 continuous, 5 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 2 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 9 columns and 27 nonzeros
# Model fingerprint: 0x7368c895
# Variable types: 0 continuous, 9 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 2 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 4 rows, 4 columns, 8 nonzeros
# Found heuristic solution: objective 2.0000000
# Variable types: 0 continuous, 4 integer (4 binary)
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 2 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 8 columns and 24 nonzeros
# Model fingerprint: 0x276fdd64
# Variable types: 0 continuous, 8 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 6 rows and 8 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 2 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 9 columns and 27 nonzeros
# Model fingerprint: 0x4b1c3252
# Variable types: 0 continuous, 9 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 6 rows and 9 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 4 columns and 12 nonzeros
# Model fingerprint: 0xc4c23134
# Variable types: 0 continuous, 4 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 2.0000000
# Presolve removed 6 rows and 4 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 8 columns and 24 nonzeros
# Model fingerprint: 0x0b1ff0df
# Variable types: 0 continuous, 8 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 6 rows and 8 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 2 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 9 columns and 27 nonzeros
# Model fingerprint: 0xfa640aa3
# Variable types: 0 continuous, 9 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 6 rows and 9 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 2 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 7 columns and 21 nonzeros
# Model fingerprint: 0xb0d26bdb
# Variable types: 0 continuous, 7 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 6 rows and 7 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# iterationnumber 6
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 12 columns and 36 nonzeros
# Model fingerprint: 0x48b6c0cb
# Variable types: 0 continuous, 12 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 2.0000000
# Presolve removed 7 rows and 12 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 11 columns and 33 nonzeros
# Model fingerprint: 0x33081810
# Variable types: 0 continuous, 11 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 7 rows and 11 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 2 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 12 columns and 36 nonzeros
# Model fingerprint: 0x1143fd9c
# Variable types: 0 continuous, 12 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 7 rows and 12 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 2 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 8 columns and 24 nonzeros
# Model fingerprint: 0x32ab7601
# Variable types: 0 continuous, 8 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 2.0000000
# Presolve removed 7 rows and 8 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 13 columns and 39 nonzeros
# Model fingerprint: 0xb7de630f
# Variable types: 0 continuous, 13 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 2.0000000
# Presolve removed 1 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 6 rows, 8 columns, 23 nonzeros
# Variable types: 0 continuous, 8 integer (8 binary)
#
# Root relaxation: cutoff, 2 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         2.00000    2.00000  0.00%     -    0s
#
# Explored 0 nodes (2 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 10 columns and 30 nonzeros
# Model fingerprint: 0x533f2d25
# Variable types: 0 continuous, 10 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 7 rows and 10 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 2 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 12 columns and 36 nonzeros
# Model fingerprint: 0x3f814dd9
# Variable types: 0 continuous, 12 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 2.0000000
# Presolve removed 7 rows and 12 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 11 columns and 33 nonzeros
# Model fingerprint: 0xf2c6c563
# Variable types: 0 continuous, 11 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 2.0000000
# Presolve removed 7 rows and 11 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 12 columns and 36 nonzeros
# Model fingerprint: 0xb15f65a1
# Variable types: 0 continuous, 12 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 7 rows and 12 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 2 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 13 columns and 39 nonzeros
# Model fingerprint: 0x08f8dc69
# Variable types: 0 continuous, 13 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 2.0000000
# Presolve removed 1 rows and 7 columns
# Presolve time: 0.00s
# Presolved: 6 rows, 6 columns, 17 nonzeros
# Variable types: 0 continuous, 6 integer (6 binary)
#
# Root relaxation: cutoff, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         2.00000    2.00000  0.00%     -    0s
#
# Explored 0 nodes (1 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# iterationnumber 7
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 8 rows, 15 columns and 45 nonzeros
# Model fingerprint: 0x59e08a31
# Variable types: 0 continuous, 15 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 2.0000000
# Presolve removed 8 rows and 15 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 8 rows, 17 columns and 51 nonzeros
# Model fingerprint: 0x2b5651c0
# Variable types: 0 continuous, 17 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 2.0000000
# Presolve removed 2 rows and 10 columns
# Presolve time: 0.00s
# Presolved: 6 rows, 7 columns, 19 nonzeros
# Found heuristic solution: objective 2.0000000
# Variable types: 0 continuous, 7 integer (7 binary)
#
# Root relaxation: cutoff, 3 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         2.00000    2.00000  0.00%     -    0s
#
# Explored 0 nodes (3 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 2 2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 8 rows, 13 columns and 39 nonzeros
# Model fingerprint: 0x48849808
# Variable types: 0 continuous, 13 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 2.0000000
# Presolve removed 1 rows and 4 columns
# Presolve time: 0.00s
# Presolved: 7 rows, 9 columns, 27 nonzeros
# Found heuristic solution: objective 2.0000000
# Variable types: 0 continuous, 9 integer (9 binary)
#
# Root relaxation: objective 3.040000e+00, 9 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       3.0000000    3.00000  0.00%     -    0s
#
# Explored 0 nodes (10 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 3 2 2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.000000000000e+00, best bound 3.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 8 rows, 19 columns and 57 nonzeros
# Model fingerprint: 0xcca1a9b3
# Variable types: 0 continuous, 19 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 0 rows and 8 columns
# Presolve time: 0.00s
# Presolved: 8 rows, 11 columns, 33 nonzeros
# Found heuristic solution: objective 2.0000000
# Variable types: 0 continuous, 11 integer (11 binary)
#
# Root relaxation: cutoff, 4 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         2.00000    2.00000  0.00%     -    0s
#
# Explored 0 nodes (4 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 2 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 8 rows, 16 columns and 48 nonzeros
# Model fingerprint: 0x50f2f006
# Variable types: 0 continuous, 16 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 2.0000000
# Presolve removed 4 rows and 12 columns
# Presolve time: 0.00s
# Presolved: 4 rows, 4 columns, 8 nonzeros
# Found heuristic solution: objective 3.0000000
# Variable types: 0 continuous, 4 integer (4 binary)
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 3 2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.000000000000e+00, best bound 3.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 8 rows, 16 columns and 48 nonzeros
# Model fingerprint: 0xf7f57830
# Variable types: 0 continuous, 16 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
# ...
#
#      0     0   24.50000    0    3   17.00000   24.50000  44.1%     -    0s
# H    0     0                      24.0000000   24.50000  2.08%     -    0s
#      0     0   24.50000    0    3   24.00000   24.50000  2.08%     -    0s
#
# Explored 1 nodes (459 simplex iterations) in 0.02 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 24 17
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.400000000000e+01, best bound 2.400000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 50 rows, 940 columns and 2820 nonzeros
# Model fingerprint: 0xa7b66a58
# Variable types: 0 continuous, 940 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Found heuristic solution: objective 17.0000000
# Presolve time: 0.00s
# Presolved: 50 rows, 940 columns, 2820 nonzeros
# Variable types: 0 continuous, 940 integer (940 binary)
#
# Root relaxation: objective 2.450000e+01, 151 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   24.50000    0    3   17.00000   24.50000  44.1%     -    0s
# H    0     0                      24.0000000   24.50000  2.08%     -    0s
#      0     0   24.50000    0    3   24.00000   24.50000  2.08%     -    0s
#
# Explored 1 nodes (631 simplex iterations) in 0.02 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 24 17
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.400000000000e+01, best bound 2.400000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 50 rows, 936 columns and 2808 nonzeros
# Model fingerprint: 0xc2c0a639
# Variable types: 0 continuous, 936 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Found heuristic solution: objective 13.0000000
# Presolve time: 0.00s
# Presolved: 50 rows, 936 columns, 2808 nonzeros
# Variable types: 0 continuous, 936 integer (936 binary)
#
# Root relaxation: objective 2.450000e+01, 168 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   24.50000    0    3   13.00000   24.50000  88.5%     -    0s
# H    0     0                      24.0000000   24.50000  2.08%     -    0s
#      0     0   24.50000    0    3   24.00000   24.50000  2.08%     -    0s
#
# Explored 1 nodes (304 simplex iterations) in 0.02 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 24 13
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.400000000000e+01, best bound 2.400000000000e+01, gap 0.0000%
# iterationnumber 50
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 51 rows, 977 columns and 2931 nonzeros
# Model fingerprint: 0xa5b3ebbd
# Variable types: 0 continuous, 977 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 14.0000000
# Presolve time: 0.00s
# Presolved: 51 rows, 977 columns, 2931 nonzeros
# Variable types: 0 continuous, 977 integer (977 binary)
#
# Root relaxation: objective 2.500000e+01, 166 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      25.0000000  977.00000  3808%     -    0s
#      0     0          -    0        25.00000   25.00000  0.00%     -    0s
#
# Explored 0 nodes (604 simplex iterations) in 0.02 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 25 14
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.500000000000e+01, best bound 2.500000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 51 rows, 978 columns and 2934 nonzeros
# Model fingerprint: 0x53003d5d
# Variable types: 0 continuous, 978 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 15.0000000
# Presolve time: 0.00s
# Presolved: 51 rows, 978 columns, 2934 nonzeros
# Variable types: 0 continuous, 978 integer (978 binary)
#
# Root relaxation: objective 2.500000e+01, 132 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      25.0000000  978.00000  3812%     -    0s
#      0     0          -    0        25.00000   25.00000  0.00%     -    0s
#
# Explored 0 nodes (337 simplex iterations) in 0.02 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 25 15
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.500000000000e+01, best bound 2.500000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 51 rows, 977 columns and 2931 nonzeros
# Model fingerprint: 0x3334fd4c
# Variable types: 0 continuous, 977 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 16.0000000
# Presolve time: 0.00s
# Presolved: 51 rows, 977 columns, 2931 nonzeros
# Variable types: 0 continuous, 977 integer (977 binary)
#
# Root relaxation: objective 2.500000e+01, 140 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   25.00000    0    6   16.00000   25.00000  56.3%     -    0s
# H    0     0                      25.0000000   25.00000  0.00%     -    0s
#      0     0   25.00000    0    6   25.00000   25.00000  0.00%     -    0s
#
# Explored 1 nodes (224 simplex iterations) in 0.02 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 25 16
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.500000000000e+01, best bound 2.500000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 51 rows, 960 columns and 2880 nonzeros
# Model fingerprint: 0xf4a3eb01
# Variable types: 0 continuous, 960 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 15.0000000
# Presolve time: 0.00s
# Presolved: 51 rows, 960 columns, 2880 nonzeros
# Variable types: 0 continuous, 960 integer (960 binary)
#
# Root relaxation: objective 2.500000e+01, 149 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   25.00000    0    8   15.00000   25.00000  66.7%     -    0s
# H    0     0                      25.0000000   25.00000  0.00%     -    0s
#      0     0   25.00000    0    8   25.00000   25.00000  0.00%     -    0s
#
# Explored 1 nodes (149 simplex iterations) in 0.02 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 25 15
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.500000000000e+01, best bound 2.500000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 51 rows, 1009 columns and 3027 nonzeros
# Model fingerprint: 0xfe3860b1
# Variable types: 0 continuous, 1009 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 16.0000000
# Presolve time: 0.01s
# Presolved: 51 rows, 1009 columns, 3027 nonzeros
# Variable types: 0 continuous, 1009 integer (1009 binary)
#
# Root relaxation: objective 2.500000e+01, 137 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   25.00000    0    8   16.00000   25.00000  56.3%     -    0s
# H    0     0                      25.0000000   25.00000  0.00%     -    0s
#      0     0   25.00000    0    8   25.00000   25.00000  0.00%     -    0s
#
# Explored 1 nodes (137 simplex iterations) in 0.02 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 25 16
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.500000000000e+01, best bound 2.500000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 51 rows, 992 columns and 2976 nonzeros
# Model fingerprint: 0xd0a45c63
# Variable types: 0 continuous, 992 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 14.0000000
# Presolve time: 0.00s
# Presolved: 51 rows, 992 columns, 2976 nonzeros
# Variable types: 0 continuous, 992 integer (992 binary)
#
# Root relaxation: objective 2.500000e+01, 114 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      25.0000000  992.00000  3868%     -    0s
#      0     0          -    0        25.00000   25.00000  0.00%     -    0s
#
# Explored 0 nodes (319 simplex iterations) in 0.02 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 25 14
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.500000000000e+01, best bound 2.500000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 51 rows, 994 columns and 2982 nonzeros
# Model fingerprint: 0x380c0e6c
# Variable types: 0 continuous, 994 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 15.0000000
# Presolve time: 0.00s
# Presolved: 51 rows, 994 columns, 2982 nonzeros
# Variable types: 0 continuous, 994 integer (994 binary)
#
# Root relaxation: objective 2.500000e+01, 145 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      25.0000000  994.00000  3876%     -    0s
#      0     0          -    0        25.00000   25.00000  0.00%     -    0s
#
# Explored 0 nodes (485 simplex iterations) in 0.02 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 25 15
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.500000000000e+01, best bound 2.500000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 51 rows, 966 columns and 2898 nonzeros
# Model fingerprint: 0x4c2cd668
# Variable types: 0 continuous, 966 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 14.0000000
# Presolve time: 0.00s
# Presolved: 51 rows, 966 columns, 2898 nonzeros
# Variable types: 0 continuous, 966 integer (966 binary)
#
# Root relaxation: objective 2.500000e+01, 128 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   25.00000    0    9   14.00000   25.00000  78.6%     -    0s
# H    0     0                      24.0000000   25.00000  4.17%     -    0s
# H    0     0                      25.0000000   25.00000  0.00%     -    0s
#      0     0   25.00000    0    9   25.00000   25.00000  0.00%     -    0s
#
# Explored 1 nodes (379 simplex iterations) in 0.02 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 25 24 14
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.500000000000e+01, best bound 2.500000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 51 rows, 997 columns and 2991 nonzeros
# Model fingerprint: 0x7b790c2a
# Variable types: 0 continuous, 997 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 15.0000000
# Presolve time: 0.01s
# Presolved: 51 rows, 997 columns, 2991 nonzeros
# Variable types: 0 continuous, 997 integer (997 binary)
#
# Root relaxation: objective 2.500000e+01, 151 iterations, 0.00 seconds
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   25.00000    0    4   15.00000   25.00000  66.7%     -    0s
# H    0     0                      25.0000000   25.00000  0.00%     -    0s
#      0     0   25.00000    0    4   25.00000   25.00000  0.00%     -    0s
#
# Explored 1 nodes (230 simplex iterations) in 0.02 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 25 15
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.500000000000e+01, best bound 2.500000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 51 rows, 982 columns and 2946 nonzeros
# Model fingerprint: 0xbdf27c2b
# Variable types: 0 continuous, 982 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 18.0000000
# Presolve time: 0.01s
# Presolved: 51 rows, 982 columns, 2946 nonzeros
# Variable types: 0 continuous, 982 integer (982 binary)
#
# Root relaxation: objective 2.500000e+01, 112 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                      25.0000000  982.00000  3828%     -    0s
#      0     0          -    0        25.00000   25.00000  0.00%     -    0s
#
# Explored 0 nodes (389 simplex iterations) in 0.02 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 25 18
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.500000000000e+01, best bound 2.500000000000e+01, gap 0.0000%

# %%
# Plot results
# Source: https://stackoverflow.com/a/37266356/18307616
plt.figure(figsize=(15,9))
lists = sorted(times_brute_dense.items()) # sorted by key, return a list of tuples

x, y = zip(*lists) # unpack a list of pairs into two tuples

plt.plot(x, y)

lists = sorted(times_gurobi_dense.items())

x, y = zip(*lists) # unpack a list of pairs into two tuples

plt.plot(x, y)


plt.legend(['MCBMP Solver', 'Gurobi'], prop={'size':20})
plt.title("Running time of MCBMP solver on dense graphs", size=28, weight='bold')
plt.xlabel("Number of vertices", size=20)
plt.ylabel("Running time (seconds)", size=20)
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.show()

# %%
'''
Test of budgeted matching polynomial program on sparse graphs
Results get saved in dict times_brute and times_gurobi
'''
# Sparse Graphs
times_brute = {}
times_gurobi = {}
for n in range(2,51):
    print("iterationnumber", n)
    running_time_bruteforce = 0
    running_time_gurobi = 0
    for i in range(10):
        g = generateRandomRestricted(n, 2/n, 10)
        gurobi = restricted_graph_to_gurobi(g, 3*n)
        start = time.time()
        budgetedMatchingPolynomial(g, 3*n)
        end = time.time()
        running_time_bruteforce += end - start
        
        start = time.time()
        gurobi.optimize()
        end = time.time()
        running_time_gurobi += end - start
    times_brute[n] = running_time_bruteforce / 10
    times_gurobi[n] = running_time_gurobi / 10
# Out:
# iterationnumber 2
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0xbe720769
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0xce4abc4d
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0xa57b1f3f
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0xff07e588
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective 1.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0x6586ca0d
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0xce4abc4d
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0xd9ad31d9
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0xb553d7e4
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0xff07e588
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective 1.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0xbe720769
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 3 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# iterationnumber 3
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0x463022c3
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective 1.0000000
# Presolve removed 4 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0x15f865f5
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective 1.0000000
# Presolve removed 4 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0xe7d916d2
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective 1.0000000
# Presolve removed 4 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0xf14cfce9
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective 1.0000000
# Presolve removed 4 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0x999d1686
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective 1.0000000
# Presolve removed 4 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0x084eb1ea
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective 1.0000000
# Presolve removed 4 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0x6ee2bff3
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective 1.0000000
# Presolve removed 4 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0xbd570fc8
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective 1.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0xf6f435b7
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective 1.0000000
# Presolve removed 4 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 4 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0x0fac40bc
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective 1.0000000
# Presolve removed 4 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# iterationnumber 4
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0x9f82a804
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 5 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 4 columns and 12 nonzeros
# Model fingerprint: 0xb221b47c
# Variable types: 0 continuous, 4 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 5 rows and 4 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0xf8654bd2
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 5 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0x10f61840
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 5 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0x7f6f7bff
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 5 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 4 columns and 12 nonzeros
# Model fingerprint: 0x28d99c9f
# Variable types: 0 continuous, 4 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 5 rows and 4 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0xe7483ddf
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 5 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 4 columns and 12 nonzeros
# Model fingerprint: 0x5a88889b
# Variable types: 0 continuous, 4 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 5 rows and 4 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 5 columns and 15 nonzeros
# Model fingerprint: 0x3b53430d
# Variable types: 0 continuous, 5 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 5 rows and 5 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 5 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0x98ed8696
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 5 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%
# iterationnumber 5
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0x622b4fec
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 1.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 6 columns and 18 nonzeros
# Model fingerprint: 0xccde9a0c
# Variable types: 0 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0xf900356a
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 2.0000000
# Presolve removed 6 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0x59a742f9
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 6 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 4 columns and 12 nonzeros
# Model fingerprint: 0x12268a45
# Variable types: 0 continuous, 4 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 6 rows and 4 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 4 columns and 12 nonzeros
# Model fingerprint: 0x004df20a
# Variable types: 0 continuous, 4 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 6 rows and 4 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 5 columns and 15 nonzeros
# Model fingerprint: 0xca30488f
# Variable types: 0 continuous, 5 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0xcd544a04
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 6 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 6 columns and 18 nonzeros
# Model fingerprint: 0x73542835
# Variable types: 0 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6 rows, 4 columns and 12 nonzeros
# Model fingerprint: 0xe0081c20
# Variable types: 0 continuous, 4 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 6 rows and 4 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# iterationnumber 6
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 7 columns and 21 nonzeros
# Model fingerprint: 0x45d0b502
# Variable types: 0 continuous, 7 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 2.0000000
# Presolve removed 7 rows and 7 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 7 columns and 21 nonzeros
# Model fingerprint: 0x6b47a28c
# Variable types: 0 continuous, 7 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 7 rows and 7 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 4 columns and 12 nonzeros
# Model fingerprint: 0x390d88e1
# Variable types: 0 continuous, 4 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 2.0000000
# Presolve removed 7 rows and 4 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 5 columns and 15 nonzeros
# Model fingerprint: 0xe82bb71e
# Variable types: 0 continuous, 5 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 2.0000000
# Presolve removed 7 rows and 5 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 4 columns and 12 nonzeros
# Model fingerprint: 0x2fe35684
# Variable types: 0 continuous, 4 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 7 rows and 4 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 3 columns and 9 nonzeros
# Model fingerprint: 0xd98a3d7c
# Variable types: 0 continuous, 3 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 2.0000000
# Presolve removed 7 rows and 3 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 7 columns and 21 nonzeros
# Model fingerprint: 0x299fbbb6
# Variable types: 0 continuous, 7 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 2.0000000
# Presolve removed 7 rows and 7 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 9 columns and 27 nonzeros
# Model fingerprint: 0xe1f25f81
# Variable types: 0 continuous, 9 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 2.0000000
# Presolve removed 1 rows and 4 columns
# Presolve time: 0.00s
# Presolved: 6 rows, 5 columns, 15 nonzeros
# Found heuristic solution: objective 2.0000000
# Variable types: 0 continuous, 5 integer (5 binary)
#
# Root relaxation: cutoff, 2 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         2.00000    2.00000  0.00%     -    0s
#
# Explored 0 nodes (2 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 2 2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0xe00afbdd
# Variable types: 0 continuous, 2 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 7 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7 rows, 5 columns and 15 nonzeros
# Model fingerprint: 0xe5010378
# Variable types: 0 continuous, 5 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 7 rows and 5 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 2 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# iterationnumber 7
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 8 rows, 5 columns and 15 nonzeros
# Model fingerprint: 0x029bcdce
# Variable types: 0 continuous, 5 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 2.0000000
# Presolve removed 8 rows and 5 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 8 rows, 6 columns and 18 nonzeros
# Model fingerprint: 0xa1bf7b29
# Variable types: 0 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 2.0000000
# Presolve removed 8 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 8 rows, 8 columns and 24 nonzeros
# Model fingerprint: 0xa9b27ff6
# Variable types: 0 continuous, 8 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 2.0000000
# Presolve removed 8 rows and 8 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 8 rows, 6 columns and 18 nonzeros
# Model fingerprint: 0x675d8a55
# Variable types: 0 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 2.0000000
# Presolve removed 8 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 8 rows, 6 columns and 18 nonzeros
# Model fingerprint: 0x1dd4f06d
# Variable types: 0 continuous, 6 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 1.0000000
# Presolve removed 8 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 2 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 8 rows, 1 columns and 3 nonzeros
# Model fingerprint: 0x7c46af1e
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 1.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 8 rows, 10 columns and 30 nonzeros
# Model fingerprint: 0x880f662e
# Variable types: 0 continuous, 10 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 2.0000000
# Presolve removed 8 rows and 10 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 8 rows, 8 columns and 24 nonzeros
# Model fingerprint: 0x19f40285
# Variable types: 0 continuous, 8 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 2.0000000
# Presolve removed 8 rows and 8 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 12 available processors)
#
# ...
# Model fingerprint: 0x22879497
# Variable types: 0 continuous, 49 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Found heuristic solution: objective 15.0000000
# Presolve removed 25 rows and 15 columns
# Presolve time: 0.00s
# Presolved: 25 rows, 34 columns, 94 nonzeros
# Found heuristic solution: objective 15.0000000
# Variable types: 0 continuous, 34 integer (33 binary)
#
# Root relaxation: objective 1.716667e+01, 18 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   17.16667    0   13   15.00000   17.16667  14.4%     -    0s
# H    0     0                      17.0000000   17.16667  0.98%     -    0s
#      0     0   17.16667    0   13   17.00000   17.16667  0.98%     -    0s
#
# Explored 1 nodes (18 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 17 15 15
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.700000000000e+01, best bound 1.700000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 50 rows, 44 columns and 132 nonzeros
# Model fingerprint: 0x0f373d37
# Variable types: 0 continuous, 44 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Found heuristic solution: objective 15.0000000
# Presolve removed 37 rows and 21 columns
# Presolve time: 0.00s
# Presolved: 13 rows, 23 columns, 49 nonzeros
# Found heuristic solution: objective 16.0000000
# Variable types: 0 continuous, 23 integer (21 binary)
#
# Root relaxation: objective 1.728571e+01, 6 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   17.28571    0    1   16.00000   17.28571  8.04%     -    0s
# H    0     0                      17.0000000   17.28571  1.68%     -    0s
#      0     0   17.28571    0    1   17.00000   17.28571  1.68%     -    0s
#
# Explored 1 nodes (6 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 17 16 15
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.700000000000e+01, best bound 1.700000000000e+01, gap 0.0000%
# iterationnumber 50
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 51 rows, 44 columns and 132 nonzeros
# Model fingerprint: 0xaebe8a11
# Variable types: 0 continuous, 44 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 15.0000000
# Presolve removed 38 rows and 21 columns
# Presolve time: 0.00s
# Presolved: 13 rows, 23 columns, 48 nonzeros
# Found heuristic solution: objective 17.0000000
# Variable types: 0 continuous, 23 integer (20 binary)
#
# Root relaxation: objective 1.825000e+01, 8 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   18.25000    0    3   17.00000   18.25000  7.35%     -    0s
# H    0     0                      18.0000000   18.25000  1.39%     -    0s
#      0     0   18.25000    0    3   18.00000   18.25000  1.39%     -    0s
#
# Explored 1 nodes (8 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 18 17 15
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.800000000000e+01, best bound 1.800000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 51 rows, 50 columns and 150 nonzeros
# Model fingerprint: 0xba2fbcf7
# Variable types: 0 continuous, 50 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 14.0000000
# Presolve removed 39 rows and 29 columns
# Presolve time: 0.00s
# Presolved: 12 rows, 21 columns, 45 nonzeros
# Found heuristic solution: objective 17.0000000
# Variable types: 0 continuous, 21 integer (18 binary)
#
# Root relaxation: objective 1.813333e+01, 4 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   18.13333    0    1   17.00000   18.13333  6.67%     -    0s
# H    0     0                      18.0000000   18.13333  0.74%     -    0s
#      0     0   18.13333    0    1   18.00000   18.13333  0.74%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 18 17 14
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.800000000000e+01, best bound 1.800000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 51 rows, 42 columns and 126 nonzeros
# Model fingerprint: 0xbdd3d151
# Variable types: 0 continuous, 42 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 13.0000000
# Presolve removed 41 rows and 26 columns
# Presolve time: 0.00s
# Presolved: 10 rows, 16 columns, 39 nonzeros
# Found heuristic solution: objective 16.0000000
# Variable types: 0 continuous, 16 integer (14 binary)
#
# Root relaxation: cutoff, 4 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0        16.00000   16.00000  0.00%     -    0s
#
# Explored 0 nodes (4 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 16 13
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.600000000000e+01, best bound 1.600000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 51 rows, 49 columns and 147 nonzeros
# Model fingerprint: 0xf7c9ecc6
# Variable types: 0 continuous, 49 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 16.0000000
# Presolve removed 27 rows and 16 columns
# Presolve time: 0.00s
# Presolved: 24 rows, 33 columns, 86 nonzeros
# Variable types: 0 continuous, 33 integer (31 binary)
#
# Root relaxation: objective 1.773333e+01, 15 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   17.73333    0    3   16.00000   17.73333  10.8%     -    0s
# H    0     0                      17.0000000   17.73333  4.31%     -    0s
#      0     0   17.73333    0    3   17.00000   17.73333  4.31%     -    0s
#
# Explored 1 nodes (15 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 17 16
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.700000000000e+01, best bound 1.700000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 51 rows, 50 columns and 150 nonzeros
# Model fingerprint: 0x7b53a59a
# Variable types: 0 continuous, 50 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 14.0000000
# Presolve removed 34 rows and 22 columns
# Presolve time: 0.00s
# Presolved: 17 rows, 28 columns, 64 nonzeros
# Found heuristic solution: objective 17.0000000
# Variable types: 0 continuous, 28 integer (27 binary)
#
# Root relaxation: objective 1.800000e+01, 6 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   18.00000    0    2   17.00000   18.00000  5.88%     -    0s
# H    0     0                      18.0000000   18.00000  0.00%     -    0s
#      0     0   18.00000    0    2   18.00000   18.00000  0.00%     -    0s
#
# Explored 1 nodes (6 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 18 17 14
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.800000000000e+01, best bound 1.800000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 51 rows, 52 columns and 156 nonzeros
# Model fingerprint: 0x28d017aa
# Variable types: 0 continuous, 52 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 14.0000000
# Presolve removed 35 rows and 27 columns
# Presolve time: 0.00s
# Presolved: 16 rows, 25 columns, 59 nonzeros
# Found heuristic solution: objective 15.0000000
# Variable types: 0 continuous, 25 integer (22 binary)
#
# Root relaxation: objective 1.677778e+01, 10 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   16.77778    0    5   15.00000   16.77778  11.9%     -    0s
# H    0     0                      16.0000000   16.77778  4.86%     -    0s
#      0     0   16.77778    0    5   16.00000   16.77778  4.86%     -    0s
#
# Explored 1 nodes (10 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 16 15 14
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.600000000000e+01, best bound 1.600000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 51 rows, 48 columns and 144 nonzeros
# Model fingerprint: 0x4dca1b02
# Variable types: 0 continuous, 48 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 16.0000000
# Presolve removed 31 rows and 13 columns
# Presolve time: 0.00s
# Presolved: 20 rows, 35 columns, 89 nonzeros
# Found heuristic solution: objective 16.0000000
# Variable types: 0 continuous, 35 integer (33 binary)
#
# Root relaxation: objective 1.873333e+01, 24 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   18.73333    0    6   16.00000   18.73333  17.1%     -    0s
# H    0     0                      18.0000000   18.73333  4.07%     -    0s
#      0     0   18.73333    0    6   18.00000   18.73333  4.07%     -    0s
#
# Explored 1 nodes (24 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 18 16 16
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.800000000000e+01, best bound 1.800000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 51 rows, 41 columns and 123 nonzeros
# Model fingerprint: 0x50458bf0
# Variable types: 0 continuous, 41 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 15.0000000
# Presolve removed 37 rows and 18 columns
# Presolve time: 0.00s
# Presolved: 14 rows, 23 columns, 54 nonzeros
# Found heuristic solution: objective 17.0000000
# Variable types: 0 continuous, 23 integer (20 binary)
#
# Root relaxation: cutoff, 7 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0        17.00000   17.00000  0.00%     -    0s
#
# Explored 0 nodes (7 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 17 15
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.700000000000e+01, best bound 1.700000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 51 rows, 52 columns and 156 nonzeros
# Model fingerprint: 0xc617a46a
# Variable types: 0 continuous, 52 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 14.0000000
# Presolve removed 39 rows and 30 columns
# Presolve time: 0.00s
# Presolved: 12 rows, 22 columns, 50 nonzeros
# Found heuristic solution: objective 17.0000000
# Variable types: 0 continuous, 22 integer (18 binary)
#
# Root relaxation: objective 1.833333e+01, 9 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   18.33333    0    1   17.00000   18.33333  7.84%     -    0s
# H    0     0                      18.0000000   18.33333  1.85%     -    0s
#      0     0   18.33333    0    1   18.00000   18.33333  1.85%     -    0s
#
# Explored 1 nodes (9 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 18 17 14
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.800000000000e+01, best bound 1.800000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 51 rows, 43 columns and 129 nonzeros
# Model fingerprint: 0x1a6c1adc
# Variable types: 0 continuous, 43 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 15.0000000
# Presolve removed 40 rows and 21 columns
# Presolve time: 0.00s
# Presolved: 11 rows, 22 columns, 44 nonzeros
# Found heuristic solution: objective 16.0000000
# Variable types: 0 continuous, 22 integer (20 binary)
#
# Root relaxation: cutoff, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0        16.00000   16.00000  0.00%     -    0s
#
# Explored 0 nodes (1 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 16 15
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.600000000000e+01, best bound 1.600000000000e+01, gap 0.0000%

# %%
# Plot results
# Source: https://stackoverflow.com/a/37266356/18307616
plt.figure(figsize=(15,9))
lists = sorted(times_brute.items()) # sorted by key, return a list of tuples

x, y = zip(*lists) # unpack a list of pairs into two tuples

plt.plot(x, y)

lists = sorted(times_gurobi.items())

x, y = zip(*lists) # unpack a list of pairs into two tuples

plt.plot(x, y)


plt.legend(['MCBMP Solver', 'Gurobi'], prop={'size':20})
plt.title("Running time of MCBMP solver on sparse graphs", size=28, weight='bold')
plt.xlabel("Number of vertices", size=20)
plt.ylabel("Running time (seconds)", size=20)
plt.tick_params(axis='x', labelsize=20)
plt.tick_params(axis='y', labelsize=20)
plt.show()
